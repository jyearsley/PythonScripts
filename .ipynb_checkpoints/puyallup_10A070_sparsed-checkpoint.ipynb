# %%
import matplotlib.pyplot as plt
from matplotlib.finance import quotes_historical_yahoo
from matplotlib.dates import YearLocator, MonthLocator, DateFormatter
import numpy as np
import pandas as pd
import datetime as dt
from matplotlib.dates import date2num, num2date 
from matplotlib.pyplot import figure, show
from matplotlib import scale as mscale
from matplotlib import transforms as mtransforms
import pylab
import matplotlib
import os
# %matplotlib inline
#import scikits.timeseries as ts
#import scikits.timeseries.lib.plotlib as tpl

os.chdir('/raid/caoqian/DHSVM3.1.2_PugetSound_Run/plot/puyallup')

data = np.loadtxt('obs.txt')
data1 = np.genfromtxt('obs.txt',dtype='int')
year = data1[:,0]
month = data1[:,1]
day = data1[:,2]
hour = data1[:,3]
minute = data1[:,4]
obs = data[:,5]
time=np.zeros([data.shape[0],1])
#print len(time)
#print len(sim)
for i in range(0,data.shape[0]):
    a= year[i]
    b= month[i]
    c= day[i]
    d= hour[i]
    e= minute[i]
    f = dt.datetime(a,b,c,d,e)
    time[i] = date2num(f)
    i+=1
numobs=np.arange(data.shape[0])

data2 = np.loadtxt('sim.txt')
data3 = np.genfromtxt('sim.txt',dtype='int')
year1 = data3[:,0]
month1 = data3[:,1]
day1 = data3[:,2]
hour1 = data3[:,3]
minute1 = data3[:,4]
sim = data2[:,5]
time1=np.zeros([data2.shape[0],1])
#print len(time)
#print len(sim)
for i in range(0,data2.shape[0]):
    a1= year1[i]
    b1= month1[i]
    c1= day1[i]
    d1= hour1[i]
    e1= minute1[i]
    f1 = dt.datetime(a1,b1,c1,d1,e1)
    time1[i] = date2num(f1)
    i+=1
numsim=np.arange(data2.shape[0])
#obs1=np.zeros([data.shape[0],2])
#obs1=[time,obs]
##obs1[:,0]= time
##obs1[:,1]= obs
#print obs1

def find_nearest(array,value):
    idx = (np.abs(array-value)).argmin()
    return array[idx]
array= time1
#value= time[3]
#print value
#print(find_nearest(array, value))

sim_obs=np.zeros([data.shape[0],4])
for i in range(0,data.shape[0]):
    value= time[i]
    sim_obs[i,0]=time[i]
    sim_obs[i,3]=obs[i]
    idx = (np.abs(array-value)).argmin()
    sim_obs[i,1]=array[idx]
    sim_obs[i,2]=sim[idx]
    i+=1
#print sim_obs
#fig,(ax) = plt.plot()
fig = plt.figure(figsize=(12,6))
ax = fig.add_subplot(111)
ax.plot_date(sim_obs[:,0], sim_obs[:,2], 'r',label='Sim')
ax.plot_date(sim_obs[:,0], sim_obs[:,3], 'b',label='Obs')
plt.gcf().autofmt_xdate()
legend = ax.legend(loc='upper right', shadow=True)
plt.title('Daily Water Temperature of Quilcene (17A060)',fontsize=16)
pylab.ylim([2,22])
ax.set_xlabel('time (day)',fontsize=14, x=0.5, y=0)
ax.set_ylabel('Water Temperature (degC)',fontsize=14)
matplotlib.rc('xtick', labelsize=14)
matplotlib.rc('ytick', labelsize=14)
#figure(num=None, figsize=(20, 12), dpi=200, facecolor='w', edgecolor='k')
#plt.show()

# %%
y1=sim
y2=obs
x=time
fig,(ax6) = plt.subplots(1, 1, sharey=True)

ax6.plot_date(x, y1, 'r',label='Sim')
ax6.plot_date(x, y2, 'b',label='Obs')

filepath1='/raid/caoqian/DHSVM3.1.2_PugetSound_Run/plot/quilcene/results/date_tmp17A060.txt'
datase = np.genfromtxt(filepath1,dtype='int')
yearse = datase[:,0]
monthse = datase[:,1]
dayse = datase[:,2]
timese=np.zeros([datase.shape[0],1])
for i in range(0,datase.shape[0]):
    a= yearse[i]
    b= monthse[i]
    c= dayse[i]
    d = dt.date(a,b,c)
    timese[i] = date2num(d)
    i+=1
 
ax6.set_xlim(timese[0],timese[1])

plt.gcf().autofmt_xdate()

legend = ax6.legend(loc='upper right', shadow=True)

fig.suptitle('Daily Water Temperature of Quilcene (17A060)',fontsize=20)

pylab.ylim([9.5,16])
ax6.set_xlabel('time (day)',fontsize=18, x=0.5, y=0)
ax6.set_ylabel('Water Temperature (degC)',fontsize=18)
matplotlib.rc('xtick', labelsize=14)
matplotlib.rc('ytick', labelsize=14)

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.finance import quotes_historical_yahoo
from matplotlib.dates import YearLocator, MonthLocator, DateFormatter
import numpy as np
import pandas as pd
import datetime as dt
from matplotlib.dates import date2num, num2date 
from matplotlib.pyplot import figure, show
from matplotlib import scale as mscale
from matplotlib import transforms as mtransforms
import pylab
import matplotlib
# %matplotlib inline
#import scikits.timeseries as ts
#import scikits.timeseries.lib.plotlib as tpl

filepath='/raid/caoqian/DHSVM3.1.2_PugetSound_Run/plot/puyallup/obs.txt'
filepath1='/raid/caoqian/DHSVM3.1.2_PugetSound_Run/plot/puyallup/sim.txt'

data = np.loadtxt(filepath)
data1 = np.genfromtxt(filepath,dtype='int')
year = data1[:,0]
month = data1[:,1]
day = data1[:,2]
hour = data1[:,3]
minute = data1[:,4]
obs = data[:,5]
time=np.zeros([data.shape[0],1])
#print len(time)
#print len(sim)
for i in range(0,data.shape[0]):
    a= year[i]
    b= month[i]
    c= day[i]
    d= hour[i]
    e= minute[i]
    f = dt.datetime(a,b,c,d,e)
    time[i] = date2num(f)
    i+=1
numobs=np.arange(data.shape[0])

data2 = np.loadtxt(filepath1)
data3 = np.genfromtxt(filepath1,dtype='int')
year1 = data3[:,0]
month1 = data3[:,1]
day1 = data3[:,2]
hour1 = data3[:,3]
minute1 = data3[:,4]
sim = data2[:,5]
time1=np.zeros([data2.shape[0],1])
#print len(time)
#print len(sim)
for i in range(0,data2.shape[0]):
    a1= year1[i]
    b1= month1[i]
    c1= day1[i]
    d1= hour1[i]
    e1= minute1[i]
    f1 = dt.datetime(a1,b1,c1,d1,e1)
    time1[i] = date2num(f1)
    i+=1
numsim=np.arange(data2.shape[0])
#obs1=np.zeros([data.shape[0],2])
#obs1=[time,obs]
##obs1[:,0]= time
##obs1[:,1]= obs
#print obs1

def find_nearest(array,value):
    idx = (np.abs(array-value)).argmin()
    return array[idx]
array= time1
#value= time[3]
#print value
#print(find_nearest(array, value))

sim_obs=np.zeros([data.shape[0],4])
for i in range(0,data.shape[0]):
    value= time[i]
    sim_obs[i,0]=time[i]
    sim_obs[i,3]=obs[i]
    idx = (np.abs(array-value)).argmin()
    sim_obs[i,1]=array[idx]
    sim_obs[i,2]=sim[idx]
    i+=1
#print sim_obs
#fig,(ax) = plt.plot()
#fig,(ax) = plt.subplots(1, 1, sharey=True)
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111)
ax.plot_date(sim_obs[:,0], sim_obs[:,2], 'r',label='Sim')
ax.plot_date(sim_obs[:,0], sim_obs[:,3], 'b',label='Obs')
plt.gcf().autofmt_xdate()
legend = ax.legend(loc='upper right', shadow=True)
plt.title('Daily Water Temperature of Quilcene (17A060)',fontsize=16)
pylab.ylim([2,22])
ax.set_xlabel('time (day)',fontsize=14, x=0.5, y=0)
ax.set_ylabel('Water Temperature (degC)',fontsize=14)
matplotlib.rc('xtick', labelsize=14)
matplotlib.rc('ytick', labelsize=14)
#figure(num=None, figsize=(20, 12), dpi=200, facecolor='w', edgecolor='k')
#plt.show()
