# %% [markdown]
# ###This notebook includes Python tools for analyzing DHSVM outputs.
# Time series data are analyzed with **numpy** and **pandas** tools and plotted with **matplotlib**. Spatial maps are analyzed and plotted using **netCDF4** and **Basemap** utilities. In general, the scripts that needs to be changed (eg. file path, locations, time range, and variables to plot, etc) are on top of the coding block if there's any. However, differences in the input data may require changing the code, such as which columns to read as the dates, how many rows to skip as the header, etc. Currently all input file paths are absolute paths so you should be able to run the code as it is and plot from my output files. All plots are saved into a pdf page (specify the file name in the second code block). Note that you'll have to run the last code block to close the pdf file you opened in order to view the file correctly.

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['norm', 'gradient']
# `%matplotlib` prevents importing * from pylab and numpy

# %% [markdown]
# **First**, import all necessary libraries.

# %%
# Import all needed libraries 
import sys, os, datetime, time
import numpy as np
import pandas as pd
import numpy.ma as ma
import math
import matplotlib.dates as dates
import matplotlib.ticker as ticker
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
from scipy.stats import norm
from scipy import stats

import os
os.getcwd() 
os.chdir("D:\\Dropbox\\Python_Scripts")
os.getcwd()
# Out:
# 'D:\\Dropbox\\Python_Scripts'

# %% [markdown]
# Read the input **streamflow** files (change the path if needed)<br>
# <span style="background-color: #FFFF00">**<span style="color:#f00">Attention</span>**: the last date in obs. file **MUST NOT** exceed the last date of sim.</span>

# %%
# Enter file path for sim. and obs. flow files
simflowpath = 'D:\\Dropbox\\Python_Scripts\\Thornton\\daily_flow.txt'
obsflowpath = 'D:\\Dropbox\\Python_Scripts\\Thornton\\streamflow.12128000.cms.1945_2008.txt'

# Read flow sim and obs dates &  data
simflowdata = np.genfromtxt(simflowpath, usecols=[1])
obsflowdata = np.genfromtxt(obsflowpath, usecols=[1])
tempsimflowdate = np.genfromtxt(simflowpath, dtype = str, skiprows = 0, usecols = 0)
tempobsflowdate = np.genfromtxt(obsflowpath, dtype = str, skiprows = 0, usecols = 0)

# %% [markdown]
# **Sort** and **match** the obs. and sim. flow files based on dates.<br>

# %%
# Convert the string format dates into a datetime object
simflowdate = []
for i in range(len(tempsimflowdate)):
    simflowdate.append(datetime.datetime.strptime(tempsimflowdate[i],'%m/%d/%Y'))
# sort the dates in an acending order
simflowdate.sort()

# Convert the string format dates into a datetime object
obsflowdate = []
for i in range(len(tempobsflowdate)):
    obsflowdate.append(datetime.datetime.strptime(tempobsflowdate[i],'%Y-%m-%d'))
# sort the dates in an acending order
obsflowdate.sort()

# extract the matching dates from both arrays and mark them by mask
# searchsorted(t1,t2) finds index in t1 for every value in t2:    
idx_flow = np.searchsorted(simflowdate, obsflowdate, side='right')-1
j2 = [i for i in idx_flow if i > 0]

# mask the array as true if 
mask_flow = idx_flow >=0

# compare the obs. and sim. time series
df = pd.DataFrame({"simflowdate":tempsimflowdate[idx_flow][mask_flow], "simflow":simflowdata[idx_flow][mask_flow], \
                   "obsflow":obsflowdata[mask_flow], "obsflowdate":tempobsflowdate[mask_flow]})

#print df
#print df.values

# %% [markdown]
# Read the input **water quality**files (change the path if needed)<br>
# <span style="background-color: #FFFF00">**<span style="color:#f00">Attention</span>**: the last date in obs. file **MUST NOT** exceed the last date of sim.</span>

# %%
# Initialize a pdf file for saving all the figures
# pdfpages = PdfPages('test_figure.pdf')

# Enter file path for swater quality simulation files
simsedfilepath = 'D:\\Dropbox\\Python_Scripts\\Thornton\\Sed.Flow.Only'
simotherfilepath = 'D:\\Dropbox\\Python_Scripts\\Thornton\\Other.Conc.Only'

# Enter file path for observed water quality variable files
obsfilepath = 'D:\\Dropbox\\Python_Scripts\\Thornton\\thornton-time-stamped.txt'

# Enter file path for observed precipitation files
precipfilepath = 'D:\\Dropbox\\Python_Scripts\\Thornton\\Mass.Balance'

# Read dates of sims (continuous)
tempsimdates = np.genfromtxt(simsedfilepath, dtype=str, skiprows=2, usecols=0)

# Read dates of obs (discrete). Use the 2nd column
tempobsdates = np.genfromtxt(obsfilepath, dtype=str, skiprows=1, usecols=0)

# Read sediment sims (use the 2nd col)
simseddata = np.genfromtxt(simsedfilepath, skiprows=2, usecols=[2])
simseddata = simseddata + 4
# Read sediment obs.
# Skip the first line, and use the 5th column for sed
obsseddata = np.genfromtxt(obsfilepath, dtype=float, skiprows=1, usecols=[2])

# Read other data
simotherdata = np.genfromtxt(simotherfilepath, skiprows=2, usecols=[1])
print len(simotherdata)
#print simotherdata
obsotherdata = np.genfromtxt(obsfilepath, dtype=float, skiprows=1, usecols=[1])
obsotherdata = obsotherdata * 0.01444;

# Read obs. precipitation data
precipdata = np.genfromtxt(precipfilepath, dtype=float, skiprows=24, usecols=[9])
print len(precipdata)
# Out:
# 37992
# 37992

# %% [markdown]
# **Third**, find out the dates when both sims and obs (discontinous) are available.
#
# <span style="background-color: #FFFF00">**Particular attention** needs to be paid on **<span style="color:#f00">np.searchsorted()</span>**. Output all matching columns to make sure its the right match. Right now, the option **side='right'** must be used in the case of **daily time step (mm/dd/yy)** to avoid the 1-day mismatch. Later when working with **3-hourly set**, this may not hold.</span>

# %%
simdates = []
Fsimdate = []
Fobsdate = []
FsimSed = []
FobsSed = []
FsimOther = []
FobsOther = []

# construct the sim. date obj.
for i in range(len(tempsimdates)):
    simdates.append(datetime.datetime.strptime(tempsimdates[i],'%m/%d/%Y-%H:%M:%S'))
simdates.sort()
# construct the obs. date obj.
obsdates = []
for i in range(len(tempobsdates)):
    obsdates.append(datetime.datetime.strptime(tempobsdates[i],'%m/%d/%Y-%H:%M:%S'))
obsdates.sort()

for i in range(len(obsdates)):
    obs = date2num(obsdates[i])
    junk = date2num(simdates)
    #value = obsdates[i]
    idx = (np.abs(junk-obs)).argmin()
    if (idx > 0):
      Fsimdate.append(simdates[idx])
      Fobsdate.append(obsdates[i])
      FsimSed.append(simseddata[idx])
      FobsSed.append(obsseddata[i])
      FobsOther.append(obsotherdata[i])
      FsimOther.append(simotherdata[idx])


#for i in range(len(FsimSed)):
    #print Fsimdate[i], FsimSed[i], Fobsdate[i], FobsSed[i]
    #print Fsimdate[i], FsimOther[i], Fobsdate[i], FobsOther[i]
    
print min(FobsSed)
# Out:
# 1999-01-19 09:00:00 4.133089 1999-01-19 09:16:00 9.1
# 1999-02-08 09:00:00 4.000873 1999-02-08 09:45:00 15.4
# 1999-02-24 12:00:00 16.530022 1999-02-24 10:41:00 29.2
# 1999-03-08 09:00:00 16.540476 1999-03-08 09:40:00 10.4
# 1999-05-10 12:00:00 4.000001 1999-05-10 10:50:00 2.6
# 1999-06-14 09:00:00 4.0 1999-06-14 09:37:00 11.6
# 1999-07-12 09:00:00 4.0 1999-07-12 09:06:00 5.8
# 1999-08-09 09:00:00 4.000002 1999-08-09 09:07:00 1.4
# 1999-09-13 09:00:00 4.0 1999-09-13 09:36:00 4.7
# 1999-10-11 09:00:00 4.000031 1999-10-11 09:17:00 5.6
# 1999-11-08 09:00:00 15.593719 1999-11-08 09:15:00 27.5
# 1999-11-09 09:00:00 71.328918 1999-11-09 09:59:00 36.3
# 1999-12-06 12:00:00 5.402818 1999-12-06 10:45:00 15.1
# 1999-12-13 09:00:00 4.00106 1999-12-13 09:06:00 12.5
# 2000-01-10 09:00:00 4.000897 2000-01-10 09:20:00 5.2
# 2000-02-01 09:00:00 26.483864 2000-02-01 09:27:00 117.0
# 2000-02-14 09:00:00 36.544109 2000-02-14 09:47:00 5.2
# 2000-02-29 12:00:00 15.491301 2000-02-29 10:36:00 38.4
# 2000-03-13 09:00:00 38.049568 2000-03-13 08:41:00 2.7
# 2000-05-08 09:00:00 4.000027 2000-05-08 10:00:00 5.6
# 2000-06-12 09:00:00 88.876595 2000-06-12 09:25:00 80.0
# 2000-07-10 09:00:00 4.0 2000-07-10 09:06:00 8.5
# 2000-07-31 09:00:00 4.0 2000-07-31 09:05:00 6.7
# 2000-09-11 09:00:00 4.000011 2000-09-11 09:43:00 2.6
# 2000-10-09 09:00:00 58.374649 2000-10-09 09:05:00 8.0
# 2000-11-13 09:00:00 4.0 2000-11-13 09:19:00 3.4
# 2000-12-11 09:00:00 4.0 2000-12-11 09:15:00 7.7
# 2001-01-08 09:00:00 4.000013 2001-01-08 09:25:00 7.2
# 2001-04-09 09:00:00 4.000008 2001-04-09 08:57:00 3.6
# 2001-05-14 09:00:00 72.546432 2001-05-14 08:40:00 22.5
# 2001-06-11 09:00:00 84.023911 2001-06-11 09:55:00 54.9
# 2001-07-09 09:00:00 4.0 2001-07-09 08:54:00 6.8
# 2001-08-13 09:00:00 4.0 2001-08-13 09:10:00 4.4
# 2001-09-10 09:00:00 4.0 2001-09-10 08:53:00 5.6
# 2001-10-08 09:00:00 47.664917 2001-10-08 08:55:00 44.8
# 2001-11-14 09:00:00 43.488106 2001-11-14 09:52:00 42.6
# 2001-12-10 09:00:00 13.664698 2001-12-10 09:34:00 4.0
# 2002-01-14 09:00:00 4.0 2002-01-14 09:15:00 5.8
# 2002-02-11 09:00:00 4.000018 2002-02-11 09:24:00 6.4
# 2002-03-11 09:00:00 50.778049 2002-03-11 09:55:00 56.0
# 2002-04-10 09:00:00 4.665486 2002-04-10 08:55:00 17.6
# 2002-05-15 09:00:00 4.0 2002-05-15 09:15:00 32.2
# 2002-06-11 09:00:00 4.0 2002-06-11 09:23:00 4.5
# 2002-07-10 09:00:00 4.0 2002-07-10 09:30:00 5.3
# 2002-08-13 09:00:00 4.0 2002-08-13 09:13:00 6.0
# 2002-09-11 09:00:00 4.0 2002-09-11 08:37:00 5.15
# 2002-10-16 09:00:00 4.0 2002-10-16 08:45:00 3.7
# 2002-11-12 09:00:00 60.59734 2002-11-12 09:45:00 149.0
# 2002-12-09 09:00:00 4.000048 2002-12-09 09:05:00 5.2
# 2003-01-15 09:00:00 4.000203 2003-01-15 08:40:00 6.4
# 2003-01-27 09:00:00 4.000116 2003-01-27 09:16:00 5.63
# 2003-02-12 09:00:00 4.0 2003-02-12 08:41:00 3.3
# 2003-03-10 09:00:00 4.000002 2003-03-10 09:00:00 4.4
# 2003-04-16 09:00:00 4.000004 2003-04-16 09:07:00 2.7
# 2003-05-14 09:00:00 4.000002 2003-05-14 09:29:00 6.6
# 2003-06-10 09:00:00 4.0 2003-06-10 09:54:00 14.7
# 2003-07-16 09:00:00 4.0 2003-07-16 09:30:00 4.9
# 2003-08-13 09:00:00 4.0 2003-08-13 08:48:00 5.2
# 2003-09-11 09:00:00 10.256062 2003-09-11 09:18:00 4.5
# 2003-10-15 09:00:00 32.986877 2003-10-15 08:56:00 4.8
# 2003-11-13 09:00:00 4.0 2003-11-13 09:43:00 5.8
# 2003-12-08 09:00:00 4.000021 2003-12-08 09:05:00 11.8
# 2004-01-13 09:00:00 4.000025 2004-01-13 08:55:00 5.8
# 2004-02-09 09:00:00 4.0 2004-02-09 09:33:00 2.7
# 2004-03-08 09:00:00 4.0 2004-03-08 09:06:00 2.2
# 2004-04-12 09:00:00 4.0 2004-04-12 08:47:00 4.8
# 2004-05-10 09:00:00 4.000035 2004-05-10 08:39:00 6.6
# 2004-05-26 12:00:00 53.206375 2004-05-26 12:30:00 65.0
# 2004-06-14 09:00:00 4.000014 2004-06-14 09:10:00 7.4
# 2004-07-12 09:00:00 4.0 2004-07-12 09:01:00 4.0
# 2004-08-09 09:00:00 4.0 2004-08-09 09:33:00 4.2
# 2004-11-08 09:00:00 4.0 2004-11-08 10:15:00 2.7
# 2004-12-06 09:00:00 4.000031 2004-12-06 09:45:00 14.3
# 2005-01-18 09:00:00 4.042511 2005-01-18 09:05:00 11.9
# 2005-02-14 09:00:00 4.000003 2005-02-14 09:04:00 6.4
# 2005-03-14 09:00:00 4.0 2005-03-14 09:30:00 15.3
# 2005-05-09 09:00:00 56.589485 2005-05-09 10:00:00 15.0
# 2005-06-13 09:00:00 4.000023 2005-06-13 08:54:00 8.2
# 2005-07-11 09:00:00 4.000009 2005-07-11 09:21:00 5.1
# 2005-09-12 09:00:00 4.0 2005-09-12 09:16:00 9.0
# 2005-10-10 09:00:00 4.000032 2005-10-10 09:40:00 42.0
# 2005-10-31 09:00:00 76.011986 2005-10-31 09:15:00 29.5
# 2005-11-14 09:00:00 4.000055 2005-11-14 09:50:00 17.3
# 2005-12-12 09:00:00 4.000006 2005-12-12 09:25:00 4.2
# 2006-01-09 09:00:00 5.871324 2006-01-09 09:00:00 15.9
# 2006-02-13 09:00:00 20.101912 2006-02-13 09:20:00 16.4
# 2006-03-13 09:00:00 4.0 2006-03-13 09:04:00 2.4
# 2006-04-10 09:00:00 4.000018 2006-04-10 09:15:00 2.5
# 2006-05-08 09:00:00 4.00001 2006-05-08 08:53:00 5.6
# 2006-06-12 09:00:00 4.000033 2006-06-12 09:19:00 11.8
# 2006-09-11 09:00:00 4.0 2006-09-11 09:10:00 5.5
# 2006-09-18 09:00:00 31.803905 2006-09-18 09:47:00 29.2
# 2006-11-07 09:00:00 4.342024 2006-11-07 09:35:00 25.4
# 2006-11-13 09:00:00 4.413492 2006-11-13 09:28:00 10.8
# 2006-12-11 09:00:00 40.13821 2006-12-11 09:47:00 42.4
# 2007-01-08 09:00:00 4.0001 2007-01-08 09:35:00 5.8
# 2007-01-08 09:00:00 4.0001 2007-01-08 09:41:00 5.5
# 2007-02-05 09:00:00 4.0 2007-02-05 09:38:00 1.9
# 2007-04-02 09:00:00 4.000002 2007-04-02 09:07:00 4.4
# 2007-05-07 09:00:00 4.0 2007-05-07 10:16:00 7.8
# 2007-05-21 09:00:00 18.259662 2007-05-21 10:30:00 23.2
# 2007-06-04 09:00:00 4.000028 2007-06-04 08:24:00 8.8
# 2007-08-06 09:00:00 4.0 2007-08-06 09:50:00 12.9
# 2007-09-04 09:00:00 75.361412 2007-09-04 09:30:00 79.7
# 2007-10-08 09:00:00 4.000018 2007-10-08 10:00:00 4.6
# 2007-11-05 09:00:00 4.0 2007-11-05 09:48:00 2.9
# 2007-12-11 09:00:00 4.003333 2007-12-11 09:15:00 2.76
# 2007-12-11 09:00:00 4.003333 2007-12-11 09:17:00 2.9
# 2008-01-07 09:00:00 4.00004 2008-01-07 09:45:00 5.6
# 2008-02-05 09:00:00 4.000037 2008-02-05 10:17:00 11.2
# 2008-03-03 09:00:00 4.000033 2008-03-03 09:08:00 3.72
# 2008-05-05 09:00:00 4.0 2008-05-05 10:10:00 4.8
# 2008-06-02 09:00:00 4.000028 2008-06-02 09:45:00 9.6
# 2008-06-03 09:00:00 241.698822 2008-06-03 09:39:00 271.0
# 2008-08-04 09:00:00 4.0 2008-08-04 08:31:00 2.9
# 2008-08-20 09:00:00 72.666344 2008-08-20 09:44:00 24.0
# 2008-09-02 09:00:00 4.0 2008-09-02 08:53:00 2.7
# 2008-11-03 09:00:00 6.931245 2008-11-03 09:50:00 16.3

# %% [markdown]
# Compute <b><span style="color:#f00">R<sup>2</sup></span></b> and <b><span style="color:#f00">Nash</span></b> between sim. and obs. flow

# %%
# average of sim
sim_mean= sum(simflowdata[idx_flow][mask_flow])/float(len(simflowdata[idx_flow][mask_flow]))
# average of obs
obs_mean= sum(obsflowdata[mask_flow])/float(len(obsflowdata[mask_flow]))
# total sum of squares 
ss_tot = sum((x-obs_mean)**2 for x in obsflowdata[mask_flow]) 
# sum of squares of residuals
ss_err = sum((y-x)**2 for y,x in zip(simflowdata[idx_flow][mask_flow],obsflowdata[mask_flow]))

nash_flow = 1 - (ss_err/ss_tot)
print "nash_flow= ", nash_flow

gradient, intercept, r_value, p_value, std_err = stats.linregress(simflowdata[idx_flow][mask_flow],obsflowdata[mask_flow])
print "R-squared = ", r_value**2
if gradient <= 1:
  adj_r2 = gradient * (r_value**2)
  print "adj_r2 =", adj_r2
if gradient > 1:
  adj_r2 = gradient**(-1) * (r_value**2)
  print "adj_r2 =", adj_r2
# Out:
# nash_flow=  0.707280454221
# R-squared =  0.793116423151
# adj_r2 = 0.622715267329

# %% [markdown]
# Compute <b><span style="color:#f00">R<sup>2</sup></span></b> between sim. and obs. sediment

# %%
# average of sim
sim_mean= sum(FsimSed)/float(len(FsimSed))

print "sim_mean = ", sim_mean
obs_mean= sum(FobsSed)/float(len(FobsSed))

# total sum of squares 
ss_tot = sum((x-obs_mean)**2 for x in FobsSed) 

# sum of squares of residuals
ss_err = sum((y-x)**2 for y,x in zip(FsimSed,FobsSed))
nash_sed = 1 - (ss_err/ss_tot)
print "nash_sed = ", nash_sed

gradient, intercept, r_value, p_value, std_err = stats.linregress(FsimSed,FobsSed)
r2_sed = r_value**2
print "Sediment R-squared = ", r2_sed
if gradient <= 1:
  adj_r2_sed = gradient * (r_value**2)
  print "adj_r2_sed =", adj_r2_sed
if gradient > 1:
  adj_r2_sed = gradient**(-1) * (r_value**2)
  print "adj_r2_sed =", adj_r2_sed
# Out:
# sim_mean =  15.6734779492
# nash_sed =  0.675830106052
# Sediment R-squared =  0.686063483139
# adj_r2_sed = 0.618351966154

# %% [markdown]
# Compute <b><span style="color:#f00">R<sup>2</sup></span></b> between sim. and obs. coliform

# %%
# average of sim
sim_mean= sum(FsimOther)/float(len(FsimOther))
obs_mean= sum(FobsOther)/float(len(FobsOther))

# total sum of squares 
ss_tot = sum((x-obs_mean)**2 for x in FobsOther) 
# sum of squares of residuals
ss_err = sum((y-x)**2 for y,x in zip(FsimOther,FobsOther))


nash_col = 1 - (ss_err/ss_tot)
print "nash_col= ", nash_col

gradient, intercept, r_value, p_value, std_err = stats.linregress(FsimOther,FobsOther)
r2_col = r_value**2
print "R-squared = ", r2_col
if gradient <= 1:
  adj_r2_col = gradient * (r_value**2)
  print "adj_r2_col =", adj_r2_col
if gradient > 1:
  adj_r2_col = gradient**(-1) * (r_value**2)
  print "adj_r2_col =", adj_r2_col
# Out:
# nash_col=  -0.171276547556
# R-squared =  0.551077611318
# adj_r2_col = 0.041321978827

# %% [markdown]
# Plot the time series of **sim. vs. obs daily streamflows **in cms.

# %%
##############################################################################################
#################################Plot the Discrete Time Series################################
##############################################################################################
# reconstruct the date objects with matching dates only 
fdate=[]
for i in idx_flow:
  if i >=0 :
    fdate.append(datetime.datetime.strptime(tempsimflowdate[i],'%m/%d/%Y'))
ssim = pd.Series(simflowdata[idx_flow][mask_flow], index=fdate)
sobs = pd.Series(obsflowdata[mask_flow], index=fdate)

fig=plt.figure(figsize=(17,5),dpi=400)
ax = plt.subplot()
fig.text(0.7, 0.8, r'$Nash=%.2f$' % nash_flow, fontsize=15)
title('daily streamflow', fontsize=14., y=1.02, fontweight='bold')
plt.ylabel('flow. ($m^{3}\,s^{-1}$)', fontsize=12.)
plt.xlabel('year', fontsize=12.)

# s=square, -=dash, g^=triangle
ssim['2002':'2009'].plot(label='Sim', color='red', linewidth=2.0)
sobs['2002':'2009'].plot(label='Obs',color ='blue')

grid(True)
#tight_layout()
ax.legend(loc='best')
savefig('D:\\Dropbox\\Python_Scripts\\Thornton\\sed.png',dpi=500,format = 'png',transparent='True')

##############################################################################################
#########################################Plot the CDF#########################################
##############################################################################################
fig=plt.figure(figsize=(7,5),dpi=400)
ax = plt.subplot()
n = len(ssim)

# log-normal probability plot
d = np.linspace(1, n, num=n)/(n+1)
y  = norm.ppf(d,0,1);

# create the axis ticks
p  = [0.001, 0.01, 0.05, 0.2, 0.5, 0.75, 0.90, 0.98, 0.999];
# relate var "p" with "y"
tick  = norm.ppf(p,0,1);
label = ['0.001','0.01','0.05','0.2','0.5','0.75','0.90','0.98','0.999'];
# recast the p to (0,1)

# sort the data in an ascending order
ssim.sort()
sobs.sort()
ax.plot(y,ssim, 'r+', label='sim')
ax.plot(y,sobs,'b*', label='obs')

# use numpoints option so the markeres don't appear twice in one legend
ax.legend(loc=(0.05,0.8),numpoints = 1)
plt.ylabel('flow. ($m^{3}\,s^{-1}$)', fontsize=12.)
plt.xlabel('cumulative prob.', fontsize=12.)
ax = gca()
ax.xaxis.set_major_locator(ticker.FixedLocator(tick))
ax.xaxis.set_major_formatter(ticker.FixedFormatter(label))
grid(True)
# save the figure to the folder
savefig('D:\\Dropbox\\Python_Scripts\\Mercer\\sed_cdf.png',dpi=500,format = 'png',transparent='True')

# %% [markdown]
# Plot the time series of **simuted sediment concentrations**.

# %% [markdown]
# Plot the **Sim** vs. **obs** monthly **sediment conc**

# %%
##############################################################################################
#################################Plot the Discrete Time Series################################
##############################################################################################
# reconstruct the date objects with matching dates only 

ssim = pd.Series(FsimSed, index=Fsimdate)
sobs = pd.Series(FobsSed, index=Fobsdate)

fig=plt.figure(figsize=(17,5),dpi=400)
ax = plt.subplot()
fig.text(0.7, 0.8, r'$R^2=%.2f$' % r2_sed, fontsize=15)
title('sediment concentration', fontsize=14., y=1.02, fontweight='bold')
plt.ylabel('conc. (mg/l)', fontsize=12.)
plt.xlabel('year', fontsize=12.)

# s=square, -=dash, g^=triangle
ssim['1999':'2009'].plot(label='Sim', color='red',style='-o',markersize=5, linewidth=2.0)
sobs['1999':'2009'].plot(label='Obs',color ='blue',style='-o',markersize=5)

grid(True)
#tight_layout()
ax.legend(loc='best')
savefig('D:\\Dropbox\\Python_Scripts\\Thornton\\sed.png',dpi=500,format = 'png',transparent='True')

##############################################################################################
#########################################Plot the CDF#########################################
##############################################################################################
fig=plt.figure(figsize=(7,5),dpi=400)
ax = plt.subplot()
n = len(ssim)

# log-normal probability plot
d = np.linspace(1, n, num=n)/(n+1)
y  = norm.ppf(d,0,1);

# create the axis ticks
p  = [0.001, 0.01, 0.05, 0.2, 0.5, 0.75, 0.90, 0.98, 0.999];
# relate var "p" with "y"
tick  = norm.ppf(p,0,1);
label = ['0.001','0.01','0.05','0.2','0.5','0.75','0.90','0.98','0.999'];
# recast the p to (0,1)

# sort the data in an ascending order
ssim.sort()
sobs.sort()
ax.plot(y,ssim, 'r+', label='sim')
ax.plot(y,sobs,'b*', label='obs')

# use numpoints option so the markeres don't appear twice in one legend
ax.legend(loc=(0.05,0.8),numpoints = 1)
plt.ylabel('conc. (mg/l)', fontsize=12.)
plt.xlabel('cumulative prob.', fontsize=12.)
ax = gca()
ax.xaxis.set_major_locator(ticker.FixedLocator(tick))
ax.xaxis.set_major_formatter(ticker.FixedFormatter(label))
grid(True)
# save the figure to the folder
savefig('D:\\Dropbox\\Python_Scripts\\Thornton\\sed_cdf1.png',dpi=500,format = 'png',transparent='True')

# %%
##############################################################################################
#########################################Plot the CDF#########################################
##############################################################################################
fig=plt.figure(figsize=(7,5),dpi=400)
ax = plt.subplot()
n = len(sobs)

# log-normal probability plot
d = np.linspace(1, n, num=n)/(n+1)
y  = norm.ppf(d,0,1);

# create the axis ticks
p  = [0.001, 0.01, 0.05, 0.2, 0.5, 0.75, 0.90, 0.98, 0.999];
# relate var "p" with "y"
tick  = norm.ppf(p,0,1);
label = ['0.001','0.01','0.05','0.2','0.5','0.75','0.90','0.98','0.999'];
# recast the p to (0,1)

sobs.sort()
ax.plot(y,sobs,'b*', label='obs')

n = len(simseddata)
d = np.linspace(1, n, num=n)/(n+1)
y  = norm.ppf(d,0,1);
simseddata.sort()
ax.plot(y,simseddata, 'r+', label='sim')


# use numpoints option so the markeres don't appear twice in one legend
ax.legend(loc=(0.05,0.8),numpoints = 1)
plt.ylabel('conc. (mg/l)', fontsize=12.)
plt.xlabel('cumulative prob.', fontsize=12.)
ax = gca()
ax.xaxis.set_major_locator(ticker.FixedLocator(tick))
ax.xaxis.set_major_formatter(ticker.FixedFormatter(label))
grid(True)
# save the figure to the folder
savefig('D:\\Dropbox\\Python_Scripts\\Thornton\\sed_cdf2.png',dpi=500,format = 'png',transparent='True')

# %% [markdown]
# Plot the **Sim** vs. **obs** monthly **coliform conc**

# %%
##############################################################################################
#################################Plot the Discrete Time Series################################
##############################################################################################

ssim = pd.Series(FsimOther, index=Fsimdate)
sobs = pd.Series(FobsOther, index=Fobsdate)

fig=plt.figure(figsize=(17,5),dpi=400)
ax = plt.subplot()
fig.text(0.7, 0.8, r'$R^2=%.2f$' % r2_col, fontsize=15)
title('coliform concentration', fontsize=14., y=1.02, fontweight='bold')
plt.ylabel('conc. (mg/l)', fontsize=12.)
plt.xlabel('year', fontsize=12.)

# s=square, -=dash, g^=triangle
ssim['1999':'2008'].plot(label='Sim', color='red', linewidth=2.0)
sobs['1999':'2008'].plot(label='Obs',color ='blue',style='-o',markersize=5)

grid(True)
#tight_layout()
ax.legend(loc='best')
savefig('D:\\Dropbox\\Python_Scripts\\Thornton\\coliform.png',dpi=500,format = 'png',transparent='True')

##############################################################################################
##############################################################################################
#########################################Plot the CDF#########################################
##############################################################################################
fig=plt.figure(figsize=(7,5),dpi=400)
ax = plt.subplot()
n = len(ssim)

# log-normal probability plot
d = np.linspace(1, n, num=n)/(n+1)
y  = norm.ppf(d,0,1);

# create the axis ticks
p  = [0.001, 0.01, 0.05, 0.2, 0.5, 0.75, 0.90, 0.98, 0.999];
# relate var "p" with "y"
tick  = norm.ppf(p,0,1);
label = ['0.001','0.01','0.05','0.2','0.5','0.75','0.90','0.98','0.999'];
# recast the p to (0,1)

# sort the data in an ascending order
ssim.sort()
sobs.sort()
ax.plot(y,ssim, 'r+', label='sim')
ax.plot(y,sobs,'b*', label='obs')

# use numpoints option so the markeres don't appear twice in one legend
ax.legend(loc=(0.05,0.8),numpoints = 1)
plt.ylabel('conc. (mg/l)', fontsize=12.)
plt.xlabel('cumulative prob.', fontsize=12.)
ax = gca()
ax.xaxis.set_major_locator(ticker.FixedLocator(tick))
ax.xaxis.set_major_formatter(ticker.FixedFormatter(label))
grid(True)
# save the figure to the folder
savefig('D:\\Dropbox\\Python_Scripts\\Thornton\\coliform_cdf1.png',dpi=500,format = 'png',transparent='True')

# %%
##############################################################################################
#########################################Plot the CDF#########################################
##############################################################################################
fig=plt.figure(figsize=(7,5),dpi=400)
ax = plt.subplot()
n = len(sobs)

# log-normal probability plot
d = np.linspace(1, n, num=n)/(n+1)
y  = norm.ppf(d,0,1);

# create the axis ticks
p  = [0.001, 0.01, 0.05, 0.2, 0.5, 0.75, 0.90, 0.98, 0.999];
# relate var "p" with "y"
tick  = norm.ppf(p,0,1);
label = ['0.001','0.01','0.05','0.2','0.5','0.75','0.90','0.98','0.999'];
# recast the p to (0,1)

sobs.sort()
ax.plot(y,sobs,'b*', label='obs')

n = len(simotherdata)
d = np.linspace(1, n, num=n)/(n+1)
y  = norm.ppf(d,0,1);
simotherdata.sort()
ax.plot(y,simotherdata, 'r+', label='sim')


# use numpoints option so the markeres don't appear twice in one legend
ax.legend(loc=(0.05,0.8),numpoints = 1)
plt.ylabel('conc. (mg/l)', fontsize=12.)
plt.xlabel('cumulative prob.', fontsize=12.)
ax = gca()
ax.xaxis.set_major_locator(ticker.FixedLocator(tick))
ax.xaxis.set_major_formatter(ticker.FixedFormatter(label))
grid(True)
# save the figure to the folder
savefig('D:\\Dropbox\\Python_Scripts\\Thornton\\sed_cdf2.png',dpi=500,format = 'png',transparent='True')
