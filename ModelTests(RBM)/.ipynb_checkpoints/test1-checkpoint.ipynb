# %% [markdown]
# ###This notebook includes Python scripts used for model tests.###
# ###<font color='purple'>Test 1: The model is updated with variable riparian veg parameter from segment to segment.</font>###

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['norm']
# `%matplotlib` prevents importing * from pylab and numpy

# %% [markdown]
# <font color='blue'>**First, import all necessary libraries.**</font>

# %%
# Import all needed libraries 
import sys, os, datetime, time
import collections
import numpy as np
import pandas as pd
import numpy.ma as ma
import math
import matplotlib.dates as dates
import matplotlib.ticker as ticker
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
from scipy.stats import norm
from scipy import stats

import os
os.getcwd() 
os.chdir("D:\\ModelUpdateTests\\test1\\")
os.getcwd()
# Out:
# 'D:\\ModelUpdateTests\\test1'

# %% [markdown]
# <font color='blue'>**Edit the figure properties**</font>

# %%
import matplotlib as mpl
mpl.rcParams['lines.linewidth'] = 2
font = {'family' : 'sans-serif',
        'sans-serif' : 'Verdana',
        'weight' : 'medium',
        'size'   : '12'}
params1 = {
          'axes.labelsize': 12,
          'text.fontsize': 12,
          'xtick.labelsize': 12,
          'xtick.direction': 'out',
          'ytick.labelsize': 12,
          'legend.pad': 0.1,     # empty space around the legend box
          'legend.fontsize': 12,
          'font.size': 12,
          'font.style': 'normal',
          'axes.style': 'normal',
          'xtick.labelstyle': 'normal',
          'legend.fontsize' : 12
          }
mpl.RcParams.update(params1)
mpl.rc('font', **font)
plt.rc("xtick", direction="out")
plt.rc("ytick", direction="out")

# %% [markdown]
# **<font color='blue'>Read the NSW.Only files from old and new model versions. <br>
# <span style="background-color: #FFFF00">Test-A setup: In the new model version, use same riparian veg parameter values for all segments. This setting should produce same energy terms as the old version.</span></font>**

# %%
mainpath = []
oldvpath = []
newvpath = []
old_NSW = []
new_NSW = []
date = []
fdate = []

mainpath = 'D:\\ModelUpdateTests\\test1\\'
oldvpath = str(mainpath)+'\\NSW-old.Only'
newvpath = str(mainpath)+'\\NSW-new.Only'

# use the NSW data for Seg 51
n = 50
old_NSW = np.genfromtxt(oldvpath, dtype=float, skiprows=2, usecols=[n])
new_NSW = np.genfromtxt(newvpath, dtype=float, skiprows=2, usecols=[n])
date = np.genfromtxt(oldvpath, dtype=str, skiprows=2, usecols=[0])

# Convert the string format dates into a datetime object
for i in range(len(date)):
    fdate.append(datetime.datetime.strptime(date[i], '%m.%d.%Y-%H:%M:%S'))

# %%
old = []
new = []
    
old = pd.Series(old_NSW, index=fdate)
new = pd.Series(new_NSW, index=fdate)

# %% [markdown]
# <font color='blue'>**Scatterplot of NSW @ Seg.** </font>

# %%
plt.scatter(old, new)
a = old.max()
b = old.min()
plt.xlim([a, b])
plt.ylim([a, b])
# Out:
# (412.91000000000003, 0.0)

# %% [markdown]
# <font color='blue'>**Plot the time series of NSW @ Seg.** </font>

# %%
fig = plt.figure(figsize=(12, 3), dpi=400)
plt.title('NSW comparison at segment %s' % str(n))
old.plot(label='new', color='red', linewidth=2.)
new.plot(label='orig', color='blue', linewidth=2.)
grid(True)
    
  
outputfilepath = 'D:\\Dropbox\\Python_Scripts\\daily_flow.png'    
savefig(str(outputfilepath),dpi=500,format = 'png',transparent='True')

# %% [markdown]
# <font color='blue'>
# <span style="background-color: #FFFF00">Test-B setup: In the new model version, use **NO** riparian veg parameter values for segments with ID from 1-10. This setting should produce greater energy terms as the old version for Seg 1-10.</span></font>
