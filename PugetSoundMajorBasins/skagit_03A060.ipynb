# %%
import matplotlib.pyplot as plt
from matplotlib.finance import quotes_historical_yahoo
from matplotlib.dates import YearLocator, MonthLocator, DateFormatter
import numpy as np
import pandas as pd
import datetime as dt
from matplotlib.dates import date2num, num2date 
from matplotlib.pyplot import figure, show
from matplotlib import scale as mscale
from matplotlib import transforms as mtransforms
import pylab
import matplotlib
import os
# %matplotlib inline
#import scikits.timeseries as ts
#import scikits.timeseries.lib.plotlib as tpl

os.chdir('D:\\trash\\SkagitData\\')
filepath='1.txt'
#dates = dt.datetime.strptime("07/27/2012","%m/%d/%Y")
#print dates

data = np.loadtxt(filepath)
data1 = np.genfromtxt(filepath,dtype='int')
year = data1[:,0]
month = data1[:,1]
day = data1[:,2]
sim = data[:,3]
obs = data[:,4]
time=np.zeros([data.shape[0],1])
#print len(time)
#print len(sim)
for i in range(0,data.shape[0]):
    a= year[i]
    b= month[i]
    c= day[i]
    d = dt.date(a,b,c)
    time[i] = date2num(d)
    i+=1
time1=np.arange(data.shape[0])
#series = ts.fill_missing_dates(sim)

y1=sim
y2=obs
x=time

fig,(ax,ax6) = plt.subplots(1, 2, sharey=True,figsize=(14,6))
#ax0 = fig.add_subplot(111)

# plot the same data on both axes

ax.plot_date(x, y1, 'r')
ax6.plot_date(x, y1, 'r',label='Sim')
ax.plot_date(x, y2, 'b')
ax6.plot_date(x, y2, 'b',label='Obs')

# zoom-in / limit the view to different portions of the data
datase = np.genfromtxt('date_tmp03A060.txt',dtype='int')
yearse = datase[:,0]
monthse = datase[:,1]
dayse = datase[:,2]
timese=np.zeros([datase.shape[0],1])
for i in range(0,datase.shape[0]):
    a= yearse[i]
    b= monthse[i]
    c= dayse[i]
    d = dt.date(a,b,c)
    timese[i] = date2num(d)
    i+=1
ax.set_xlim(timese[0],timese[1])  
ax6.set_xlim(timese[2],timese[3])
# hide the spines between ax and ax2

ax.spines['right'].set_visible(False)
ax6.spines['left'].set_visible(False)

ax.yaxis.tick_left()
ax.tick_params(labeltop='off') # don't put tick labels at the top
#for ax in [ax2, ax3, ax4, ax5]:
    #plt.step(ax2.get_yticklabels()[-1], visible=False)
    #ax.set_yticks([])
ax6.yaxis.tick_right()
    
# Make the spacing between the two axes a bit smaller
plt.subplots_adjust(wspace=0.05)

d = .015 # how big to make the diagonal lines in axes coordinates
# arguments to pass plot, just so we don't keep repeating them
kwargs = dict(transform=ax.transAxes, color='k', clip_on=False)
ax.plot((1-d,1+d),(-d,+d), **kwargs) # top-left diagonal
ax.plot((1-d,1+d),(1-d,1+d), **kwargs) # bottom-left diagonal

kwargs.update(transform=ax6.transAxes) # switch to the bottom axes
ax6.plot((-d,d),(-d,+d), **kwargs) # top-right diagonal
ax6.plot((-d,d),(1-d,1+d), **kwargs) # bottom-right diagonal

plt.gcf().autofmt_xdate()
#locator = AutoDateLocator()
#locator.intervald[MONTHLY]=[1]
#locator = MonthLocator(interval=2)
#fig, ax = plt.subplots()
#ax.plot(time,sim,'r', label='Sim')
#ax.plot(time,obs,'b', label='Obs')
legend = ax6.legend(loc='upper right', shadow=True)
##ax.set_xlim(0,270)

fig.suptitle('Daily Water Temperature of Skagit (03A060)',fontsize=20)

#plt.locator_params(nbins=4)
start1, end1 = ax.get_xlim()
ax.xaxis.set_ticks(np.arange(start1, end1,15))
start6, end6 = ax6.get_xlim()
ax6.xaxis.set_ticks(np.arange(start6, end6, 15))

pylab.ylim([10,22])
ax.set_xlabel('time (day)',fontsize=18, x=1, y=0)
ax.set_ylabel('Water Temperature (degC)',fontsize=18)
matplotlib.rc('xtick', labelsize=14)
matplotlib.rc('ytick', labelsize=14)

bias=np.sum(abs(sim-obs))/data.shape[0]
tempr1=0
tempr2=0
tempr3=0
for i in range(0,data.shape[0]):
    tempr1+=(sim[i]-np.mean(sim))*(obs[i]-np.mean(obs))
    tempr2+=(sim[i]-np.mean(sim))**2
    tempr3+=(obs[i]-np.mean(obs))**2
    i+=1
R2=(tempr1/((tempr2*tempr3)**0.5))**2
RMSE=(sum((sim-obs)**2)/data.shape[0])**0.5
#print x
print bias,R2,RMSE
bias_1="{:.2f}".format(bias)
R2_1="{:.2f}".format(R2)
RMSE_1="{:.2f}".format(RMSE)
ax.text(731758,21,'$R^2= $'+str(R2_1),fontsize=14)
ax.text(731758,20.3,'$RMSE= $'+str(RMSE_1),fontsize=14)
ax.text(731758,19.6,'$Bias= $'+str(bias_1),fontsize=14)
#savefig('1.png',dpi=75)
#plt.show()
# Out:
# 1.19979228395 0.502796388532 1.43907995227

# %%
import matplotlib.pyplot as plt
from matplotlib.finance import quotes_historical_yahoo
from matplotlib.dates import YearLocator, MonthLocator, DateFormatter
import numpy as np
import pandas as pd
import datetime as dt
from matplotlib.dates import date2num, num2date 
from matplotlib.pyplot import figure, show
from matplotlib import scale as mscale
from matplotlib import transforms as mtransforms
import pylab
import matplotlib
import os
# %matplotlib inline
#import scikits.timeseries as ts
#import scikits.timeseries.lib.plotlib as tpl

os.chdir('D:\\trash\\SkagitData\\')
filepath='2.txt'
#dates = dt.datetime.strptime("07/27/2012","%m/%d/%Y")
#print dates

data = np.loadtxt(filepath)
data1 = np.genfromtxt(filepath,dtype='int')
year = data1[:,0]
month = data1[:,1]
day = data1[:,2]
sim = data[:,4]
obs = data[:,5]
time=np.zeros([data.shape[0],1])
#print len(time)
#print len(sim)
for i in range(0,data.shape[0]):
    a= year[i]
    b= month[i]
    c= day[i]
    d = dt.date(a,b,c)
    time[i] = date2num(d)
    i+=1
time1=np.arange(data.shape[0])
#series = ts.fill_missing_dates(sim)

y1=sim
y2=obs
x=time

fig,(ax,ax6) = plt.subplots(1, 2, sharey=True,figsize=(14,6))
#ax0 = fig.add_subplot(111)

# plot the same data on both axes

ax.plot_date(x, y1, 'r')
ax6.plot_date(x, y1, 'r',label='Sim')
ax.plot_date(x, y2, 'b')
ax6.plot_date(x, y2, 'b',label='Obs')

# zoom-in / limit the view to different portions of the data
datase = np.genfromtxt('date_tmp03A060.txt',dtype='int')
yearse = datase[:,0]
monthse = datase[:,1]
dayse = datase[:,2]
timese=np.zeros([datase.shape[0],1])
for i in range(0,datase.shape[0]):
    a= yearse[i]
    b= monthse[i]
    c= dayse[i]
    d = dt.date(a,b,c)
    timese[i] = date2num(d)
    i+=1
ax.set_xlim(timese[0],timese[1])  
ax6.set_xlim(timese[2],timese[3])
# hide the spines between ax and ax2

ax.spines['right'].set_visible(False)
ax6.spines['left'].set_visible(False)

ax.yaxis.tick_left()
ax.tick_params(labeltop='off') # don't put tick labels at the top
#for ax in [ax2, ax3, ax4, ax5]:
    #plt.step(ax2.get_yticklabels()[-1], visible=False)
    #ax.set_yticks([])
ax6.yaxis.tick_right()
    
# Make the spacing between the two axes a bit smaller
plt.subplots_adjust(wspace=0.05)

d = .015 # how big to make the diagonal lines in axes coordinates
# arguments to pass plot, just so we don't keep repeating them
kwargs = dict(transform=ax.transAxes, color='k', clip_on=False)
ax.plot((1-d,1+d),(-d,+d), **kwargs) # top-left diagonal
ax.plot((1-d,1+d),(1-d,1+d), **kwargs) # bottom-left diagonal

kwargs.update(transform=ax6.transAxes) # switch to the bottom axes
ax6.plot((-d,d),(-d,+d), **kwargs) # top-right diagonal
ax6.plot((-d,d),(1-d,1+d), **kwargs) # bottom-right diagonal

plt.gcf().autofmt_xdate()
#locator = AutoDateLocator()
#locator.intervald[MONTHLY]=[1]
#locator = MonthLocator(interval=2)
#fig, ax = plt.subplots()
#ax.plot(time,sim,'r', label='Sim')
#ax.plot(time,obs,'b', label='Obs')
legend = ax6.legend(loc='upper right', shadow=True)
##ax.set_xlim(0,270)

fig.suptitle('Daily Water Temperature of Skagit (03A060)',fontsize=20)

#plt.locator_params(nbins=4)
start1, end1 = ax.get_xlim()
ax.xaxis.set_ticks(np.arange(start1, end1,15))
start6, end6 = ax6.get_xlim()
ax6.xaxis.set_ticks(np.arange(start6, end6, 15))

pylab.ylim([9.5,22])
ax.set_xlabel('time (day)',fontsize=18, x=1, y=0)
ax.set_ylabel('Water Temperature (degC)',fontsize=18)
matplotlib.rc('xtick', labelsize=14)
matplotlib.rc('ytick', labelsize=14)

bias=np.sum(abs(sim-obs))/data.shape[0]
tempr1=0
tempr2=0
tempr3=0
for i in range(0,data.shape[0]):
    tempr1+=(sim[i]-np.mean(sim))*(obs[i]-np.mean(obs))
    tempr2+=(sim[i]-np.mean(sim))**2
    tempr3+=(obs[i]-np.mean(obs))**2
    i+=1
R2=(tempr1/((tempr2*tempr3)**0.5))**2
RMSE=(sum((sim-obs)**2)/data.shape[0])**0.5
#print x
print bias,R2,RMSE
bias_1="{:.2f}".format(bias)
R2_1="{:.2f}".format(R2)
RMSE_1="{:.2f}".format(RMSE)
ax.text(731758,21,'$R^2= $'+str(R2_1),fontsize=14)
ax.text(731758,20.3,'$RMSE= $'+str(RMSE_1),fontsize=14)
ax.text(731758,19.6,'$Bias= $'+str(bias_1),fontsize=14)
#savefig('1.png',dpi=75)
#plt.show()
# Out:
# 1.2868571048 0.453060231121 1.55845145091
