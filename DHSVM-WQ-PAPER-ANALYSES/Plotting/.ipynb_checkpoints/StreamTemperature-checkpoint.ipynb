# %% [markdown]
# ###This notebook includes Python tools for plotting stream temperature simulations

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['norm']
# `%matplotlib` prevents importing * from pylab and numpy

# %% [markdown]
# <font color='blue'>**First, import all necessary libraries.**</font>

# %%
# Import all needed libraries 
import sys, os, datetime, time
import collections
import numpy as np
import pandas as pd
import numpy.ma as ma
import math
import matplotlib.dates as dates
import matplotlib.ticker as ticker
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
from scipy.stats import norm
from scipy import stats

import os
os.getcwd() 
os.chdir("D:\\Dropbox\\Python_Scripts")
os.getcwd()
# Out:
# 'D:\\Dropbox\\Python_Scripts'

# %% [markdown]
# <font color='blue'>**Edit the figure properties**</font>

# %%
import matplotlib as mpl
mpl.rcParams['lines.linewidth'] = 2
font = {'family' : 'sans-serif',
        'sans-serif' : 'Verdana',
        'weight' : 'medium',
        'size'   : '12'}
params1 = {
          'axes.labelsize': 12,
          'text.fontsize': 12,
          'xtick.labelsize': 12,
          'xtick.direction': 'out',
          'ytick.labelsize': 12,
          'legend.pad': 0.01,     # empty space around the legend box
          'legend.fontsize': 12,
          'legend.labelspacing':0.25,
          'font.size': 12,
          'font.style': 'normal',
          'axes.style': 'normal',
          'xtick.labelstyle': 'normal',
          }
mpl.RcParams.update(params1)
mpl.rc('font', **font)
plt.rc("xtick", direction="out")
plt.rc("ytick", direction="out")
plt.rc('legend',**{'fontsize':12})

# %% [markdown]
# **<font color='blue'>Read the input streamflow files (change the path if needed)<br></font>
# <span style="background-color: #FFFF00"><span style="color:#f00">Attention?</span></span>**

# %%
basin_name = ['Thornton', 'Mercer', 'Issaquah']
mainpath = {}
simtemperaturepath = {}
obstemperaturepath = {}

for i, n in enumerate(basin_name):
    mainpath[n] = 'D:\\Dropbox\\Python_Scripts\\'+str(basin_name[i])+'\\water_temp\\'
    simtemperaturepath[n] = str(mainpath[n])+'\\sim2.txt'
    obstemperaturepath[n] = str(mainpath[n])+'\\obs2.txt'

# %% [markdown]
# **<font color='blue'>Read the data in. </font>**

# %%
simtempdata = {}
obstempdata = {}
tempsimdate = {}
tempobsdate = {}

# Read flow sim and obs dates &  data
for i, n in enumerate(basin_name):
    simtempdata[n] = np.genfromtxt(simtemperaturepath[n], usecols=[1])
    obstempdata[n] = np.genfromtxt(obstemperaturepath[n], usecols=[1])
    tempsimdate[n] = np.genfromtxt(simtemperaturepath[n], dtype=str, skiprows=0, usecols=0)
    tempobsdate[n] = np.genfromtxt(obstemperaturepath[n], dtype=str, skiprows=0, usecols =0)

# %% [markdown]
# <font color='blue'>**Sort and match the obs. and sim. flow files based on dates.**<br></font>

# %%
# Convert the string format dates into a datetime object
simdate = collections.defaultdict(list)

for i, n in enumerate(basin_name):
    for j in range(len(tempsimdate[n])):
        simdate[n].append(datetime.datetime.strptime(tempsimdate[n][j],'%m/%d/%Y-%H:%M'))
# sort the dates in an acending order
for i, n in enumerate(basin_name):
    simdate[n].sort()

# Convert the string format dates into a datetime object
obsdate = collections.defaultdict(list)
for i, n in enumerate(basin_name):
    for j in range(len(tempobsdate[n])):
        obsdate[n].append(datetime.datetime.strptime(tempobsdate[n][j],'%m/%d/%Y-%H:%M'))
for i, n in enumerate(basin_name):
    obsdate[n].sort()

# %%
Fsimdate = collections.defaultdict(list)
Fobsdate = collections.defaultdict(list)
FsimTemp = collections.defaultdict(list)
FobsTemp = collections.defaultdict(list)

for j, n in enumerate(basin_name):
    for i in range(len(obsdate[n])):
        obs = dates.date2num(obsdate[n][i])
        junk = date2num(simdate[n])
        idx = (np.abs(junk-obs)).argmin()
        if (idx-1 > 0 and (idx+1)< len(simdate[n])):
            Fsimdate[n].append(simdate[n][idx])
            Fobsdate[n].append(obsdate[n][i])
            FsimTemp[n].append(simtempdata[n][idx])
            FobsTemp[n].append(obstempdata[n][i])

# %% [markdown]
# <font color='blue'>**Compute PBIAS and NSE.** </font>

# %%
PBias = {}
Bias = {}
print "Bias then PBias:"
for i, n in enumerate(basin_name):
    PBias[n] = sum((x-y) for x, y in zip(FsimTemp[n], FobsTemp[n]))/sum(x for x in FsimTemp[n]) 
    Bias[n] = sum((x-y) for x, y in zip(FsimTemp[n], FobsTemp[n]))/len(FsimTemp[n]) 
    print str(n), Bias[n], PBias[n]

R2 = {}
print "\nNash:"
for i, n in enumerate(basin_name):
    obs_mean= sum(FobsTemp[n])/float(len(FobsTemp[n]))
    ss_tot = sum((x-obs_mean)**2 for x in FobsTemp[n]) 
    ss_err = sum((y-x)**2 for y, x in zip(FsimTemp[n], FobsTemp[n]))
    R2[n] = 1 - ss_err/ss_tot
    print str(n), R2[n]
# Out:
# Bias then PBias:
# Thornton -0.25355704698 -0.0231369631052
# Mercer 0.158514056225 0.0148413029664
# Issaquah -0.185362903226 -0.0190211769379
#
# Nash:
# Thornton 0.91724668295
# Mercer 0.860325989464
# Issaquah 0.93899744582

# %% [markdown]
# <font color='blue'>**Plot the time series of sim. vs. obs daily streamflows in cms.** </font>

# %%
junk = []
for i in range(len(FsimTemp['Mercer'])):
    if (Fsimdate['Mercer'][i].year==2008 and Fsimdate['Mercer'][i].month==8):
        FsimTemp['Mercer'][i]+=0
    junk.append(datetime.datetime.strftime(Fsimdate['Mercer'][i],'%m/%d/%Y-%H:%M'))
    # print junk[i], FsimTemp['Mercer'][i]
# Out:
# 01/12/1993-09:00 3.29
# 01/20/1993-15:00 6.66
# 02/16/1993-09:00 3.52
# 03/09/1993-09:00 8.18
# 03/22/1993-12:00 11.27
# 04/13/1993-09:00 9.19
# 05/11/1993-09:00 13.47
# 06/15/1993-09:00 15.38
# 07/13/1993-09:00 14.61
# 08/10/1993-09:00 15.43
# 09/21/1993-09:00 10.65
# 10/12/1993-09:00 12.88
# 11/16/1993-09:00 8.25
# 12/13/1993-12:00 8.16
# 12/21/1993-09:00 7.02
# 01/19/1994-09:00 6.41
# 02/15/1994-12:00 7.8
# 02/23/1994-09:00 5.23
# 03/15/1994-09:00 9.16
# 04/12/1994-09:00 10.05
# 05/17/1994-09:00 13.19
# 06/21/1994-09:00 14.98
# 07/12/1994-09:00 15.0
# 08/08/1994-09:00 15.12
# 08/08/1994-09:00 15.12
# 09/20/1994-09:00 14.26
# 10/11/1994-09:00 10.81
# 10/26/1994-12:00 12.42
# 11/08/1994-00:00 7.56
# 11/08/1994-09:00 8.02
# 08/16/2006-15:00 16.14
# 09/13/2006-12:00 12.33
# 09/19/2006-09:00 11.62
# 10/11/2006-12:00 12.43
# 11/07/2006-09:00 12.86
# 11/15/2006-12:00 9.25
# 12/13/2006-00:00 7.35
# 01/10/2007-12:00 4.65
# 02/07/2007-12:00 9.89
# 03/07/2007-12:00 10.86
# 04/04/2007-12:00 11.32
# 05/09/2007-12:00 12.33
# 05/21/2007-15:00 12.93
# 06/06/2007-12:00 13.8
# 07/05/2007-12:00 15.53
# 08/08/2007-15:00 16.67
# 09/05/2007-12:00 15.35
# 10/10/2007-15:00 11.08
# 11/07/2007-12:00 12.12
# 11/07/2007-12:00 12.12
# 12/03/2007-09:00 5.83
# 12/12/2007-12:00 8.71
# 01/09/2008-12:00 5.65
# 02/06/2008-15:00 6.24
# 03/05/2008-15:00 9.0
# 04/09/2008-15:00 9.49
# 05/07/2008-15:00 10.26
# 06/03/2008-09:00 12.09
# 06/12/2008-15:00 12.24
# 07/09/2008-15:00 15.21
# 08/06/2008-15:00 17.16
# 08/20/2008-09:00 17.62
# 09/04/2008-12:00 13.56
# 09/04/2008-15:00 12.58
# 10/08/2008-12:00 12.3
# 11/05/2008-12:00 10.13
# 12/03/2008-12:00 10.14

# %%
ssim = {}
sobs = {}
for i, n in enumerate(basin_name):
    ssim[n] = pd.Series(FsimTemp[n], index=Fsimdate[n])
    sobs[n] = pd.Series(FobsTemp[n], index=Fobsdate[n])
    
fig=plt.figure(figsize=(8, 12),dpi=400)
for i, n in enumerate(basin_name):
    ax = plt.subplot(3, 1, i+1)
    # add spacing between subplots
    fig.subplots_adjust(hspace=0.3, wspace=0.1, bottom=0.2)
    
    props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
    plt.text(0.99, 0.01, str(n), color='blue', transform=ax.transAxes, verticalalignment='bottom', horizontalalignment='right')
    
    ssim[n].plot(label='Sim', color='red', linewidth=2.0)
    sobs[n].plot(label='Obs',color ='black', linewidth=2.0)
    
    if (n == 'Mercer'):
        textstr1 = '$Bias = 0.16$$^\circ$$C$'% Bias[n] 
    else:
        textstr1 = '$Bias = %.2f$$^\circ$$C$'% Bias[n] 
    #textstr1 = '$NSE = %.2f$'% R2[n] 
    plt.text(0.015, 0.95, textstr1, fontsize=14, transform=ax.transAxes, verticalalignment='top', horizontalalignment='left',bbox=props)
  
    grid(True)
    if (i == 0):
        leg = plt.legend(fancybox=True, loc='upper right')
        leg.get_frame().set_alpha(0.5)
      
    plt.ylabel('Temperature ($^\circ$$C$)', fontsize=12.)
    
    if (n == 'Mercer'):
        plt.ylim([0., 22])
    if (n == 'Thornton'):
        plt.ylim([0, 25])
    if (n == 'Issaquah'):
        plt.ylim([0, 20])
        ax.set_xlabel("year")
        
    # force all axis label placed horizontally
    plt.setp(ax.xaxis.get_majorticklabels(), rotation='horizontal')
    
    # set ticker properties
    ax.xaxis.set_tick_params(width=1, length=5)
    ax.get_xaxis().tick_bottom()
    
    # plt.tight_layout()
    
outputfilepath = 'D:\\Box Sync\\WQ-PAPER\\Figures\\WaterTemperature.png'    
savefig(str(outputfilepath),dpi=500,format = 'png',transparent='True')
