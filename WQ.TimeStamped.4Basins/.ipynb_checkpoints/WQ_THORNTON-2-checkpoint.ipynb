# %% [markdown]
# ###This notebook includes Python tools for analyzing DHSVM outputs.
# Time series data are analyzed with **numpy** and **pandas** tools and plotted with **matplotlib**. Spatial maps are analyzed and plotted using **netCDF4** and **Basemap** utilities. In general, the scripts that needs to be changed (eg. file path, locations, time range, and variables to plot, etc) are on top of the coding block if there's any. However, differences in the input data may require changing the code, such as which columns to read as the dates, how many rows to skip as the header, etc. Currently all input file paths are absolute paths so you should be able to run the code as it is and plot from my output files. All plots are saved into a pdf page (specify the file name in the second code block). Note that you'll have to run the last code block to close the pdf file you opened in order to view the file correctly.

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# **First**, import all necessary libraries.

# %%
# Import all needed libraries 
import sys, os, datetime, time
import numpy as np
import pandas as pd
import numpy.ma as ma
import math
import matplotlib.dates as dates
import matplotlib.ticker as ticker
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
from scipy.stats import norm
from scipy import stats

import os
os.getcwd() 
os.chdir("D:\\Dropbox\\Python_Scripts")
os.getcwd()
# Out:
# 'D:\\Dropbox\\Python_Scripts'

# %% [markdown]
# Read the input **streamflow** files (change the path if needed)<br>
# <span style="background-color: #FFFF00">**<span style="color:#f00">Attention</span>**: the last date in obs. file **MUST NOT** exceed the last date of sim.</span>

# %%
# Enter file path for sim. and obs. flow files
simflowpath = 'D:\\Dropbox\\Python_Scripts\\Thornton\\daily_flow.txt'
obsflowpath = 'D:\\Dropbox\\Python_Scripts\\Thornton\\streamflow.12128000.cms.1945_2008.txt'

# Read flow sim and obs dates &  data
simflowdata = np.genfromtxt(simflowpath, usecols=[1])
obsflowdata = np.genfromtxt(obsflowpath, usecols=[1])
tempsimflowdate = np.genfromtxt(simflowpath, dtype = str, skiprows = 0, usecols = 0)
tempobsflowdate = np.genfromtxt(obsflowpath, dtype = str, skiprows = 0, usecols = 0)

# %% [markdown]
# **Sort** and **match** the obs. and sim. flow files based on dates.<br>

# %%
# Convert the string format dates into a datetime object
simflowdate = []
for i in range(len(tempsimflowdate)):
    simflowdate.append(datetime.datetime.strptime(tempsimflowdate[i],'%m/%d/%Y'))
# sort the dates in an acending order
simflowdate.sort()

# Convert the string format dates into a datetime object
obsflowdate = []
for i in range(len(tempobsflowdate)):
    obsflowdate.append(datetime.datetime.strptime(tempobsflowdate[i],'%Y-%m-%d'))
# sort the dates in an acending order
obsflowdate.sort()

# extract the matching dates from both arrays and mark them by mask
# searchsorted(t1,t2) finds index in t1 for every value in t2:    
idx_flow = np.searchsorted(simflowdate, obsflowdate, side='right')-1
j2 = [i for i in idx_flow if i > 0]

# mask the array as true if 
mask_flow = idx_flow >=0

# compare the obs. and sim. time series
df = pd.DataFrame({"simflowdate":tempsimflowdate[idx_flow][mask_flow], "simflow":simflowdata[idx_flow][mask_flow], \
                   "obsflow":obsflowdata[mask_flow], "obsflowdate":tempobsflowdate[mask_flow]})

#print df
#print df.values

# %% [markdown]
# Read the input **water quality**files (change the path if needed)<br>
# <span style="background-color: #FFFF00">**<span style="color:#f00">Attention</span>**: the last date in obs. file **MUST NOT** exceed the last date of sim.</span>

# %%
# Initialize a pdf file for saving all the figures
# pdfpages = PdfPages('test_figure.pdf')

# Enter file path for swater quality simulation files
simsedfilepath = 'D:\\Dropbox\\Python_Scripts\\Thornton\\Sed.Flow.Only'
simotherfilepath = 'D:\\Dropbox\\Python_Scripts\\Thornton\\Other.Conc.Only'

# Enter file path for observed water quality variable files
obsfilepath = 'D:\\Dropbox\\Python_Scripts\\Thornton\\thornton-time-stamped.txt'

# Enter file path for observed precipitation files
precipfilepath = 'D:\\Dropbox\\Python_Scripts\\Thornton\\Mass.Balance'

# Read dates of sims (continuous)
tempsimdates = np.genfromtxt(simsedfilepath, dtype=str, skiprows=2, usecols=0)

# Read dates of obs (discrete). Use the 2nd column
tempobsdates = np.genfromtxt(obsfilepath, dtype=str, skiprows=1, usecols=0)

# Read sediment sims (use the 2nd col)
simseddata = np.genfromtxt(simsedfilepath, skiprows=2, usecols=[2])
simseddata = simseddata + 3.4
# Read sediment obs.
# Skip the first line, and use the 5th column for sed
obsseddata = np.genfromtxt(obsfilepath, dtype=float, skiprows=1, usecols=[2])

# Read other data
simotherdata = np.genfromtxt(simotherfilepath, skiprows=2, usecols=[1])
simotherdata = (simotherdata + 1)/0.01444
obsotherdata = np.genfromtxt(obsfilepath, dtype=float, skiprows=1, usecols=[1])
obsotherdata = obsotherdata

# Read obs. precipitation data
precipdata = np.genfromtxt(precipfilepath, dtype=float, skiprows=24, usecols=[9])
print len(precipdata)


# Read TP data
simOrgPfilepath = 'D:\\Dropbox\\Python_Scripts\\Thornton\\OrgP.Conc.Only'
simOrgnPdata = np.genfromtxt(simOrgPfilepath, skiprows=2, usecols=[1])
simSolPfilepath = 'D:\\Dropbox\\Python_Scripts\\Thornton\\solP.Conc.Only'
simSolPdata = np.genfromtxt(simSolPfilepath, skiprows=2, usecols=[1])
simTPdata = simOrgnPdata + simSolPdata
obsTPdata = np.genfromtxt(obsfilepath, dtype=float, skiprows=1, usecols=[6])
# Out:
# 73048

# %% [markdown]
# **Third**, find out the dates when both sims and obs (discontinous) are available.
#
# <span style="background-color: #FFFF00">**Particular attention** needs to be paid on **<span style="color:#f00">np.searchsorted()</span>**. </span>

# %%
#######dates###########
simdates = []
Fsimdate = []
Fobsdate = []
########sediment#######
FsimSed = []
FsimSedPre = []
FsimSedPost = []
FobsSed = []
########coliform#######
FsimOther = []
FsimOtherPre = []
FsimOtherPost = []
FobsOther = []
######phosphorous######
FsimTP = []
FsimTPPre = []
FsimTPPost = []
FobsTP = []
#######################

# construct the sim. date obj.
for i in range(len(tempsimdates)):
    simdates.append(datetime.datetime.strptime(tempsimdates[i],'%m/%d/%Y-%H:%M:%S'))
simdates.sort()
# construct the obs. date obj.
obsdates = []
for i in range(len(tempobsdates)):
    obsdates.append(datetime.datetime.strptime(tempobsdates[i],'%m/%d/%Y-%H:%M:%S'))
obsdates.sort()


for i in range(len(obsdates)):
    obs = dates.date2num(obsdates[i])
    junk = date2num(simdates)
    #value = obsdates[i]
    idx = (np.abs(junk-obs)).argmin()
    if (idx-1 > 0 and (idx+1)< len(simdates)):
      Fsimdate.append(simdates[idx])
      Fobsdate.append(obsdates[i])
      #
      FsimSed.append(simseddata[idx])
      FsimSedPre.append(simseddata[idx-1])
      FsimSedPost.append(simseddata[idx+1])
      FobsSed.append(obsseddata[i])
      #
      FobsOther.append(obsotherdata[i])
      FsimOther.append(simotherdata[idx])
      FsimOtherPre.append(simotherdata[idx-1])
      FsimOtherPost.append(simotherdata[idx+1])
      #
      FobsTP.append(obsTPdata[i])
      FsimTP.append(simTPdata[idx])
      FsimTPPre.append(simTPdata[idx-1])
      FsimTPPost.append(simTPdata[idx+1])


#for i in range(len(FsimSed)):
    #print Fsimdate[i], FsimSed[i], FsimSedPre[i], FsimSedPost[i], Fobsdate[i], FobsSed[i]
    #print Fsimdate[i], FsimOther[i], FsimOtherPre[i], FsimOtherPost[i], Fobsdate[i], FobsOther[i]
    #print Fsimdate[i], FsimTP[i], Fobsdate[i], FobsTP[i]

# %% [markdown]
# Compute <b><span style="color:#f00">R<sup>2</sup></span></b> and <b><span style="color:#f00">Nash</span></b> between sim. and obs. flow

# %%
# average of sim
sim_mean= sum(simflowdata[idx_flow][mask_flow])/float(len(simflowdata[idx_flow][mask_flow]))
# average of obs
obs_mean= sum(obsflowdata[mask_flow])/float(len(obsflowdata[mask_flow]))
# total sum of squares 
ss_tot = sum((x-obs_mean)**2 for x in obsflowdata[mask_flow]) 
# sum of squares of residuals
ss_err = sum((y-x)**2 for y,x in zip(simflowdata[idx_flow][mask_flow],obsflowdata[mask_flow]))

nash_flow = 1 - (ss_err/ss_tot)
print "nash_flow= ", nash_flow

gradient, intercept, r_value, p_value, std_err = stats.linregress(simflowdata[idx_flow][mask_flow],obsflowdata[mask_flow])
print "R-squared = ", r_value**2
if gradient <= 1:
  adj_r2 = gradient * (r_value**2)
  print "adj_r2 =", adj_r2
if gradient > 1:
  adj_r2 = gradient**(-1) * (r_value**2)
  print "adj_r2 =", adj_r2
# Out:
# nash_flow=  0.331752570194
# R-squared =  0.527241891273
# adj_r2 = 0.332102756097

# %% [markdown]
# Compute <b><span style="color:#f00">R<sup>2</sup></span></b> between sim. and obs. sediment

# %%
# average of sim
sim_mean= sum(FsimSed)/float(len(FsimSed))

print "sim_mean = ", sim_mean
obs_mean= sum(FobsSed)/float(len(FobsSed))

# total sum of squares 
ss_tot = sum((x-obs_mean)**2 for x in FobsSed) 

# sum of squares of residuals
ss_err = sum((y-x)**2 for y,x in zip(FsimSed,FobsSed))
nash_sed = 1 - (ss_err/ss_tot)
print "nash_sed = ", nash_sed

gradient, intercept, r_value, p_value, std_err = stats.linregress(FsimSed,FobsSed)
r2_sed = r_value**2
print "Sediment R-squared = ", r2_sed
if gradient <= 1:
  adj_r2_sed = gradient * (r_value**2)
  print "adj_r2_sed =", adj_r2_sed
if gradient > 1:
  adj_r2_sed = gradient**(-1) * (r_value**2)
  print "adj_r2_sed =", adj_r2_sed
# Out:
# sim_mean =  11.3164094476
# nash_sed =  0.621338315815
# Sediment R-squared =  0.727789337638
# adj_r2_sed = 0.49953934331

# %% [markdown]
# Compute <b><span style="color:#f00">R<sup>2</sup></span></b> between sim. and obs. coliform

# %%
# average of sim
sim_mean= sum(FsimOther)/float(len(FsimOther))
obs_mean= sum(FobsOther)/float(len(FobsOther))

# total sum of squares 
ss_tot = sum((x-obs_mean)**2 for x in FobsOther) 
# sum of squares of residuals
ss_err = sum((y-x)**2 for y,x in zip(FsimOther,FobsOther))


nash_col = 1 - (ss_err/ss_tot)
print "nash_col= ", nash_col

gradient, intercept, r_value, p_value, std_err = stats.linregress(FsimOther,FobsOther)
r2_col = r_value**2
print "R-squared = ", r2_col
if gradient <= 1:
  adj_r2_col = gradient * (r_value**2)
  print "adj_r2_col =", adj_r2_col
if gradient > 1:
  adj_r2_col = gradient**(-1) * (r_value**2)
  print "adj_r2_col =", adj_r2_col
# Out:
# nash_col=  0.436418973541
# R-squared =  0.469333884518
# adj_r2_col = 0.397279238228

# %% [markdown]
# Compute <b><span style="color:#f00">R<sup>2</sup></span></b> between sim. and obs. Total Phosphorous

# %%
sim_mean= sum(FsimTP)/float(len(FsimTP))
obs_mean= sum(FobsTP)/float(len(FobsTP))

# total sum of squares 
ss_tot = sum((x-obs_mean)**2 for x in FobsTP) 
# sum of squares of residuals
ss_err = sum((y-x)**2 for y,x in zip(FsimTP,FobsTP))

nash_TP = 1 - (ss_err/ss_tot)
print "nash_TP= ", nash_TP

gradient, intercept, r_value, p_value, std_err = stats.linregress(FsimTP, FobsTP)
r2_TP = r_value**2
print "R-squared = ", r2_TP
if gradient <= 1:
  adj_r2_TP = gradient * (r_value**2)
  print "adj_r2_TP =", adj_r2_TP
if gradient > 1:
  adj_r2_TP = gradient**(-1) * (r_value**2)
  print "adj_r2_TP =", adj_r2_TP
# Out:
# nash_TP=  0.460324718372
# R-squared =  0.568816085491
# adj_r2_TP = 0.429545566542

# %% [markdown]
# Plot the time series of **sim. vs. obs daily streamflows **in cms.

# %%
##############################################################################################
#################################Plot the Discrete Time Series################################
##############################################################################################
# reconstruct the date objects with matching dates only 
fdate=[]
for i in idx_flow:
  if i >=0 :
    fdate.append(datetime.datetime.strptime(tempsimflowdate[i],'%m/%d/%Y'))
ssim = pd.Series(simflowdata[idx_flow][mask_flow], index=fdate)
sobs = pd.Series(obsflowdata[mask_flow], index=fdate)

fig=plt.figure(figsize=(17,5),dpi=400)
ax = plt.subplot()
fig.text(0.7, 0.8, r'$Nash=%.2f$' % nash_flow, fontsize=15)
title('daily streamflow', fontsize=14., y=1.02, fontweight='bold')
plt.ylabel('flow. ($m^{3}\,s^{-1}$)', fontsize=12.)
plt.xlabel('year', fontsize=12.)

# s=square, -=dash, g^=triangle
ssim['2002':'2009'].plot(label='Sim', color='red', linewidth=2.0)
sobs['2002':'2009'].plot(label='Obs',color ='blue')

grid(True)
#tight_layout()
ax.legend(loc='best')
#savefig('D:\\Dropbox\\Python_Scripts\\Thornton\\flow.png',dpi=500,format = 'png',transparent='True')

##############################################################################################
#########################################Plot the CDF#########################################
##############################################################################################
fig=plt.figure(figsize=(7,5),dpi=400)
ax = plt.subplot()
n = len(ssim)

# log-normal probability plot
d = np.linspace(1, n, num=n)/(n+1)
y  = norm.ppf(d,0,1);

# create the axis ticks
p  = [0.001, 0.01, 0.05, 0.2, 0.5, 0.75, 0.90, 0.98, 0.999];
# relate var "p" with "y"
tick  = norm.ppf(p,0,1);
label = ['0.001','0.01','0.05','0.2','0.5','0.75','0.90','0.98','0.999'];
# recast the p to (0,1)

# sort the data in an ascending order
ssim.sort()
sobs.sort()
ax.plot(y,ssim, 'r+', label='sim')
ax.plot(y,sobs,'b*', label='obs')

# use numpoints option so the markeres don't appear twice in one legend
ax.legend(loc=(0.05,0.8),numpoints = 1)
plt.ylabel('flow. ($m^{3}\,s^{-1}$)', fontsize=12.)
plt.xlabel('cumulative prob.', fontsize=12.)
ax = gca()
ax.xaxis.set_major_locator(ticker.FixedLocator(tick))
ax.xaxis.set_major_formatter(ticker.FixedFormatter(label))
grid(True)
# save the figure to the folder
#savefig('D:\\Dropbox\\Python_Scripts\\Thornton\\flow_cdf.png',dpi=500,format = 'png',transparent='True')

# %% [markdown]
# Plot the time series of **simuted sediment concentrations**.

# %%
# find out the element-wise min and max among three series
a = pd.DataFrame([FsimSedPost, FsimSed, FsimSedPre]).min()
LowerBand = pd.Series(a.values, index=Fsimdate)
b = pd.DataFrame([FsimSedPost, FsimSed, FsimSedPre]).max()
UpperBand = pd.Series(b.values, index=Fsimdate)
sobs = pd.Series(FobsSed, index=Fsimdate)

BandWidth= pd.concat([UpperBand, LowerBand, sobs],  axis=1)
band = BandWidth.sort(column=0, ascending=False)
print band

n = len(band[1])
# log-normal probability plot
d = np.linspace(1, n, num=n)/(n+1)
y  = norm.ppf(d,0,1);
rd = pd.DataFrame(y)
y2 = rd[0].quantile(1.0)

fig=plt.figure(figsize=(12,5),dpi=400)
ax = plt.subplot()
fill_between(y, band[1],band[0], facecolor='grey', interpolate=True)
# log transform y
plot(y, band[2], 'o')

# create the axis ticks
p  = [0.05, 0.15, 0.3, 0.5, 0.75, 0.90, 0.98, 0.999];
# relate var "p" with "y"
tick  = norm.ppf(p,0,1);
label = ['0.05','0.15','0.3','0.5','0.75','0.90','0.98','0.999'];
# recast the p to (0,1)
ax = gca()
ax.xaxis.set_major_locator(ticker.FixedLocator(tick))
ax.xaxis.set_major_formatter(ticker.FixedFormatter(label))

# only plot the 50% percentile
pylab.xlim([min(y), y2])
plt.ylabel('conc. (mg/l)', fontsize=12.)
plt.xlabel('cumulative prob.', fontsize=12.)
# Out:
#                               0          1       2
# 2007-12-02 06:00:00  343.614081  81.195502  273.00
# 2008-06-03 09:00:00  320.565527  88.848616  294.00
# 1993-03-22 09:00:00  177.548422  59.260794  170.00
# 2010-08-31 12:00:00  153.204504  76.765791  102.00
# 2000-02-01 06:00:00  114.872519  24.497322  117.00
# 2002-11-12 06:00:00  114.797545  76.587836  149.00
# 2000-06-12 12:00:00  114.723555  52.881659   80.00
# 1997-10-29 09:00:00  112.064665  40.072913   52.30
# 1998-05-27 12:00:00  110.747382  45.229330   38.00
# 2010-11-01 09:00:00  109.728506  50.762141  114.00
# 2010-01-04 09:00:00  108.136687  41.146914   89.60
# 2001-06-11 12:00:00  101.352202  42.423968   54.90
# 2010-04-21 12:00:00   98.002882  31.852335   40.00
# 2004-05-26 09:00:00   84.666327  17.035368   65.00
# 2009-05-05 12:00:00   83.267249  31.212824   85.60
# 2001-11-14 09:00:00   82.599684  40.987162   42.60
# 2001-05-14 12:00:00   78.149016  24.025490   22.50
# 2002-03-11 09:00:00   73.665335  21.928250   56.00
# 1999-06-24 15:00:00   71.559889  37.446761   44.00
# 2000-11-08 15:00:00   71.185095  32.897873   33.40
# 2005-05-09 12:00:00   70.440413  19.987883   15.00
# 1993-01-20 06:00:00   68.240546  42.899844   54.00
# 1994-11-30 12:00:00   64.181338  34.423954   54.00
# 2007-09-04 09:00:00   62.197581   9.042287   79.70
# 1997-12-16 12:00:00   60.080607  22.725731   20.20
# 1999-11-09 15:00:00   55.396334  32.901875   36.30
# 2005-10-31 15:00:00   53.063361  28.407158   29.50
# 2008-08-20 12:00:00   48.791365  32.282492   24.00
# 2010-09-08 09:00:00   46.141337   6.109529   58.10
# 2006-12-11 09:00:00   42.627673  23.578190   42.40
# 1998-10-12 09:00:00   40.908522   9.441912  108.00
# 2000-03-13 09:00:00   39.912066   7.289964    2.70
# 1995-05-02 09:00:00   39.040533   8.148451  170.00
# 1996-11-12 12:00:00   38.907198   7.832400   33.20
# 2010-03-11 12:00:00   35.599253   7.776111   18.30
# 1998-01-05 09:00:00   35.066616  22.649439   49.20
# 1995-02-14 18:00:00   34.130045   4.549201    9.00
# 2006-09-18 09:00:00   33.806898   6.189800   29.20
# 1995-10-16 09:00:00   33.374592  10.237346   35.00
# 1999-02-24 12:00:00   29.375927  12.035985   29.20
# 1997-03-18 09:00:00   28.192690  17.047180   29.50
# 2000-02-29 12:00:00   27.294596   8.566445   38.40
# 1999-03-08 09:00:00   26.976479   4.400136   10.40
# 2003-10-15 09:00:00   26.073641   6.024194    4.80
# 2013-01-08 09:00:00   26.032160   9.962753   18.80
# 1995-03-09 09:00:00   25.947106   9.686070   25.00
# 2000-10-09 09:00:00   25.480326   5.781736    8.00
# 1999-02-08 09:00:00   24.578965   4.401379   15.40
# 2000-02-14 09:00:00   22.910618   8.899541    5.20
# 2000-01-10 09:00:00   20.152207   4.426395    5.20
# 1994-10-31 09:00:00   19.865496  10.933576   23.00
# 2008-10-06 09:00:00   19.627703   6.650663    2.90
# 2010-06-08 09:00:00   16.806888   4.703036    4.32
# 2010-05-03 09:00:00   12.100890   4.655187    8.20
# 2011-05-02 09:00:00   11.107359   4.664072   27.10
# 2006-02-13 09:00:00   10.166365   5.594978   16.40
# 1994-02-15 09:00:00    9.437624   6.177558   28.00
# 2007-05-21 09:00:00    8.683962   6.463892   23.20
# 1996-04-01 09:00:00    8.277511   6.388933   78.00
# 1998-01-14 09:00:00    7.934373   6.923516   88.00
#                             ...        ...     ...
#
# [286 rows x 3 columns]

# %% [markdown]
# ## Plot the **Sim** vs. **obs** monthly **coliform conc**

# %%
# find out the element-wise min and max among three series
a = pd.DataFrame([FsimOtherPost, FsimOther, FsimOtherPre]).min()
LowerBand = pd.Series(a.values, index=Fsimdate)
b = pd.DataFrame([FsimOtherPost, FsimOther, FsimOtherPre]).max()
UpperBand = pd.Series(b.values, index=Fsimdate)
sobs = pd.Series(FobsOther, index=Fsimdate)

BandWidth= pd.concat([UpperBand, LowerBand, sobs],  axis=1)
band = BandWidth.sort(column=0, ascending=False)
print band

n = len(band[1])
# log-normal probability plot
d = np.linspace(1, n, num=n)/(n+1)
y  = norm.ppf(d,0,1);
rd = pd.DataFrame(y)
y2 = rd[0].quantile(1.0)

fig=plt.figure(figsize=(12,5),dpi=400)
ax = plt.subplot()
fill_between(y, band[1], band[0], facecolor='grey', interpolate=True)
plot(y, band[2], 'o')

# create the axis ticks
p  = [0.001, 0.01, 0.05, 0.2, 0.5, 0.75, 0.90, 0.98, 0.999];
# relate var "p" with "y"
tick  = norm.ppf(p,0,1);
label = ['0.001','0.01','0.05','0.2','0.5','0.75','0.90','0.98','0.999'];
# recast the p to (0,1)
ax = gca()
ax.xaxis.set_major_locator(ticker.FixedLocator(tick))
ax.xaxis.set_major_formatter(ticker.FixedFormatter(label))

# only plot the 50% percentile
pylab.xlim([min(y), y2])
plt.ylabel('conc. (mg/l)', fontsize=12.)
plt.xlabel('cumulative prob.', fontsize=12.)
# Out:
#                                 0            1      2
# 2008-06-03 09:00:00  11150.144529  7358.800970  12000
# 2010-08-31 12:00:00   9614.576731  7799.945845   8600
# 2007-09-04 09:00:00   7400.868837  5993.431510  10000
# 1998-09-18 15:00:00   7142.497576  5023.672022   9000
# 1993-03-22 09:00:00   6475.935734  4870.382479   2200
# 2001-06-11 12:00:00   6251.782133  4649.532687   5400
# 2000-10-09 09:00:00   6153.544183  5073.911427    640
# 2001-10-08 09:00:00   6006.958380  5736.594598   2800
# 1993-11-15 09:00:00   5919.838504  4785.800831    220
# 2007-12-02 06:00:00   5876.760942  4817.444321  12000
# 2008-08-20 12:00:00   5706.705194  5256.252355  10000
# 2002-11-12 06:00:00   5545.230956  5301.174861   3000
# 2001-05-14 12:00:00   5533.976593  4530.228255   5700
# 2003-10-15 09:00:00   5427.645845  4976.260457   1400
# 2006-09-18 09:00:00   5352.990859  4577.536357   4500
# 2008-10-06 09:00:00   5347.765443  4655.974307    380
# 1998-10-12 09:00:00   5261.019668  4799.938435   4600
# 2003-09-11 09:00:00   5240.795983  4628.065235   1200
# 2010-04-21 12:00:00   5228.395014  4204.004848   2700
# 2010-09-08 09:00:00   5102.112188  4582.843075   3200
# 2000-06-12 12:00:00   5045.367729  4256.080956  16000
# 2004-05-26 09:00:00   4965.653255  4560.018837   5000
# 2000-11-08 15:00:00   4944.360180  4055.926177   2500
# 1999-06-24 15:00:00   4902.298130  4068.779640  10000
# 1997-10-29 09:00:00   4560.078047  3973.311011   7700
# 2009-05-05 12:00:00   4300.045637  3699.919806   2500
# 2005-05-09 12:00:00   4217.085249  3517.005055   1000
# 1998-05-27 12:00:00   4138.991967  3593.229778   3800
# 2007-05-21 09:00:00   4122.688089  3700.598199   4000
# 1999-11-09 15:00:00   4122.126731  3381.037812   4300
# 2010-11-01 09:00:00   4079.147992  3382.625970   3500
# 1995-10-16 09:00:00   4059.213019  3452.283864   3300
# 2001-11-14 09:00:00   4005.839751  3114.865166   2100
# 1994-10-31 09:00:00   3936.142798  3727.504778   3300
# 1993-01-20 06:00:00   3779.888158  3564.439127   1200
# 1997-12-16 12:00:00   3749.109072  3272.783033   2000
# 1995-02-14 18:00:00   3516.078047   276.388781    250
# 2005-10-31 15:00:00   3506.546607  3157.370222   2300
# 1996-11-12 12:00:00   3478.010596  2979.953255   5100
# 2002-03-11 09:00:00   3243.550139  2805.481094   2100
# 2010-01-04 09:00:00   3146.050346  2705.342382   1200
# 1994-02-15 09:00:00   3066.459695  2971.084903    910
# 2010-03-11 12:00:00   3024.816413  2552.116205    510
# 2008-11-03 09:00:00   2973.359211  2964.706648    700
# 1994-11-30 12:00:00   2920.432341  2495.901177   2500
# 2013-12-02 12:00:00   2919.544737  2265.034903    310
# 1998-01-05 09:00:00   2909.458518  2721.938158   1600
# 2010-05-03 09:00:00   2858.835042  2544.808864    560
# 1998-10-28 12:00:00   2839.210249  2444.071814   6100
# 1995-05-02 09:00:00   2641.440097  2386.376039   7600
# 1996-04-01 09:00:00   2585.813435  2334.849654   2500
# 2004-09-13 09:00:00   2321.971607  2109.115720   3600
# 2010-06-08 09:00:00   2234.413504  1990.045152    240
# 2011-05-02 09:00:00   2219.852493  1954.886288    360
# 1995-06-12 09:00:00   2200.559349  1765.511011    590
# 1995-03-09 09:00:00   2171.951662  1990.821260   3200
# 2000-03-13 09:00:00   2158.765859  1858.248823     68
# 2000-02-29 12:00:00   2155.452008  1890.623407   1400
# 2000-02-01 06:00:00   2147.342382  2021.401247   1000
# 1997-03-18 09:00:00   2121.179155  1678.614058   2200
#                               ...          ...    ...
#
# [286 rows x 3 columns]

# %%
##############################################################################################
#########################################Plot the CDF#########################################
##############################################################################################
fig=plt.figure(figsize=(7,5),dpi=400)
ax = plt.subplot()
n = len(sobs)

# log-normal probability plot
d = np.linspace(1, n, num=n)/(n+1)
y  = norm.ppf(d,0,1);

# create the axis ticks
p  = [0.001, 0.01, 0.05, 0.2, 0.5, 0.75, 0.90, 0.98, 0.999];
# relate var "p" with "y"
tick  = norm.ppf(p,0,1);
label = ['0.001','0.01','0.05','0.2','0.5','0.75','0.90','0.98','0.999'];
# recast the p to (0,1)

sobs.sort()
ax.plot(y,sobs,'b*', label='obs')

n = len(simotherdata)
d = np.linspace(1, n, num=n)/(n+1)
y  = norm.ppf(d,0,1);
simotherdata.sort()
ax.plot(y,simotherdata, 'r+', label='sim')


# use numpoints option so the markeres don't appear twice in one legend
ax.legend(loc=(0.05,0.8),numpoints = 1)
plt.ylabel('conc. (mg/l)', fontsize=12.)
plt.xlabel('cumulative prob.', fontsize=12.)
ax = gca()
ax.xaxis.set_major_locator(ticker.FixedLocator(tick))
ax.xaxis.set_major_formatter(ticker.FixedFormatter(label))
grid(True)
# save the figure to the folder
savefig('D:\\Dropbox\\Python_Scripts\\Thornton\\sed_cdf2.png',dpi=500,format = 'png',transparent='True')

# %% [markdown]
# Plot the time series of **total phosphorous concentrations**.

# %%
ssim = pd.Series(FsimTP, index=Fsimdate)
sobs = pd.Series(FobsTP, index=Fobsdate)

fig=plt.figure(figsize=(17,5),dpi=400)
ax = plt.subplot()
fig.text(0.7, 0.8, r'$R^2=%.2f$' % r2_TP, fontsize=16)
fig.text(0.87, 0.85, "A", fontsize=18)
title('TP concentration', fontsize=14., y=1.05, fontweight='bold')
plt.ylabel('conc. (mg/l)', fontsize=14.)
plt.xlabel('year', fontsize=14.)
plt.tick_params(axis='both', which='major', labelsize=14)

# s=square, -=dash, g^=triangle
ssim['1999':'2009'].plot(label='Sim', color='red')
sobs['1999':'2009'].plot(label='Obs',color ='blue',style='-o',fontsize=14,markersize=3)

# find out the element-wise min and max among three series
a = FsimTP - pd.DataFrame([FsimTPPost, FsimTP, FsimTPPre]).min()
b = pd.DataFrame([FsimTPPost, FsimTP, FsimTPPre]).max() - FsimTP

# shaded uncertainty envelope plotting
#fill_between(Fsimdate, a, b, facecolor='grey', interpolate=True)

# uncertainty plot plotting
#errorbar(Fsimdate, FsimSed, yerr=[a, b], fmt='o', ecolor='g', capthick=2)

grid(True)
#tight_layout()
ax.legend(loc='best')
plt.show()
savefig('D:\\Dropbox\\Python_Scripts\\Thornton\\TP.png',dpi=500,format = 'png',transparent='True')
