# %% [markdown]
# ###This notebook includes Python tools for analyzing DHSVM outputs.
# Time series data are analyzed with **numpy** and **pandas** tools and plotted with **matplotlib**. Spatial maps are analyzed and plotted using **netCDF4** and **Basemap** utilities. In general, the scripts that needs to be changed (eg. file path, locations, time range, and variables to plot, etc) are on top of the coding block if there's any. However, differences in the input data may require changing the code, such as which columns to read as the dates, how many rows to skip as the header, etc. Currently all input file paths are absolute paths so you should be able to run the code as it is and plot from my output files. All plots are saved into a pdf page (specify the file name in the second code block). Note that you'll have to run the last code block to close the pdf file you opened in order to view the file correctly.

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['norm', 'gradient']
# `%matplotlib` prevents importing * from pylab and numpy

# %% [markdown]
# **First**, import all necessary libraries.

# %%
# Import all needed libraries 
import sys, os, datetime, time
import numpy as np
import pandas as pd
import numpy.ma as ma
import math
import matplotlib.dates as dates
import matplotlib.ticker as ticker
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
from scipy.stats import norm
from scipy import stats

import os
os.getcwd() 
os.chdir("D:\\Dropbox\\Python_Scripts")
os.getcwd()
# Out:
# 'D:\\Dropbox\\Python_Scripts'

# %% [markdown]
# Read the input **streamflow** files (change the path if needed)<br>
# <span style="background-color: #FFFF00">**<span style="color:#f00">Attention</span>**: the last date in obs. file **MUST NOT** exceed the last date of sim.</span>

# %%
# Enter file path for sim. and obs. flow files
simflowpath = 'D:\\Dropbox\\Python_Scripts\\Issaquah\\daily_flow.txt'
obsflowpath = 'D:\\Dropbox\\Python_Scripts\\Issaquah\\streamflow.12121600.cms.1999_2009.txt'

# Read flow sim and obs dates &  data
simflowdata = np.genfromtxt(simflowpath, usecols=[1])
obsflowdata = np.genfromtxt(obsflowpath, usecols=[1])
tempsimflowdate = np.genfromtxt(simflowpath, dtype = str, skiprows = 0, usecols = 0)
tempobsflowdate = np.genfromtxt(obsflowpath, dtype = str, skiprows = 0, usecols = 0)

# %% [markdown]
# **Sort** and **match** the obs. and sim. flow files based on dates.<br>

# %%
# Convert the string format dates into a datetime object
simflowdate = []
for i in range(len(tempsimflowdate)):
    simflowdate.append(datetime.datetime.strptime(tempsimflowdate[i],'%m/%d/%Y'))
# sort the dates in an acending order
simflowdate.sort()

# Convert the string format dates into a datetime object
obsflowdate = []
for i in range(len(tempobsflowdate)):
    obsflowdate.append(datetime.datetime.strptime(tempobsflowdate[i],'%Y-%m-%d'))
# sort the dates in an acending order
obsflowdate.sort()

# extract the matching dates from both arrays and mark them by mask
# searchsorted(t1,t2) finds index in t1 for every value in t2:    
idx_flow = np.searchsorted(simflowdate, obsflowdate, side='right')-1
j2 = [i for i in idx_flow if i > 0]

# mask the array as true if 
mask_flow = idx_flow >=0

# compare the obs. and sim. time series
df = pd.DataFrame({"simflowdate":tempsimflowdate[idx_flow][mask_flow], "simflow":simflowdata[idx_flow][mask_flow], \
                   "obsflow":obsflowdata[mask_flow], "obsflowdate":tempobsflowdate[mask_flow]})

#print df
#print df.values

# %% [markdown]
# Read the input **water quality**files (change the path if needed)<br>
# <span style="background-color: #FFFF00">**<span style="color:#f00">Attention</span>**: the last date in obs. file **MUST NOT** exceed the last date of sim.</span>

# %%
# Initialize a pdf file for saving all the figures
# pdfpages = PdfPages('test_figure.pdf')

# Enter file path for swater quality simulation files
simsedfilepath = 'D:\\Dropbox\\Python_Scripts\\Issaquah\\Sed.Flow.Only'
simotherfilepath = 'D:\\Dropbox\\Python_Scripts\\Issaquah\\Other.Conc.Only'

# Enter file path for observed water quality variable files
obsfilepath = 'D:\\Dropbox\\Python_Scripts\\Issaquah\\issaquah-time-stamped.txt'

# Enter file path for observed precipitation files
precipfilepath = 'D:\\Dropbox\\Python_Scripts\\Issaquah\\Mass.Balance'

# Read dates of sims (continuous)
tempsimdates = np.genfromtxt(simsedfilepath, dtype=str, skiprows=2, usecols=0)

# Read dates of obs (discrete). Use the 2nd column
tempobsdates = np.genfromtxt(obsfilepath, dtype=str, skiprows=1, usecols=0)

# Read sediment sims (use the 2nd col)
simseddata = np.genfromtxt(simsedfilepath, skiprows=2, usecols=[2])
simseddata = simseddata + 4
# Read sediment obs.
# Skip the first line, and use the 5th column for sed
obsseddata = np.genfromtxt(obsfilepath, dtype=float, skiprows=1, usecols=[2])

# Read other data
simotherdata = np.genfromtxt(simotherfilepath, skiprows=2, usecols=[1])
print len(simotherdata)
#print simotherdata
obsotherdata = np.genfromtxt(obsfilepath, dtype=float, skiprows=1, usecols=[1])
obsotherdata = obsotherdata * 0.01444 + 0.6;

# Read obs. precipitation data
precipdata = np.genfromtxt(precipfilepath, dtype=float, skiprows=24, usecols=[9])
print len(precipdata)
# Out:
# 35800
# 35800

# %% [markdown]
# **Third**, find out the dates when both sims and obs (discontinous) are available.
#
# <span style="background-color: #FFFF00">**Particular attention** needs to be paid on **<span style="color:#f00">np.searchsorted()</span>**. Output all matching columns to make sure its the right match. Right now, the option **side='right'** must be used in the case of **daily time step (mm/dd/yy)** to avoid the 1-day mismatch. Later when working with **3-hourly set**, this may not hold.</span>

# %%
simdates = []
Fsimdate = []
Fobsdate = []
FsimSed = []
FobsSed = []
FsimOther = []
FobsOther = []
Fpcp = []

# construct the sim. date obj.
for i in range(len(tempsimdates)):
    simdates.append(datetime.datetime.strptime(tempsimdates[i],'%m/%d/%Y-%H:%M:%S'))
simdates.sort()
# construct the obs. date obj.
obsdates = []
for i in range(len(tempobsdates)):
    obsdates.append(datetime.datetime.strptime(tempobsdates[i],'%m/%d/%Y-%H:%M:%S'))
obsdates.sort()

for i in range(len(obsdates)):
    obs = date2num(obsdates[i])
    junk = date2num(simdates)
    #value = obsdates[i]
    idx = (np.abs(junk-obs)).argmin()
    if (idx > 0):
      Fsimdate.append(simdates[idx])
      Fobsdate.append(obsdates[i])
      FsimSed.append(simseddata[idx])
      FobsSed.append(obsseddata[i])
      FobsOther.append(obsotherdata[i])
      FsimOther.append(simotherdata[idx])
      Fpcp.append(precipdata[idx])

for i in range(len(FsimSed)):
    #print Fsimdate[i], FsimSed[i], Fobsdate[i], FobsSed[i]
    print Fsimdate[i], FsimOther[i], Fobsdate[i], FobsOther[i]
    
print min(FobsSed)
# Out:
# 2000-01-12 12:00:00 1.336203 2000-01-12 10:50:00 1.33644
# 2000-02-01 12:00:00 11.4966 2000-02-01 11:50:00 6.9536
# 2000-02-15 12:00:00 4.772109 2000-02-15 11:02:00 1.1054
# 2000-02-29 12:00:00 2.897192 2000-02-29 12:10:00 1.19204
# 2000-03-14 12:00:00 7.790555 2000-03-14 10:38:00 1.35088
# 2000-04-11 12:00:00 0.004777 2000-04-11 12:01:00 2.1884
# 2000-05-09 00:00:00 0.52757 2000-05-09 01:10:00 13.596
# 2000-06-12 12:00:00 11.256111 2000-06-12 12:00:00 39.588
# 2000-08-01 12:00:00 0.0 2000-08-01 12:20:00 3.1992
# 2000-09-12 12:00:00 0.0 2000-09-12 10:36:00 2.9104
# 2000-09-12 12:00:00 0.0 2000-09-12 10:40:00 2.3328
# 2000-10-10 12:00:00 21.355387 2000-10-10 11:07:00 9.986
# 2000-11-14 09:00:00 0.002003 2000-11-14 10:20:00 1.72632
# 2000-12-12 09:00:00 0.002096 2000-12-12 09:35:00 2.1884
# 2001-01-09 12:00:00 1.166678 2001-01-09 11:45:00 1.19204
# 2001-01-09 12:00:00 1.166678 2001-01-09 11:47:00 1.33644
# 2001-02-13 12:00:00 0.002968 2001-02-13 11:14:00 1.00432
# 2001-03-06 12:00:00 0.000581 2001-03-06 11:30:00 1.04764
# 2001-04-10 09:00:00 13.743578 2001-04-10 10:22:00 1.49528
# 2001-04-30 12:00:00 10.897496 2001-04-30 12:19:00 29.48
# 2001-05-15 09:00:00 10.620606 2001-05-15 10:10:00 10.4192
# 2001-06-11 12:00:00 26.18354 2001-06-11 12:29:00 32.368
# 2001-07-10 12:00:00 0.0 2001-07-10 11:26:00 3.0548
# 2001-07-10 12:00:00 0.0 2001-07-10 11:28:00 2.6216
# 2001-08-14 12:00:00 0.0 2001-08-14 11:45:00 2.9104
# 2001-09-11 12:00:00 0.0 2001-09-11 11:40:00 2.9104
# 2001-10-09 12:00:00 10.11912 2001-10-09 10:55:00 4.7876
# 2001-11-15 12:00:00 1.091111 2001-11-15 13:00:00 32.368
# 2001-12-11 12:00:00 0.159617 2001-12-11 11:26:00 1.06208
# 2002-01-15 09:00:00 0.004594 2002-01-15 10:13:00 0.78772
# 2002-02-12 09:00:00 0.003102 2002-02-12 10:19:00 0.84548
# 2002-03-11 12:00:00 12.381887 2002-03-11 12:15:00 5.2208
# 2002-04-09 09:00:00 9.900249 2002-04-09 10:20:00 1.3942
# 2002-05-14 12:00:00 5.32081 2002-05-14 10:50:00 1.63968
# 2002-06-12 12:00:00 0.001255 2002-06-12 11:53:00 1.69744
# 2002-07-09 09:00:00 0.001396 2002-07-09 09:30:00 2.766
# 2002-08-12 09:00:00 0.0 2002-08-12 09:21:00 3.0548
# 2002-10-15 09:00:00 0.0 2002-10-15 10:13:00 1.2498
# 2002-11-12 12:00:00 26.71244 2002-11-12 11:54:00 9.4084
# 2002-12-09 09:00:00 3.270505 2002-12-09 09:55:00 1.65412
# 2003-01-14 09:00:00 0.978903 2003-01-14 10:30:00 1.84184
# 2003-02-10 09:00:00 0.075963 2003-02-10 10:00:00 1.58192
# 2003-03-11 12:00:00 1.277608 2003-03-11 10:44:00 1.30756
# 2003-06-09 12:00:00 0.001106 2003-06-09 12:35:00 4.3544
# 2003-07-15 12:00:00 0.0 2003-07-15 10:53:00 1.6108
# 2003-09-10 12:00:00 17.629787 2003-09-10 11:50:00 4.0656
# 2003-10-14 12:00:00 0.0 2003-10-14 12:04:00 4.4988
# 2003-11-12 09:00:00 0.007219 2003-11-12 09:15:00 0.98988
# 2003-12-09 12:00:00 0.301635 2003-12-09 10:31:00 0.87436
# 2004-03-09 09:00:00 1.159205 2004-03-09 10:25:00 3.488
# 2004-05-11 12:00:00 12.649513 2004-05-11 11:03:00 6.376
# 2004-05-26 15:00:00 28.798002 2004-05-26 14:22:00 35.256
# 2004-07-13 12:00:00 0.0 2004-07-13 12:14:00 2.3328
# 2004-08-10 09:00:00 0.0 2004-08-10 09:57:00 3.9212
# 2004-09-13 12:00:00 1.632918 2004-09-13 12:10:00 10.4192
# 2004-11-09 12:00:00 0.001739 2004-11-09 10:37:00 1.7552
# 2004-12-07 09:00:00 6.430282 2004-12-07 10:24:00 1.65412
# 2005-01-18 12:00:00 2.580555 2005-01-18 10:40:00 4.3544
# 2005-02-15 12:00:00 0.254185 2005-02-15 10:45:00 0.78772
# 2005-03-15 09:00:00 0.005164 2005-03-15 09:44:00 1.20648
# 2005-05-10 09:00:00 12.717175 2005-05-10 10:07:00 29.48
# 2005-05-10 09:00:00 12.717175 2005-05-10 10:09:00 29.48
# 2005-07-12 09:00:00 4.221735 2005-07-12 10:13:00 4.3544
# 2005-09-13 12:00:00 0.0 2005-09-13 10:46:00 4.21
# 2005-10-11 12:00:00 5.254901 2005-10-11 11:10:00 2.9104
# 2005-10-31 00:00:00 11.624374 2005-10-31 01:17:00 30.924
# 2005-11-15 09:00:00 0.034453 2005-11-15 09:53:00 1.23536
# 2005-12-13 12:00:00 1.646159 2005-12-13 11:17:00 1.0332
# 2006-01-09 12:00:00 0.83382 2006-01-09 12:58:00 1.69744
# 2006-02-14 09:00:00 0.05679 2006-02-14 10:27:00 1.8996
# 2006-03-14 09:00:00 1.862329 2006-03-14 09:10:00 0.87436
# 2006-05-09 09:00:00 0.022377 2006-05-09 09:41:00 1.8996
# 2006-06-13 12:00:00 7.242721 2006-06-13 12:20:00 19.372
# 2006-08-15 09:00:00 0.0 2006-08-15 10:15:00 3.6324
# 2006-08-29 03:00:00 0.603451 2006-08-29 02:54:00 2.044
# 2006-09-12 12:00:00 0.0 2006-09-12 11:50:00 7.3868
# 2006-09-19 12:00:00 21.222597 2006-09-19 12:05:00 29.48
# 2006-10-10 12:00:00 0.0 2006-10-10 10:45:00 3.6324
# 2006-12-12 09:00:00 3.066902 2006-12-12 10:30:00 2.766
# 2007-02-06 09:00:00 1.039727 2007-02-06 09:45:00 1.01876
# 2007-04-03 09:00:00 0.009571 2007-04-03 10:13:00 0.85992
# 2007-05-08 12:00:00 0.002372 2007-05-08 12:05:00 1.13428
# 2007-05-21 12:00:00 11.45545 2007-05-21 12:57:00 4.0656
# 2007-07-05 09:00:00 0.0 2007-07-05 10:24:00 3.488
# 2007-08-07 09:00:00 12.086925 2007-08-07 09:34:00 4.3544
# 2007-09-04 12:00:00 36.355667 2007-09-04 12:01:00 58.36
# 2007-10-09 12:00:00 0.0 2007-10-09 12:35:00 2.1884
# 2007-11-06 09:00:00 0.008368 2007-11-06 10:15:00 1.09096
# 2007-12-03 03:00:00 12.797971 2007-12-03 01:36:00 30.924
# 2007-12-12 09:00:00 0.029742 2007-12-12 10:20:00 0.8888
# 2008-01-08 12:00:00 5.782071 2008-01-08 12:33:00 1.04764
# 2008-02-05 12:00:00 4.861154 2008-02-05 10:48:00 1.84184
# 2008-03-04 12:00:00 0.49274 2008-03-04 10:38:00 0.84548
# 2008-04-08 12:00:00 2.24716 2008-04-08 12:08:00 0.80216
# 2008-06-03 15:00:00 20.79294 2008-06-03 14:06:00 8.542
# 2008-06-11 12:00:00 0.187775 2008-06-11 10:42:00 1.95736
# 2008-07-08 09:00:00 0.001557 2008-07-08 10:00:00 1.7552
# 2008-08-05 12:00:00 0.0 2008-08-05 11:57:00 1.63968
# 2008-08-20 12:00:00 43.372299 2008-08-20 12:26:00 12.2964
# 2008-09-03 12:00:00 0.0 2008-09-03 11:55:00 1.49528
# 2008-10-07 09:00:00 4.355486 2008-10-07 10:09:00 3.0548
# 2008-11-04 12:00:00 9.385327 2008-11-04 10:50:00 8.9752
# 2008-12-02 12:00:00 3.230231 2008-12-02 10:45:00 1.07652
# 1.0

# %% [markdown]
# Compute <b><span style="color:#f00">R<sup>2</sup></span></b> and <b><span style="color:#f00">Nash</span></b> between sim. and obs. flow

# %%
# average of sim
sim_mean= sum(simflowdata[idx_flow][mask_flow])/float(len(simflowdata[idx_flow][mask_flow]))
# average of obs
obs_mean= sum(obsflowdata[mask_flow])/float(len(obsflowdata[mask_flow]))
# total sum of squares 
ss_tot = sum((x-obs_mean)**2 for x in obsflowdata[mask_flow]) 
# sum of squares of residuals
ss_err = sum((y-x)**2 for y,x in zip(simflowdata[idx_flow][mask_flow],obsflowdata[mask_flow]))

nash_flow = 1 - (ss_err/ss_tot)
print "nash_flow= ", nash_flow

gradient, intercept, r_value, p_value, std_err = stats.linregress(simflowdata[idx_flow][mask_flow],obsflowdata[mask_flow])
print "R-squared = ", r_value**2
if gradient <= 1:
  adj_r2 = gradient * (r_value**2)
  print "adj_r2 =", adj_r2
if gradient > 1:
  adj_r2 = gradient**(-1) * (r_value**2)
  print "adj_r2 =", adj_r2
# Out:
# nash_flow=  0.836777462357
# R-squared =  0.858673810603
# adj_r2 = 0.740618076458

# %% [markdown]
# Compute <b><span style="color:#f00">R<sup>2</sup></span></b> between sim. and obs. sediment

# %%
# average of sim
sim_mean= sum(FsimSed)/float(len(FsimSed))

print "sim_mean = ", sim_mean
obs_mean= sum(FobsSed)/float(len(FobsSed))

# total sum of squares 
ss_tot = sum((x-obs_mean)**2 for x in FobsSed) 

# sum of squares of residuals
ss_err = sum((y-x)**2 for y,x in zip(FsimSed,FobsSed))
nash_sed = 1 - (ss_err/ss_tot)
print "nash_sed = ", nash_sed

gradient, intercept, r_value, p_value, std_err = stats.linregress(FsimSed,FobsSed)
r2_sed = r_value**2
print "Sediment R-squared = ", r2_sed
if gradient <= 1:
  adj_r2_sed = gradient * (r_value**2)
  print "adj_r2_sed =", adj_r2_sed
if gradient > 1:
  adj_r2_sed = gradient**(-1) * (r_value**2)
  print "adj_r2_sed =", adj_r2_sed
# Out:
# sim_mean =  33.9243551553
# nash_sed =  0.490268205596
# Sediment R-squared =  0.501738728539
# adj_r2_sed = 0.445857577742

# %% [markdown]
# Compute <b><span style="color:#f00">R<sup>2</sup></span></b> between sim. and obs. coliform

# %%
# average of sim
sim_mean= sum(FsimOther)/float(len(FsimOther))
obs_mean= sum(FobsOther)/float(len(FobsOther))

# total sum of squares 
ss_tot = sum((x-obs_mean)**2 for x in FobsOther) 
# sum of squares of residuals
ss_err = sum((y-x)**2 for y,x in zip(FsimOther,FobsOther))


nash_col = 1 - (ss_err/ss_tot)
print "nash_col= ", nash_col

gradient, intercept, r_value, p_value, std_err = stats.linregress(FsimOther,FobsOther)
r2_col = r_value**2
print "R-squared = ", r2_col
if gradient <= 1:
  adj_r2_col = gradient * (r_value**2)
  print "adj_r2_col =", adj_r2_col
if gradient > 1:
  adj_r2_col = gradient**(-1) * (r_value**2)
  print "adj_r2_col =", adj_r2_col
# Out:
# nash_col=  0.36774731392
# R-squared =  0.410910999337
# adj_r2_col = 0.332290711117

# %% [markdown]
# Plot the time series of **sim. vs. obs daily streamflows **in cms.

# %%
##############################################################################################
#################################Plot the Discrete Time Series################################
##############################################################################################
# reconstruct the date objects with matching dates only 
fdate=[]
for i in idx_flow:
  if i >=0 :
    fdate.append(datetime.datetime.strptime(tempsimflowdate[i],'%m/%d/%Y'))
ssim = pd.Series(simflowdata[idx_flow][mask_flow], index=fdate)
sobs = pd.Series(obsflowdata[mask_flow], index=fdate)

fig=plt.figure(figsize=(17,5),dpi=400)
ax = plt.subplot()
fig.text(0.7, 0.8, r'$Nash=%.2f$' % nash_flow, fontsize=15)
title('daily streamflow', fontsize=14., y=1.02, fontweight='bold')
plt.ylabel('flow. ($m^{3}\,s^{-1}$)', fontsize=12.)
plt.xlabel('year', fontsize=12.)

# s=square, -=dash, g^=triangle
ssim['2002':'2009'].plot(label='Sim', color='red', linewidth=2.0)
sobs['2002':'2009'].plot(label='Obs',color ='blue')

grid(True)
#tight_layout()
ax.legend(loc='best')
savefig('D:\\Dropbox\\Python_Scripts\\Thornton\\sed.png',dpi=500,format = 'png',transparent='True')

##############################################################################################
#########################################Plot the CDF#########################################
##############################################################################################
fig=plt.figure(figsize=(7,5),dpi=400)
ax = plt.subplot()
n = len(ssim)

# log-normal probability plot
d = np.linspace(1, n, num=n)/(n+1)
y  = norm.ppf(d,0,1);

# create the axis ticks
p  = [0.001, 0.01, 0.05, 0.2, 0.5, 0.75, 0.90, 0.98, 0.999];
# relate var "p" with "y"
tick  = norm.ppf(p,0,1);
label = ['0.001','0.01','0.05','0.2','0.5','0.75','0.90','0.98','0.999'];
# recast the p to (0,1)

# sort the data in an ascending order
ssim.sort()
sobs.sort()
ax.plot(y,ssim, 'r+', label='sim')
ax.plot(y,sobs,'b*', label='obs')

# use numpoints option so the markeres don't appear twice in one legend
ax.legend(loc=(0.05,0.8),numpoints = 1)
plt.ylabel('flow. ($m^{3}\,s^{-1}$)', fontsize=12.)
plt.xlabel('cumulative prob.', fontsize=12.)
ax = gca()
ax.xaxis.set_major_locator(ticker.FixedLocator(tick))
ax.xaxis.set_major_formatter(ticker.FixedFormatter(label))
grid(True)
# save the figure to the folder
savefig('D:\\Dropbox\\Python_Scripts\\Mercer\\sed_cdf.png',dpi=500,format = 'png',transparent='True')

# %% [markdown]
# Plot the time series of **simuted sediment concentrations**.

# %% [markdown]
# Plot the **Sim** vs. **obs** monthly **sediment conc**

# %%
##############################################################################################
#################################Plot the Discrete Time Series################################
##############################################################################################
# reconstruct the date objects with matching dates only 

ssim = pd.Series(FsimSed, index=Fsimdate)
sobs = pd.Series(FobsSed, index=Fobsdate)
PCP = pd.Series(Fpcp, index=Fsimdate)

# Enter time range you'd like to plot, date format should be year, month, date 
startdate = datetime.datetime(1999,10,1)
enddate = datetime.datetime(2009,1,1)

# plot the primary sediment y-axis
fig = plt.figure(figsize=(17,5), dpi=400)
title('3-hourly sediment conc.', fontsize=14., y=1.02, fontweight='bold')
ax = fig.add_subplot(111)
pylab.xlim([startdate, enddate])
pylab.ylim([0,900])
#ax.set_xlabel("Year", fontsize=12.)
ax.set_ylabel(r"conc. ($mg\,l^{-1}$)", fontsize=12.)
lns1=ax.plot(Fsimdate, ssim, 'r-o', label='sim')
lns3=ax.plot(Fobsdate, sobs, 'b-o', label='obs')

# plot the secondary ppt y-axis
ax2 = ax.twinx()
ax2 = plt.gca()
ax2.set_ylabel(r"rain. ($m$)", fontsize=12.)
#lns2=ax2.plot(simdates, PCP, 'g', label='precip')
lns2 = ax2.bar(Fsimdate, PCP)
pylab.xlim([startdate, enddate])
pylab.ylim([0,0.1])
ax2.invert_yaxis()
ax2.grid(True)

#add legend
ax.legend((lns1[0],lns3[0],lns2[0]), ('Obs', 'sim', 'precip'),loc=(0.05, 0.7))

# %%
##############################################################################################
#################################Plot the Discrete Time Series################################
##############################################################################################
# reconstruct the date objects with matching dates only 

ssim = pd.Series(FsimSed, index=Fsimdate)
sobs = pd.Series(FobsSed, index=Fobsdate)


# plot the primary sediment y-axis
fig=plt.figure(figsize=(12,5),dpi=400)
ax = plt.subplot()
fig.text(0.7, 0.8, r'$R^2=%.2f$' % r2_sed, fontsize=15)
title('sediment concentration', fontsize=14., y=1.02, fontweight='bold')
plt.ylabel('conc. (mg/l)', fontsize=12.)
plt.xlabel('year', fontsize=12.)

# s=square, -=dash, g^=triangle
ssim['1999':'2009'].plot(label='Sim', color='red',style='-o',markersize=5, linewidth=2.0)
sobs['1999':'2009'].plot(label='Obs',color ='blue',style='-o',markersize=5)

grid(True)
#tight_layout()
ax.legend(loc='best')
savefig('D:\\Dropbox\\Python_Scripts\\Issaquah\\sed.png',dpi=500,format = 'png',transparent='True')

##############################################################################################
#########################################Plot the CDF#########################################
##############################################################################################
fig=plt.figure(figsize=(7,5),dpi=400)
ax = plt.subplot()
n = len(ssim)

# log-normal probability plot
d = np.linspace(1, n, num=n)/(n+1)
y  = norm.ppf(d,0,1);

# create the axis ticks
p  = [0.001, 0.01, 0.05, 0.2, 0.5, 0.75, 0.90, 0.98, 0.999];
# relate var "p" with "y"
tick  = norm.ppf(p,0,1);
label = ['0.001','0.01','0.05','0.2','0.5','0.75','0.90','0.98','0.999'];
# recast the p to (0,1)

# sort the data in an ascending order
ssim.sort()
sobs.sort()
ax.plot(y,ssim, 'r+', label='sim')
ax.plot(y,sobs,'b*', label='obs')

# use numpoints option so the markeres don't appear twice in one legend
ax.legend(loc=(0.05,0.8),numpoints = 1)
plt.ylabel('conc. (mg/l)', fontsize=12.)
plt.xlabel('cumulative prob.', fontsize=12.)
ax = gca()
ax.xaxis.set_major_locator(ticker.FixedLocator(tick))
ax.xaxis.set_major_formatter(ticker.FixedFormatter(label))
grid(True)
# save the figure to the folder
savefig('D:\\Dropbox\\Python_Scripts\\Issaquah\\sed_cdf1.png',dpi=500,format = 'png',transparent='True')

# %%
##############################################################################################
#########################################Plot the CDF#########################################
##############################################################################################
fig=plt.figure(figsize=(7,5),dpi=400)
ax = plt.subplot()
n = len(sobs)

# log-normal probability plot
d = np.linspace(1, n, num=n)/(n+1)
y  = norm.ppf(d,0,1);

# create the axis ticks
p  = [0.001, 0.01, 0.05, 0.2, 0.5, 0.75, 0.90, 0.98, 0.999];
# relate var "p" with "y"
tick  = norm.ppf(p,0,1);
label = ['0.001','0.01','0.05','0.2','0.5','0.75','0.90','0.98','0.999'];
# recast the p to (0,1)

sobs.sort()
ax.plot(y,sobs,'b*', label='obs')

n = len(simseddata)
d = np.linspace(1, n, num=n)/(n+1)
y  = norm.ppf(d,0,1);
simseddata.sort()
ax.plot(y,simseddata, 'r+', label='sim')


# use numpoints option so the markeres don't appear twice in one legend
ax.legend(loc=(0.05,0.8),numpoints = 1)
plt.ylabel('conc. (mg/l)', fontsize=12.)
plt.xlabel('cumulative prob.', fontsize=12.)
ax = gca()
ax.xaxis.set_major_locator(ticker.FixedLocator(tick))
ax.xaxis.set_major_formatter(ticker.FixedFormatter(label))
grid(True)
# save the figure to the folder
#savefig('D:\\Dropbox\\Python_Scripts\\Thornton\\sed_cdf2.png',dpi=500,format = 'png',transparent='True')

# %% [markdown]
# Plot the **Sim** vs. **obs** monthly **coliform conc**

# %%
##############################################################################################
#################################Plot the Discrete Time Series################################
##############################################################################################

ssim = pd.Series(FsimOther, index=Fsimdate)
sobs = pd.Series(FobsOther, index=Fobsdate)

fig=plt.figure(figsize=(12,5),dpi=400)
ax = plt.subplot()
fig.text(0.7, 0.8, r'$R^2=%.2f$' % r2_col, fontsize=15)
title('coliform concentration', fontsize=14., y=1.02, fontweight='bold')
plt.ylabel('conc. (mg/l)', fontsize=12.)
plt.xlabel('year', fontsize=12.)

# s=square, -=dash, g^=triangle
ssim['2000':'2008'].plot(label='Sim', color='red', style='-o',linewidth=2.0)
sobs['2000':'2008'].plot(label='Obs',color ='blue',style='-o',markersize=5)

grid(True)
#tight_layout()
ax.legend(loc='best')
savefig('D:\\Dropbox\\Python_Scripts\\Issaquah\\coliform.png',dpi=500,format = 'png',transparent='True')

##############################################################################################
##############################################################################################
#########################################Plot the CDF#########################################
##############################################################################################
fig=plt.figure(figsize=(7,5),dpi=400)
ax = plt.subplot()
n = len(ssim)

# log-normal probability plot
d = np.linspace(1, n, num=n)/(n+1)
y  = norm.ppf(d,0,1);

# create the axis ticks
p  = [0.001, 0.01, 0.05, 0.2, 0.5, 0.75, 0.90, 0.98, 0.999];
# relate var "p" with "y"
tick  = norm.ppf(p,0,1);
label = ['0.001','0.01','0.05','0.2','0.5','0.75','0.90','0.98','0.999'];
# recast the p to (0,1)

# sort the data in an ascending order
ssim.sort()
sobs.sort()
ax.plot(y,ssim, 'r+', label='sim')
ax.plot(y,sobs,'b*', label='obs')

# use numpoints option so the markeres don't appear twice in one legend
ax.legend(loc=(0.05,0.8),numpoints = 1)
plt.ylabel('conc. (mg/l)', fontsize=12.)
plt.xlabel('cumulative prob.', fontsize=12.)
ax = gca()
ax.xaxis.set_major_locator(ticker.FixedLocator(tick))
ax.xaxis.set_major_formatter(ticker.FixedFormatter(label))
grid(True)
# save the figure to the folder
savefig('D:\\Dropbox\\Python_Scripts\\Issaquah\\coliform_cdf.png',dpi=500,format = 'png',transparent='True')

# %%
##############################################################################################
#########################################Plot the CDF#########################################
##############################################################################################
fig=plt.figure(figsize=(7,5),dpi=400)
ax = plt.subplot()
n = len(sobs)

# log-normal probability plot
d = np.linspace(1, n, num=n)/(n+1)
y  = norm.ppf(d,0,1);

# create the axis ticks
p  = [0.001, 0.01, 0.05, 0.2, 0.5, 0.75, 0.90, 0.98, 0.999];
# relate var "p" with "y"
tick  = norm.ppf(p,0,1);
label = ['0.001','0.01','0.05','0.2','0.5','0.75','0.90','0.98','0.999'];
# recast the p to (0,1)

sobs.sort()
ax.plot(y,sobs,'b*', label='obs')

n = len(simotherdata)
d = np.linspace(1, n, num=n)/(n+1)
y  = norm.ppf(d,0,1);
simotherdata.sort()
ax.plot(y,simotherdata, 'r+', label='sim')


# use numpoints option so the markeres don't appear twice in one legend
ax.legend(loc=(0.05,0.8),numpoints = 1)
plt.ylabel('conc. (mg/l)', fontsize=12.)
plt.xlabel('cumulative prob.', fontsize=12.)
ax = gca()
ax.xaxis.set_major_locator(ticker.FixedLocator(tick))
ax.xaxis.set_major_formatter(ticker.FixedFormatter(label))
grid(True)
# save the figure to the folder
#savefig('D:\\Dropbox\\Python_Scripts\\Thornton\\sed_cdf2.png',dpi=500,format = 'png',transparent='True')
