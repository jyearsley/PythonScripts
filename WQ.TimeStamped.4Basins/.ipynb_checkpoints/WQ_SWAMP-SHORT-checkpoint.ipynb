# %% [markdown]
# ###This notebook includes Python tools for analyzing DHSVM outputs.
# Time series data are analyzed with **numpy** and **pandas** tools and plotted with **matplotlib**. Spatial maps are analyzed and plotted using **netCDF4** and **Basemap** utilities. In general, the scripts that needs to be changed (eg. file path, locations, time range, and variables to plot, etc) are on top of the coding block if there's any. However, differences in the input data may require changing the code, such as which columns to read as the dates, how many rows to skip as the header, etc. Currently all input file paths are absolute paths so you should be able to run the code as it is and plot from my output files. All plots are saved into a pdf page (specify the file name in the second code block). Note that you'll have to run the last code block to close the pdf file you opened in order to view the file correctly.

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['norm', 'gradient']
# `%matplotlib` prevents importing * from pylab and numpy

# %% [markdown]
# **First**, import all necessary libraries.

# %%
# Import all needed libraries 
import sys, os, datetime, time
import numpy as np
import pandas as pd
import numpy.ma as ma
import math
import matplotlib.dates as dates
import matplotlib.ticker as ticker
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
from scipy.stats import norm
from scipy import stats

import os
os.getcwd() 
os.chdir("D:\\Dropbox\\Python_Scripts")
os.getcwd()
# Out:
# 'D:\\Dropbox\\Python_Scripts'

# %% [markdown]
# Read the input **streamflow** files (change the path if needed)<br>
# <span style="background-color: #FFFF00">**<span style="color:#f00">Attention</span>**: the last date in obs. file **MUST NOT** exceed the last date of sim.</span>

# %%
# Enter file path for sim. and obs. flow files
simflowpath = 'D:\\Dropbox\\Python_Scripts\\Swamp\\daily_flow.txt'
obsflowpath = 'D:\\Dropbox\\Python_Scripts\\Swamp\\streamflow.12127100.cms.1979_1990.txt'

# Read flow sim and obs dates &  data
simflowdata = np.genfromtxt(simflowpath, usecols=[1])
obsflowdata = np.genfromtxt(obsflowpath, usecols=[1])
tempsimflowdate = np.genfromtxt(simflowpath, dtype = str, skiprows = 0, usecols = 0)
tempobsflowdate = np.genfromtxt(obsflowpath, dtype = str, skiprows = 0, usecols = 0)

# %% [markdown]
# **Sort** and **match** the obs. and sim. flow files based on dates.<br>

# %%
# Convert the string format dates into a datetime object
simflowdate = []
for i in range(len(tempsimflowdate)):
    simflowdate.append(datetime.datetime.strptime(tempsimflowdate[i],'%m/%d/%Y'))
# sort the dates in an acending order
simflowdate.sort()

# Convert the string format dates into a datetime object
obsflowdate = []
for i in range(len(tempobsflowdate)):
    obsflowdate.append(datetime.datetime.strptime(tempobsflowdate[i],'%Y-%m-%d'))
# sort the dates in an acending order
obsflowdate.sort()

# extract the matching dates from both arrays and mark them by mask
# searchsorted(t1,t2) finds index in t1 for every value in t2:    
idx_flow = np.searchsorted(simflowdate, obsflowdate, side='right')-1
j2 = [i for i in idx_flow if i > 0]

# mask the array as true if 
mask_flow = idx_flow >=0

# compare the obs. and sim. time series
df = pd.DataFrame({"simflowdate":tempsimflowdate[idx_flow][mask_flow], "simflow":simflowdata[idx_flow][mask_flow], \
                   "obsflow":obsflowdata[mask_flow], "obsflowdate":tempobsflowdate[mask_flow]})

#print df
#print df.values

# %% [markdown]
# Read the input **water quality**files (change the path if needed)<br>
# <span style="background-color: #FFFF00">**<span style="color:#f00">Attention</span>**: the last date in obs. file **MUST NOT** exceed the last date of sim.</span>

# %%
# Initialize a pdf file for saving all the figures
# pdfpages = PdfPages('test_figure.pdf')

# Enter file path for swater quality simulation files
simsedfilepath = 'D:\\Dropbox\\Python_Scripts\\Swamp\\Sed.Flow.Only'
simotherfilepath = 'D:\\Dropbox\\Python_Scripts\\Swamp\\Other.Conc.Only'

# Enter file path for observed water quality variable files
obsfilepath = 'D:\\Dropbox\\Python_Scripts\\Swamp\\swamp-time-stamped.txt'

# Enter file path for observed precipitation files
precipfilepath = 'D:\\Dropbox\\Python_Scripts\\Swamp\\Mass.Balance'

# Read dates of sims (continuous)
tempsimdates = np.genfromtxt(simsedfilepath, dtype=str, skiprows=2, usecols=0)

# Read dates of obs (discrete). Use the 2nd column
tempobsdates = np.genfromtxt(obsfilepath, dtype=str, skiprows=1, usecols=0)

# Read sediment sims (use the 2nd col)
simseddata = np.genfromtxt(simsedfilepath, skiprows=2, usecols=[2])
simseddata = simseddata + 1.2
# Read sediment obs.
# Skip the first line, and use the 5th column for sed
obsseddata = np.genfromtxt(obsfilepath, dtype=float, skiprows=1, usecols=[2])

# Read other data
simotherdata = np.genfromtxt(simotherfilepath, skiprows=2, usecols=[1])
print len(simotherdata)
#print simotherdata
obsotherdata = np.genfromtxt(obsfilepath, dtype=float, skiprows=1, usecols=[1])
obsotherdata = obsotherdata * 0.01444;

# Read obs. precipitation data
precipdata = np.genfromtxt(precipfilepath, dtype=float, skiprows=24, usecols=[9])
print len(precipdata)
# Out:
# 35799
# 35799

# %% [markdown]
# **Third**, find out the dates when both sims and obs (discontinous) are available.
#
# <span style="background-color: #FFFF00">**Particular attention** needs to be paid on **<span style="color:#f00">np.searchsorted()</span>**. Output all matching columns to make sure its the right match. Right now, the option **side='right'** must be used in the case of **daily time step (mm/dd/yy)** to avoid the 1-day mismatch. Later when working with **3-hourly set**, this may not hold.</span>

# %%
simdates = []
Fsimdate = []
Fobsdate = []
FsimSed = []
FobsSed = []
FsimOther = []
FobsOther = []

# construct the sim. date obj.
for i in range(len(tempsimdates)):
    simdates.append(datetime.datetime.strptime(tempsimdates[i],'%m/%d/%Y-%H:%M:%S'))
simdates.sort()
# construct the obs. date obj.
obsdates = []
for i in range(len(tempobsdates)):
    obsdates.append(datetime.datetime.strptime(tempobsdates[i],'%m/%d/%Y-%H:%M:%S'))
obsdates.sort()

for i in range(len(obsdates)):
    obs = date2num(obsdates[i])
    junk = date2num(simdates)
    #value = obsdates[i]
    idx = (np.abs(junk-obs)).argmin()
    if (idx > 0):
      Fsimdate.append(simdates[idx])
      Fobsdate.append(obsdates[i])
      FsimSed.append(simseddata[idx])
      FobsSed.append(obsseddata[i])
      FobsOther.append(obsotherdata[i])
      FsimOther.append(simotherdata[idx])


for i in range(len(FsimSed)):
    print Fsimdate[i], FsimSed[i], Fobsdate[i], FobsSed[i]
    #print Fsimdate[i], FsimOther[i], Fobsdate[i], FobsOther[i]
    
print min(FobsSed)
# Out:
# 1999-01-19 09:00:00 3.999726 1999-01-19 10:08:00 5.5
# 1999-02-08 12:00:00 2.704527 1999-02-08 11:25:00 8.8
# 1999-02-24 12:00:00 4.257912 1999-02-24 11:28:00 10.4
# 1999-03-08 12:00:00 2.703052 1999-03-08 11:20:00 4.9
# 1999-04-12 12:00:00 2.700174 1999-04-12 10:33:00 1.5
# 1999-05-10 12:00:00 2.700043 1999-05-10 12:25:00 0.8
# 1999-06-14 12:00:00 2.7 1999-06-14 10:50:00 2.0
# 1999-06-24 15:00:00 11.944262 1999-06-24 14:10:00 12.5
# 1999-07-12 09:00:00 2.7 1999-07-12 10:25:00 1.8
# 1999-08-09 12:00:00 2.700748 1999-08-09 10:42:00 1.0
# 1999-09-13 12:00:00 2.7 1999-09-13 10:45:00 1.6
# 1999-10-11 12:00:00 2.700631 1999-10-11 10:58:00 2.4
# 1999-11-08 12:00:00 2.700741 1999-11-08 11:00:00 12.2
# 1999-11-09 12:00:00 19.561809 1999-11-09 10:43:00 37.2
# 1999-12-06 12:00:00 3.471959 1999-12-06 12:00:00 15.3
# 1999-12-13 12:00:00 2.799 1999-12-13 10:45:00 6.0
# 2000-01-10 12:00:00 4.622477 2000-01-10 10:55:00 5.0
# 2000-02-01 12:00:00 46.072086 2000-02-01 11:29:00 27.1
# 2000-02-29 12:00:00 3.569781 2000-02-29 11:25:00 10.4
# 2000-03-13 09:00:00 2.716098 2000-03-13 09:47:00 2.8
# 2000-04-10 12:00:00 2.7 2000-04-10 10:38:00 1.6
# 2000-04-10 12:00:00 2.7 2000-04-10 10:40:00 1.5
# 2000-05-08 12:00:00 2.700407 2000-05-08 12:09:00 3.6
# 2000-06-12 09:00:00 42.555232 2000-06-12 10:05:00 47.8
# 2000-07-10 12:00:00 2.7 2000-07-10 10:43:00 2.0
# 2000-07-31 12:00:00 2.7 2000-07-31 11:06:00 3.7
# 2000-09-11 12:00:00 2.701047 2000-09-11 11:30:00 2.1
# 2000-10-09 09:00:00 2.700952 2000-10-09 10:25:00 8.9
# 2000-11-08 06:00:00 27.190713 2000-11-08 07:25:00 36.2
# 2000-11-13 09:00:00 2.7 2000-11-13 10:29:00 9.3
# 2000-12-10 18:00:00 2.72743 2000-12-10 16:45:00 11.1
# 2001-01-08 12:00:00 2.700201 2001-01-08 10:40:00 6.4
# 2001-02-12 12:00:00 2.7 2001-02-12 10:44:00 2.4
# 2001-03-05 12:00:00 2.7 2001-03-05 11:20:00 2.0
# 2001-04-09 09:00:00 2.700176 2001-04-09 10:18:00 1.2
# 2001-04-30 12:00:00 2.700693 2001-04-30 11:25:00 7.3
# 2001-05-14 12:00:00 4.629482 2001-05-14 10:46:00 4.0
# 2001-06-11 09:00:00 30.04795 2001-06-11 10:28:00 41.6
# 2001-07-09 09:00:00 2.7 2001-07-09 10:16:00 1.21
# 2001-08-13 09:00:00 2.7 2001-08-13 10:09:00 1.2
# 2001-09-10 09:00:00 2.7 2001-09-10 10:20:00 1.3
# 2001-10-08 09:00:00 2.700945 2001-10-08 10:28:00 5.7
# 2002-01-14 12:00:00 2.7 2002-01-14 10:45:00 6.7
# 2002-03-11 12:00:00 5.86195 2002-03-11 10:50:00 22.4
# 2002-04-10 12:00:00 2.724375 2002-04-10 10:37:00 5.5
# 2002-05-15 12:00:00 2.7 2002-05-15 10:45:00 3.06
# 2002-06-11 12:00:00 2.7 2002-06-11 11:15:00 3.5
# 2002-07-10 12:00:00 2.7 2002-07-10 11:10:00 4.8
# 2002-08-13 09:00:00 2.7 2002-08-13 10:28:00 2.6
# 2002-09-11 09:00:00 2.7 2002-09-11 09:59:00 1.4
# 2002-10-16 12:00:00 2.7 2002-10-16 11:15:00 6.3
# 2002-11-12 12:00:00 15.347356 2002-11-12 10:53:00 9.09
# 2003-01-15 09:00:00 2.700019 2003-01-15 09:56:00 4.6
# 2003-01-27 12:00:00 2.703508 2003-01-27 10:35:00 4.31
# 2003-02-12 09:00:00 2.7 2003-02-12 09:49:00 5.1
# 2003-03-10 12:00:00 2.700005 2003-03-10 10:35:00 5.7
# 2003-04-16 09:00:00 2.700053 2003-04-16 10:21:00 2.0
# 2003-05-14 12:00:00 2.700215 2003-05-14 10:43:00 3.8
# 2003-06-10 12:00:00 2.70002 2003-06-10 11:10:00 5.94
# 2003-07-16 12:00:00 2.7 2003-07-16 11:10:00 2.34
# 2003-08-13 09:00:00 2.7 2003-08-13 10:15:00 2.07
# 2003-09-11 12:00:00 2.701202 2003-09-11 11:21:00 1.9
# 2003-10-15 09:00:00 2.700944 2003-10-15 10:03:00 1.4
# 2003-11-13 12:00:00 2.7 2003-11-13 11:20:00 1.6
# 2003-12-08 12:00:00 2.700164 2003-12-08 10:42:00 5.9
# 2004-01-13 09:00:00 2.700123 2004-01-13 10:18:00 1.3
# 2004-02-09 09:00:00 2.7 2004-02-09 10:23:00 2.0
# 2004-03-08 09:00:00 2.700009 2004-03-08 10:07:00 1.6
# 2004-04-12 09:00:00 2.7 2004-04-12 10:11:00 2.6
# 2004-05-10 09:00:00 2.700516 2004-05-10 09:55:00 2.42
# 2004-05-26 15:00:00 29.930135 2004-05-26 13:36:00 13.0
# 2004-06-14 12:00:00 2.700825 2004-06-14 10:34:00 1.4
# 2004-07-12 09:00:00 2.7 2004-07-12 10:26:00 2.1
# 2004-08-09 12:00:00 2.7 2004-08-09 11:16:00 1.8
# 2004-09-13 12:00:00 2.701015 2004-09-13 10:37:00 4.6
# 2004-10-11 09:00:00 2.7 2004-10-11 09:25:00 2.2
# 2004-11-08 12:00:00 2.70003 2004-11-08 11:10:00 2.6
# 2004-12-06 12:00:00 2.701097 2004-12-06 11:40:00 3.1
# 2005-01-18 09:00:00 3.071123 2005-01-18 10:05:00 5.1
# 2005-02-14 12:00:00 2.700085 2005-02-14 10:58:00 1.81
# 2005-03-14 12:00:00 2.7 2005-03-14 11:25:00 3.07
# 2005-04-11 12:00:00 2.838164 2005-04-11 11:21:00 6.1
# 2005-05-09 12:00:00 3.348791 2005-05-09 11:35:00 5.29
# 2005-06-13 12:00:00 2.700291 2005-06-13 10:32:00 4.4
# 2005-07-11 12:00:00 2.700118 2005-07-11 10:45:00 2.0
# 2005-08-08 09:00:00 2.7 2005-08-08 10:01:00 2.7
# 2005-09-12 09:00:00 2.7 2005-09-12 10:09:00 1.2
# 2005-10-10 12:00:00 2.700562 2005-10-10 11:30:00 1.67
# 2005-10-31 09:00:00 25.96586 2005-10-31 10:13:00 34.7
# 2005-11-14 12:00:00 2.700279 2005-11-14 11:10:00 2.8
# 2005-12-12 09:00:00 2.700119 2005-12-12 10:29:00 3.9
# 2006-01-09 09:00:00 2.752319 2006-01-09 10:15:00 5.5
# 2006-02-13 09:00:00 2.72724 2006-02-13 10:27:00 8.3
# 2006-03-13 09:00:00 2.70002 2006-03-13 10:09:00 2.9
# 2006-05-08 09:00:00 19.96878 2006-05-08 09:57:00 3.4
# 2006-06-12 09:00:00 2.700631 2006-06-12 10:26:00 1.7
# 2006-07-10 09:00:00 2.7 2006-07-10 09:57:00 2.3
# 2006-09-11 09:00:00 2.7 2006-09-11 10:25:00 2.1
# 2006-09-18 12:00:00 2.7011 2006-09-18 10:53:00 6.1
# 2006-10-09 12:00:00 2.70067 2006-10-09 10:53:00 2.0
# 2006-12-11 12:00:00 10.906021 2006-12-11 10:37:00 27.4
# 2007-01-08 12:00:00 2.700011 2007-01-08 10:50:00 8.8
# 2007-02-05 12:00:00 2.700061 2007-02-05 10:45:00 3.5
# 2007-03-05 12:00:00 2.7 2007-03-05 10:48:00 6.1
# 2007-05-07 12:00:00 2.7 2007-05-07 11:32:00 6.9
# 2007-05-21 12:00:00 2.700757 2007-05-21 11:27:00 25.4
# 2007-06-04 09:00:00 2.700494 2007-06-04 09:23:00 7.04
# 2007-07-02 12:00:00 2.7 2007-07-02 10:40:00 2.9
# 2007-08-06 12:00:00 2.7 2007-08-06 11:17:00 4.2
# 2007-09-04 12:00:00 2.701341 2007-09-04 11:00:00 4.1
# 2007-10-08 12:00:00 2.7 2007-10-08 11:43:00 4.0
# 2007-11-05 12:00:00 2.7 2007-11-05 11:18:00 2.8
# 2007-12-11 12:00:00 2.7 2007-12-11 10:45:00 12.9
# 2008-01-07 12:00:00 2.7 2008-01-07 11:18:00 15.4
# 2008-02-05 12:00:00 2.700391 2008-02-05 11:30:00 5.0
# 2008-03-03 09:00:00 2.700484 2008-03-03 10:23:00 4.73
# 2008-04-07 12:00:00 2.758576 2008-04-07 11:25:00 3.9
# 2008-06-02 12:00:00 2.700463 2008-06-02 11:33:00 3.9
# 2008-06-03 06:00:00 65.05968 2008-06-03 07:02:00 79.7
# 2008-07-07 12:00:00 2.7 2008-07-07 11:22:00 9.7
# 2008-08-04 09:00:00 2.7 2008-08-04 09:42:00 6.9
# 2008-08-20 12:00:00 2.701114 2008-08-20 11:25:00 15.0
# 2008-09-02 09:00:00 2.7 2008-09-02 10:07:00 3.1
# 2008-10-06 12:00:00 2.700629 2008-10-06 10:34:00 5.1
# 2008-11-03 12:00:00 2.700761 2008-11-03 11:41:00 8.0
# 2008-12-01 12:00:00 2.7 2008-12-01 10:41:00 3.4
# 0.8

# %% [markdown]
# Compute <b><span style="color:#f00">R<sup>2</sup></span></b> between sim. and obs. sediment

# %%
# average of sim
sim_mean= sum(FsimSed)/float(len(FsimSed))

print "sim_mean = ", sim_mean
obs_mean= sum(FobsSed)/float(len(FobsSed))

# total sum of squares 
ss_tot = sum((x-obs_mean)**2 for x in FobsSed) 

# sum of squares of residuals
ss_err = sum((y-x)**2 for y,x in zip(FsimSed,FobsSed))
nash_sed = 1 - (ss_err/ss_tot)
print "nash_sed = ", nash_sed

gradient, intercept, r_value, p_value, std_err = stats.linregress(FsimSed,FobsSed)
r2_sed = r_value**2
print "Sediment R-squared = ", r2_sed
if gradient <= 1:
  adj_r2_sed = gradient * (r_value**2)
  print "adj_r2_sed =", adj_r2_sed
if gradient > 1:
  adj_r2_sed = gradient**(-1) * (r_value**2)
  print "adj_r2_sed =", adj_r2_sed
# Out:
# sim_mean =  5.28064087302
# nash_sed =  0.696395720048
# Sediment R-squared =  0.731139249252
# adj_r2_sed = 0.724409144648

# %% [markdown]
# Compute <b><span style="color:#f00">R<sup>2</sup></span></b> between sim. and obs. coliform

# %%
# average of sim
sim_mean= sum(FsimOther)/float(len(FsimOther))
obs_mean= sum(FobsOther)/float(len(FobsOther))

# total sum of squares 
ss_tot = sum((x-obs_mean)**2 for x in FobsOther) 
# sum of squares of residuals
ss_err = sum((y-x)**2 for y,x in zip(FsimOther,FobsOther))


nash_col = 1 - (ss_err/ss_tot)
print "nash_col= ", nash_col

gradient, intercept, r_value, p_value, std_err = stats.linregress(FsimOther,FobsOther)
r2_col = r_value**2
print "R-squared = ", r2_col
if gradient <= 1:
  adj_r2_col = gradient * (r_value**2)
  print "adj_r2_col =", adj_r2_col
if gradient > 1:
  adj_r2_col = gradient**(-1) * (r_value**2)
  print "adj_r2_col =", adj_r2_col
# Out:
# nash_col=  0.288116927284
# R-squared =  0.308236860832
# adj_r2_col = 0.294276533478

# %% [markdown]
# Plot the **Sim** vs. **obs** monthly **sediment conc**

# %%
##############################################################################################
#################################Plot the Discrete Time Series################################
##############################################################################################
# reconstruct the date objects with matching dates only 

ssim = pd.Series(FsimSed, index=Fsimdate)
sobs = pd.Series(FobsSed, index=Fobsdate)

fig=plt.figure(figsize=(12,5),dpi=400)
ax = plt.subplot()
fig.text(0.7, 0.8, r'$R^2=%.2f$' % r2_sed, fontsize=15)
title('sediment concentration', fontsize=14., y=1.02, fontweight='bold')
plt.ylabel('conc. (mg/l)', fontsize=12.)
plt.xlabel('year', fontsize=12.)

# s=square, -=dash, g^=triangle
ssim['1999':'2008'].plot(label='Sim', color='red',style='-o',markersize=5, linewidth=2.0)
sobs['1999':'2008'].plot(label='Obs',color ='blue',style='-o',markersize=5)

grid(True)
#tight_layout()
ax.legend(loc='best')
savefig('D:\\Dropbox\\Python_Scripts\\Swamp\\sed.png',dpi=500,format = 'png',transparent='True')

##############################################################################################
#########################################Plot the CDF#########################################
##############################################################################################
fig=plt.figure(figsize=(7,5),dpi=400)
ax = plt.subplot()
n = len(ssim)

# log-normal probability plot
d = np.linspace(1, n, num=n)/(n+1)
y  = norm.ppf(d,0,1);

# create the axis ticks
p  = [0.001, 0.01, 0.05, 0.2, 0.5, 0.75, 0.90, 0.98, 0.999];
# relate var "p" with "y"
tick  = norm.ppf(p,0,1);
label = ['0.001','0.01','0.05','0.2','0.5','0.75','0.90','0.98','0.999'];
# recast the p to (0,1)

# sort the data in an ascending order
ssim.sort()
sobs.sort()
ax.plot(y,ssim, 'r+', label='sim')
ax.plot(y,sobs,'b*', label='obs')

# use numpoints option so the markeres don't appear twice in one legend
ax.legend(loc=(0.05,0.8),numpoints = 1)
plt.ylabel('conc. (mg/l)', fontsize=12.)
plt.xlabel('cumulative prob.', fontsize=12.)
ax = gca()
ax.xaxis.set_major_locator(ticker.FixedLocator(tick))
ax.xaxis.set_major_formatter(ticker.FixedFormatter(label))
grid(True)
# save the figure to the folder
savefig('D:\\Dropbox\\Python_Scripts\\Swamp\\sed_cdf.png',dpi=500,format = 'png',transparent='True')

# %%
##############################################################################################
#########################################Plot the CDF#########################################
##############################################################################################
fig=plt.figure(figsize=(7,5),dpi=400)
ax = plt.subplot()
n = len(sobs)

# log-normal probability plot
d = np.linspace(1, n, num=n)/(n+1)
y  = norm.ppf(d,0,1);

# create the axis ticks
p  = [0.001, 0.01, 0.05, 0.2, 0.5, 0.75, 0.90, 0.98, 0.999];
# relate var "p" with "y"
tick  = norm.ppf(p,0,1);
label = ['0.001','0.01','0.05','0.2','0.5','0.75','0.90','0.98','0.999'];
# recast the p to (0,1)

sobs.sort()
ax.plot(y,sobs,'b*', label='obs')

n = len(simseddata)
d = np.linspace(1, n, num=n)/(n+1)
y  = norm.ppf(d,0,1);
simseddata.sort()
ax.plot(y,simseddata, 'r+', label='sim')


# use numpoints option so the markeres don't appear twice in one legend
ax.legend(loc=(0.05,0.8),numpoints = 1)
plt.ylabel('conc. (mg/l)', fontsize=12.)
plt.xlabel('cumulative prob.', fontsize=12.)
ax = gca()
ax.xaxis.set_major_locator(ticker.FixedLocator(tick))
ax.xaxis.set_major_formatter(ticker.FixedFormatter(label))
grid(True)
# save the figure to the folder
#savefig('D:\\Dropbox\\Python_Scripts\\Thornton\\sed_cdf2.png',dpi=500,format = 'png',transparent='True')

# %% [markdown]
# Plot the **Sim** vs. **obs** monthly **coliform conc**

# %%
##############################################################################################
#################################Plot the Discrete Time Series################################
##############################################################################################

ssim = pd.Series(FsimOther, index=Fsimdate)
sobs = pd.Series(FobsOther, index=Fobsdate)

fig=plt.figure(figsize=(12,5),dpi=400)
ax = plt.subplot()
fig.text(0.7, 0.8, r'$R^2=%.2f$' % r2_col, fontsize=15)
title('coliform concentration', fontsize=14., y=1.02, fontweight='bold')
plt.ylabel('conc. (mg/l)', fontsize=12.)
plt.xlabel('year', fontsize=12.)
plt.ylim([0,160])
# s=square, -=dash, g^=triangle
ssim['1999':'2008'].plot(label='Sim', color='red',style='-o',linewidth=2.0)
sobs['1999':'2008'].plot(label='Obs',color ='blue',style='-o',markersize=5)

grid(True)
#tight_layout()
ax.legend(loc='best')
savefig('D:\\Dropbox\\Python_Scripts\\Swamp\\coliform.png',dpi=500,format = 'png',transparent='True')

##############################################################################################
##############################################################################################
#########################################Plot the CDF#########################################
##############################################################################################
fig=plt.figure(figsize=(7,5),dpi=400)
ax = plt.subplot()
n = len(ssim)

# log-normal probability plot
d = np.linspace(1, n, num=n)/(n+1)
y  = norm.ppf(d,0,1);

# create the axis ticks
p  = [0.001, 0.01, 0.05, 0.2, 0.5, 0.75, 0.90, 0.98, 0.999];
# relate var "p" with "y"
tick  = norm.ppf(p,0,1);
label = ['0.001','0.01','0.05','0.2','0.5','0.75','0.90','0.98','0.999'];
# recast the p to (0,1)

# sort the data in an ascending order
ssim.sort()
sobs.sort()
ax.plot(y,ssim, 'r+', label='sim')
ax.plot(y,sobs,'b*', label='obs')

# use numpoints option so the markeres don't appear twice in one legend
ax.legend(loc=(0.05,0.8),numpoints = 1)
plt.ylabel('conc. (mg/l)', fontsize=12.)
plt.xlabel('cumulative prob.', fontsize=12.)
ax = gca()
ax.xaxis.set_major_locator(ticker.FixedLocator(tick))
ax.xaxis.set_major_formatter(ticker.FixedFormatter(label))
grid(True)
# save the figure to the folder
savefig('D:\\Dropbox\\Python_Scripts\\Thornton\\coliform_cdf.png',dpi=500,format = 'png',transparent='True')

# %%
##############################################################################################
#########################################Plot the CDF#########################################
##############################################################################################
fig=plt.figure(figsize=(7,5),dpi=400)
ax = plt.subplot()
n = len(sobs)

# log-normal probability plot
d = np.linspace(1, n, num=n)/(n+1)
y  = norm.ppf(d,0,1);

# create the axis ticks
p  = [0.001, 0.01, 0.05, 0.2, 0.5, 0.75, 0.90, 0.98, 0.999];
# relate var "p" with "y"
tick  = norm.ppf(p,0,1);
label = ['0.001','0.01','0.05','0.2','0.5','0.75','0.90','0.98','0.999'];
# recast the p to (0,1)

sobs.sort()
ax.plot(y,sobs,'b*', label='obs')

n = len(simotherdata)
d = np.linspace(1, n, num=n)/(n+1)
y  = norm.ppf(d,0,1);
simotherdata.sort()
ax.plot(y,simotherdata, 'r+', label='sim')


# use numpoints option so the markeres don't appear twice in one legend
ax.legend(loc=(0.05,0.8),numpoints = 1)
plt.ylabel('conc. (mg/l)', fontsize=12.)
plt.xlabel('cumulative prob.', fontsize=12.)
ax = gca()
ax.xaxis.set_major_locator(ticker.FixedLocator(tick))
ax.xaxis.set_major_formatter(ticker.FixedFormatter(label))
grid(True)
# save the figure to the folder
#savefig('D:\\Dropbox\\Python_Scripts\\Thornton\\sed_cdf2.png',dpi=500,format = 'png',transparent='True')
