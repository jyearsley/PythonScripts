# %% [markdown]
# ###This notebook includes Python tools for analyzing DHSVM outputs.
# Time series data are analyzed with **numpy** and **pandas** tools and plotted with **matplotlib**. Spatial maps are analyzed and plotted using **netCDF4** and **Basemap** utilities. In general, the scripts that needs to be changed (eg. file path, locations, time range, and variables to plot, etc) are on top of the coding block if there's any. However, differences in the input data may require changing the code, such as which columns to read as the dates, how many rows to skip as the header, etc. Currently all input file paths are absolute paths so you should be able to run the code as it is and plot from my output files. All plots are saved into a pdf page (specify the file name in the second code block). Note that you'll have to run the last code block to close the pdf file you opened in order to view the file correctly.

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['norm', 'f', 'e', 'gradient']
# `%matplotlib` prevents importing * from pylab and numpy

# %% [markdown]
# **First**, import all necessary libraries.

# %%
# Import all needed libraries 
import sys, os, datetime, time
import numpy as np
import pandas as pd
import numpy.ma as ma
import math
import matplotlib.dates as dates
import matplotlib.ticker as ticker
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
from scipy.stats import norm
from scipy import stats

import os
os.getcwd() 
os.chdir("D:\\Dropbox\\Python_Scripts")
os.getcwd()
# Out:
# 'D:\\Dropbox\\Python_Scripts'

# %% [markdown]
# Read the input **streamflow** files (change the path if needed)<br>
# <span style="background-color: #FFFF00">**<span style="color:#f00">Attention</span>**: the last date in obs. file **MUST NOT** exceed the last date of sim.</span>

# %%
# Enter file path for sim. and obs. flow files
simflowpath = 'D:\\Dropbox\\Python_Scripts\\Issaquah\\LULC_Scenarios\\2002\\output\\daily_flow.txt'
obsflowpath = 'D:\\Dropbox\\Python_Scripts\\Issaquah\\streamflow.12121600.cms.txt'

# Read flow sim and obs dates &  data
simflowdata = np.genfromtxt(simflowpath, usecols=[1])
obsflowdata = np.genfromtxt(obsflowpath, usecols=[1])
tempsimflowdate = np.genfromtxt(simflowpath, dtype = str, skiprows = 0, usecols = 0)
tempobsflowdate = np.genfromtxt(obsflowpath, dtype = str, skiprows = 0, usecols = 0)

# %% [markdown]
# **Sort** and **match** the obs. and sim. flow files based on dates.<br>

# %%
# Convert the string format dates into a datetime object
simflowdate = []
for i in range(len(tempsimflowdate)):
    simflowdate.append(datetime.datetime.strptime(tempsimflowdate[i],'%m/%d/%Y'))
# sort the dates in an acending order
simflowdate.sort()

# Convert the string format dates into a datetime object
obsflowdate = []
for i in range(len(tempobsflowdate)):
    obsflowdate.append(datetime.datetime.strptime(tempobsflowdate[i],'%Y-%m-%d'))
# sort the dates in an acending order
obsflowdate.sort()

# extract the matching dates from both arrays and mark them by mask
# searchsorted(t1,t2) finds index in t1 for every value in t2:    
idx_flow = np.searchsorted(simflowdate, obsflowdate, side='right')-1
j2 = [i for i in idx_flow if i > 0]

# mask the array as true if 
mask_flow = idx_flow >=0

# compare the obs. and sim. time series
df = pd.DataFrame({"simflowdate":tempsimflowdate[idx_flow][mask_flow], "simflow":simflowdata[idx_flow][mask_flow], \
                   "obsflow":obsflowdata[mask_flow], "obsflowdate":tempobsflowdate[mask_flow]})

#print df
#print df.values

# %% [markdown]
# Read the input **water quality**files (change the path if needed)<br>
# <span style="background-color: #FFFF00">**<span style="color:#f00">Attention</span>**: the last date in obs. file **MUST NOT** exceed the last date of sim.</span>

# %%
# Initialize a pdf file for saving all the figures
# pdfpages = PdfPages('test_figure.pdf')

# Enter file path for swater quality simulation files
simsedfilepath = 'D:\\Dropbox\\Python_Scripts\\Issaquah\\LULC_Scenarios\\2002\\output\\Sed.Flow.Only'
simotherfilepath = 'D:\\Dropbox\\Python_Scripts\\Issaquah\\LULC_Scenarios\\2002\\output\\Other.Conc.Only'
simOrgPfilepath = 'D:\\Dropbox\\Python_Scripts\\Issaquah\\LULC_Scenarios\\2002\\output\\OrgP.Conc.Only'
simSolPfilepath = 'D:\\Dropbox\\Python_Scripts\\Issaquah\\LULC_Scenarios\\2002\\output\\solP.Conc.Only'

# Enter file path for observed water quality variable files
obsfilepath = 'D:\\Dropbox\\Python_Scripts\\Issaquah\\issaquah-time-stamped-validated.txt'

# Enter file path for observed precipitation files
precipfilepath = 'D:\\Dropbox\\Python_Scripts\\Issaquah\\LULC_Scenarios\\2002\\output\\Mass.Balance'

# Read dates of sims (continuous)
tempsimdates = np.genfromtxt(simsedfilepath, dtype=str, skiprows=2, usecols=0)

# Read dates of obs (discrete). Use the 2nd column
tempobsdates = np.genfromtxt(obsfilepath, dtype=str, skiprows=1, usecols=0)

# Read sediment sims (use the 2nd col)
simseddata = np.genfromtxt(simsedfilepath, skiprows=2, usecols=[2])
simseddata = simseddata + 5
# Read sediment obs.
# Skip the first line, and use the 5th column for sed
obsseddata = np.genfromtxt(obsfilepath, dtype=float, skiprows=1, usecols=[2])

# Read other data
simotherdata = np.genfromtxt(simotherfilepath, skiprows=2, usecols=[1])
simotherdata = simotherdata + 20
print len(simotherdata)
#print simotherdata1
obsotherdata = np.genfromtxt(obsfilepath, dtype=float, skiprows=1, usecols=[1])
obsotherdata = obsotherdata;

# Read obs. precipitation data
precipdata = np.genfromtxt(precipfilepath, dtype=float, skiprows=24, usecols=[9])
print len(precipdata)

# Read P (phosphorous) data
simOrgnPdata = np.genfromtxt(simOrgPfilepath, skiprows=2, usecols=[1])
simSolPdata = np.genfromtxt(simSolPfilepath, skiprows=2, usecols=[1])
simTPdata = simOrgnPdata + simSolPdata
obsTPdata = np.genfromtxt(obsfilepath, dtype=float, skiprows=1, usecols=[6])

print len(simTPdata)
print len(simOrgnPdata)
print len(simSolPdata)
# Out:
# 58440
# 58440
# 58440
# 58440
# 58440

# %% [markdown]
# **Third**, find out the dates when both sims and obs (discontinous) are available.
#
# <span style="background-color: #FFFF00">**Particular attention** needs to be paid on **<span style="color:#f00">np.searchsorted()</span>**. Output all matching columns to make sure its the right match. Right now, the option **side='right'** must be used in the case of **daily time step (mm/dd/yy)** to avoid the 1-day mismatch. Later when working with **3-hourly set**, this may not hold.</span>

# %%
#######dates###########
simdates = []
Fsimdate = []
Fobsdate = []
########sediment#######
FsimSed = []
FsimSedPre = []
FsimSedPost = []
FobsSed = []
########coliform#######
FsimOther = []
FsimOtherPre = []
FsimOtherPost = []
FobsOther = []
######phosphorous######
FsimTP = []
FsimTPPre = []
FsimTPPost = []
FobsTP = []
#######################

# construct the sim. date obj.
for i in range(len(tempsimdates)):
    simdates.append(datetime.datetime.strptime(tempsimdates[i],'%m/%d/%Y-%H:%M:%S'))
simdates.sort()
# construct the obs. date obj.
obsdates = []
for i in range(len(tempobsdates)):
    obsdates.append(datetime.datetime.strptime(tempobsdates[i],'%m/%d/%Y-%H:%M:%S'))
obsdates.sort()


for i in range(len(obsdates)):
    obs = dates.date2num(obsdates[i])
    junk = date2num(simdates)
    #value = obsdates[i]
    idx = (np.abs(junk-obs)).argmin()
    if (idx-1 > 0 and (idx+1)< len(simdates)):
      Fsimdate.append(simdates[idx])
      Fobsdate.append(obsdates[i])
      #
      FsimSed.append(simseddata[idx])
      FsimSedPre.append(simseddata[idx-1])
      FsimSedPost.append(simseddata[idx+1])
      FobsSed.append(obsseddata[i])
      #
      FobsOther.append(obsotherdata[i])
      FsimOther.append(simotherdata[idx])
      FsimOtherPre.append(simotherdata[idx-1])
      FsimOtherPost.append(simotherdata[idx+1])
      #
      FobsTP.append(obsTPdata[i])
      FsimTP.append(simTPdata[idx])
      FsimTPPre.append(simTPdata[idx-1])
      FsimTPPost.append(simTPdata[idx+1])

# unit conversion (divide by 1000)
for i in range(len(FsimOther)):
    FsimOther[i]= FsimOther[i]/1000
    FobsOther[i] = FobsOther[i]/1000
    FsimOtherPost[i] = FsimOtherPost[i]/1000 
    FsimOtherPre[i] = FsimOtherPre[i]/1000 
    
for i in range(len(FsimSed)):
    #print Fsimdate[i], FsimSed[i], FobsSed[i], FsimOther[i], FobsOther[i]
    #print Fsimdate[i], FsimOther[i], FsimOtherPre[i], FsimOtherPost[i], Fobsdate[i], FobsOther[i]
    print Fobsdate[i], FsimSed[i], FobsSed[i], FsimOther[i], FobsOther[i], FsimTP[i], FobsTP[i]
# Out:
# 1993-01-20 13:50:00 38.892094 30.0 1.103511475 0.29 0.092386 0.05
# 1993-02-16 10:37:00 1.06144 2.0 0.020075558 0.017 0.0230732027 0.03
# 1993-03-22 13:35:00 27.395216 19.0 0.557056763 0.12 0.078533 0.05
# 1993-04-13 10:37:00 4.86721 7.4 0.024017759 0.06 0.02446116 0.02
# 1993-06-15 10:45:00 2.622803 6.0 0.17875943 0.21 0.02629054 0.03
# 1993-07-13 10:35:00 1.75128 1.6 0.039362986 0.15 0.021009013 0.01
# 1993-08-10 11:30:00 1.0 1.4 0.02 0.16 0.013742 0.02
# 1993-09-21 11:20:00 1.124343 4.1 0.020449515 0.2 0.0071230255 0.02
# 1993-10-12 10:40:00 2.776037 5.1 0.0335613 0.15 0.0144259628 0.05
# 1993-12-13 13:20:00 10.71757 4.4 0.034531239 0.06 0.02134738 0.02
# 1994-01-19 11:28:00 1.561173 4.0 0.020089382 0.011 0.024874298 0.01
# 1994-02-15 12:40:00 3.347931 4.3 0.261102188 0.32 0.0262169 0.02
# 1994-02-23 11:00:00 16.856705 13.0 0.513290314 0.5 0.0357779 0.02
# 1994-03-15 11:10:00 4.287299 4.2 0.209481796 0.056 0.0357216 0.02
# 1994-04-12 11:06:00 9.474167 13.0 0.275739471 0.33 0.02633598 0.02
# 1994-05-17 11:31:00 1.927913 7.5 0.245610825 0.46 0.02200163 0.04
# 1994-06-21 11:25:00 1.000005 3.6 0.020000374 0.16 0.020739 0.02
# 1994-07-12 12:00:00 1.0 0.8 0.02 0.14 0.013221 0.03
# 1994-09-20 11:25:00 1.0 10.0 0.02000032 2.4 0.0064059 0.05
# 1994-10-26 11:05:00 68.313202 92.0 2.638835205 0.7 0.25026 0.17
# 1994-10-31 15:25:00 25.772425 10.0 0.706372864 0.48 0.039867 0.05
# 1994-11-08 12:20:00 4.703938 3.1 0.113416672 0.18 0.0193426 0.03
# 1994-12-15 08:58:00 5.605794 7.3 0.272684235 0.038 0.0273012 0.06
# 1995-01-10 11:40:00 10.035425 15.0 0.285671295 0.11 0.0309924 0.03
# 1995-01-30 14:45:00 11.347392 22.0 0.390708435 0.2 0.0328551 0.06
# 1995-02-15 10:30:00 2.450926 4.2 0.04024621 0.054 0.0268158 0.03
# 1995-03-14 11:30:00 18.44939 12.0 0.052646294 0.065 0.02777524 0.04
# 1995-04-11 09:50:00 6.422492 4.0 0.316726654 0.043 0.0305486 0.03
# 1995-05-02 11:23:00 10.940289 15.0 1.315351318 0.42 0.0517302 0.05
# 1995-06-13 10:00:00 3.24768 3.0 0.560397339 0.17 0.0199845 0.04
# 1995-07-18 09:55:00 1.0 1.6 0.020000315 0.25 0.0090396 0.03
# 1995-08-17 11:15:00 50.173717 26.8 3.316209229 1.4 0.20986 0.09
# 1995-11-14 11:45:00 116.090042 18.4 0.021505012 0.027 0.02631631 0.03
# 1995-12-12 11:55:00 145.12616 23.3 0.043752817 0.045 0.0390053 0.05
# 1996-01-09 12:00:00 19.503435 36.2 0.023990179 0.027 0.0284523 0.06
# 1996-02-08 06:00:00 4672.306641 1890.0 0.05336779 0.29 0.415991 1.24
# 1996-02-13 10:12:00 154.71843 45.6 0.02044967 0.02 0.0393944 0.08
# 1996-03-12 11:10:00 2.911424 6.0 0.036304947 0.042 0.02789344 0.02
# 1996-04-16 11:35:00 24.073385 84.5 0.526023895 0.39 0.0511788 0.11
# 1996-05-14 11:05:00 53.756626 15.4 0.075039383 0.32 0.0380418 0.04
# 1996-06-11 10:42:00 1.001652 2.4 0.020184383 0.1 0.025014 0.02
# 1996-07-16 10:40:00 1.0 3.6 0.020002193 0.19 0.014838 0.04
# 1996-08-13 10:00:00 1.0 3.3 0.020001097 0.16 0.0089348 0.03
# 1996-09-10 09:05:00 1.0 1.5 0.020001462 0.4 0.0067366 0.02
# 1996-11-13 09:45:00 23.083509 70.5 0.770446899 0.9 0.0470303 0.18
# 1996-12-10 10:20:00 71.853401 33.4 0.024847557 0.073 0.0369052 0.04
# 1997-01-14 10:20:00 11.880655 7.8 0.020090041 0.032 0.0250522 0.03
# 1997-02-10 11:35:00 2.433928 1.1 0.020053469 0.009 0.02557944 0.03
# 1997-03-18 03:00:00 140.573227 29.9 0.112653473 0.18 0.0406655 0.06
# 1997-04-08 12:00:00 5.88951 3.7 0.306360352 0.66 0.0362797 0.01
# 1997-05-13 12:25:00 1.123564 3.8 0.020151846 0.037 0.0283327853 0.06
# 1997-06-10 12:50:00 1.022837 3.1 0.020041643 1.3 0.027616 0.04
# 1997-07-08 10:20:00 17.980774 11.0 1.978227661 0.55 0.06133 0.04
# 1997-08-12 12:25:00 1.0 2.4 0.020001797 0.09 0.017542 0.0099
# 1997-10-02 12:40:00 7.991263 5.8 0.890369812 0.54 0.0232789 0.05
# 1997-10-14 10:50:00 3.849427 5.5 0.067018269 0.13 0.02675062 0.04
# 1997-10-29 11:15:00 34.386028 98.7 1.069819702 3.1 0.096295 0.2
# 1997-11-13 11:10:00 1.754114 4.1 0.020180722 0.038 0.027070836 0.03
# 1997-12-09 11:30:00 3.615588 2.7 0.097060951 0.023 0.0364772 0.02
# 1997-12-16 13:20:00 67.374222 61.9 1.117524292 0.54 0.168469 0.14
# 1998-01-05 12:20:00 44.610569 56.9 0.448567749 0.33 0.049723 0.13
# 1998-02-10 10:38:00 2.478946 5.7 0.077661304 0.12 0.03076093 0.02
# 1998-03-10 12:10:00 27.455605 12.6 0.21253688 0.095 0.0337061 0.03
# 1998-04-14 12:45:00 1.588981 2.6 0.024566295 0.026 0.02975323 0.01
# 1998-05-12 11:50:00 4.530811 2.6 0.198170074 0.15 0.034129 0.02
# 1998-05-27 13:15:00 13.644638 158.0 0.672882751 2.4 0.042495 0.3
# 1998-07-14 11:28:00 1.048183 1.0 0.020016812 0.38 0.012610262 0.05
# 1998-08-11 11:30:00 1.0 3.4 0.020001382 0.02 0.0080086 0.02
# 1998-09-15 13:00:00 1.0 4.5 0.020001862 0.19 0.0063617 0.02
# 1998-10-13 10:50:00 14.498261 17.5 1.67489978 0.8 0.039715 0.06
# 1998-10-28 13:40:00 15.191916 20.6 1.898553589 1.2 0.0340595 0.05
# 1998-11-10 11:40:00 2.353952 1.5 0.100280922 0.21 0.01570468 0.02
# 1998-12-07 09:55:00 68.067375 25.5 0.105260338 0.2 0.039018 0.03
# 1999-01-20 17:10:00 273.978821 19.2 0.021622123 0.035 0.0437554 0.02
# 1999-03-09 12:20:00 14.964836 7.0 0.119913429 0.041 0.0274839 0.02
# 1999-04-13 11:20:00 1.868405 2.9 0.039974775 0.023 0.03037585 0.01
# 1999-05-11 10:45:00 2.226167 3.1 0.103719231 0.038 0.0309468 0.01
# 1999-06-24 12:25:00 51.347431 241.0 1.645137085 5.3 0.192311 0.22
# 1999-07-13 12:15:00 1.0 2.4 0.020001931 0.053 0.018527 0.01
# 1999-08-10 11:07:00 1.0 3.4 0.020000921 0.082 0.011431 0.02
# 1999-09-14 11:27:00 1.0 2.8 0.020001727 0.093 0.0077134 0.01
# 1999-10-12 10:51:00 2.946491 4.3 0.277382233 0.08 0.01583868 0.03
# 1999-11-09 11:47:00 7.645575 8.8 0.859926697 0.23 0.0284198 0.03
# 1999-12-06 11:40:00 68.562172 10.7 0.118664146 0.22 0.0323034 0.02
# 2000-01-12 10:50:00 11.944041 5.6 0.099964172 0.051 0.0383181 0.02
# 2000-02-01 17:50:00 127.668205 155.0 0.360435883 0.44 0.116079 0.12
# 2000-03-14 10:38:00 8.963846 11.1 0.541206116 0.052 0.0362225 0.03
# 2000-04-11 12:01:00 1.092693 4.2 0.020156122 0.11 0.029469 0.01
# 2000-05-09 13:10:00 7.276657 16.7 0.73087561 0.9 0.0377686 0.04
# 2000-06-12 12:00:00 62.123501 220.0 0.763075317 2.7 0.190804 0.15
# 2000-07-11 10:30:00 1.0 2.1 0.020405872 0.18 0.020662 0.0048
# 2000-08-01 12:20:00 1.0 3.4 0.020000986 0.18 0.013943 0.06
# 2000-10-10 11:07:00 9.23445 10.4 1.494770508 0.65 0.0362388 0.04
# 2000-11-08 14:35:00 19.386461 30.7 1.233650757 2.6 0.072008 0.09
# 2000-12-12 09:35:00 1.45009 3.0 0.020092916 0.11 0.0255823 0.02
# 2001-01-09 11:45:00 7.971661 4.1 0.093395599 0.051 0.0514 0.02
# 2001-02-13 11:14:00 1.327605 3.1 0.020105931 0.028 0.028225802 0.01
# 2001-03-06 11:30:00 1.014842 3.0 0.020039078 0.031 0.027448 0.02
# 2001-04-10 10:22:00 20.64467 9.1 0.895515076 0.062 0.0436473 0.02
# 2001-05-15 10:10:00 12.92193 16.5 0.743095642 0.68 0.0367189 0.04
# 2001-06-11 12:29:00 37.555496 99.3 1.805158447 2.2 0.15444 0.12
# 2001-07-10 11:28:00 1.0 1.68 0.020000618 0.14 0.018824 0.01
# 2001-08-14 11:45:00 1.0 1.8 0.02000091 0.16 0.0095968 0.03
# 2001-09-11 11:40:00 1.0 4.2 0.020000816 0.16 0.0086315 0.03
# 2001-10-09 10:55:00 4.382676 7.6 0.723096924 0.29 0.0159123 0.05
# 2001-11-14 21:00:00 314.693451 650.0 0.112954056 2.2 0.173396 0.27
# 2001-12-11 11:26:00 19.635366 6.4 0.028831321 0.032 0.0300905 0.02

# %% [markdown]
# Compute <b><span style="color:#f00">R<sup>2</sup></span></b> and <b><span style="color:#f00">Nash</span></b> between sim. and obs. flow

# %%
# average of sim
sim_mean= sum(simflowdata[idx_flow][mask_flow])/float(len(simflowdata[idx_flow][mask_flow]))
# average of obs
obs_mean= sum(obsflowdata[mask_flow])/float(len(obsflowdata[mask_flow]))
# total sum of squares 
ss_tot = sum((x-obs_mean)**2 for x in obsflowdata[mask_flow]) 
# sum of squares of residuals
ss_err = sum((y-x)**2 for y,x in zip(simflowdata[idx_flow][mask_flow],obsflowdata[mask_flow]))

nash_flow = 1 - (ss_err/ss_tot)
print "nash_flow= ", nash_flow

gradient, intercept, r_value, p_value, std_err = stats.linregress(simflowdata[idx_flow][mask_flow],obsflowdata[mask_flow])
print "R-squared = ", r_value**2
if gradient <= 1:
  adj_r2 = gradient * (r_value**2)
  print "adj_r2 =", adj_r2
if gradient > 1:
  adj_r2 = gradient**(-1) * (r_value**2)
  print "adj_r2 =", adj_r2
# Out:
# nash_flow=  0.836778256598
# R-squared =  0.858674024116
# adj_r2 = 0.740619577846

# %% [markdown]
# Compute <b><span style="color:#f00">R<sup>2</sup></span></b> between sim. and obs. sediment

# %%
# average of sim
sim_mean= sum(FsimSed)/float(len(FsimSed))

print "sim_mean = ", sim_mean
obs_mean= sum(FobsSed)/float(len(FobsSed))

# total sum of squares 
ss_tot = sum((x-obs_mean)**2 for x in FobsSed) 

# sum of squares of residuals
ss_err = sum((y-x)**2 for y,x in zip(FsimSed,FobsSed))
nash_sed = 1 - (ss_err/ss_tot)
print "nash_sed = ", nash_sed

gradient, intercept, r_value, p_value, std_err = stats.linregress(FsimSed,FobsSed)
r2_sed = r_value**2
print "Sediment R-squared = ", r2_sed
if gradient <= 1:
  adj_r2_sed = gradient * (r_value**2)
  print "adj_r2_sed =", adj_r2_sed
if gradient > 1:
  adj_r2_sed = gradient**(-1) * (r_value**2)
  print "adj_r2_sed =", adj_r2_sed
# Out:
# sim_mean =  67.6422661121
# nash_sed =  -1.01659228775
# Sediment R-squared =  0.897750747656
# adj_r2_sed = 0.36574033481

# %% [markdown]
# Compute <b><span style="color:#f00">R<sup>2</sup></span></b> between sim. and obs. coliform

# %%
# average of sim
sim_mean= sum(FsimOther)/float(len(FsimOther))
obs_mean= sum(FobsOther)/float(len(FobsOther))

# total sum of squares 
ss_tot = sum((x-obs_mean)**2 for x in FobsOther) 
# sum of squares of residuals
ss_err = sum((y-x)**2 for y,x in zip(FsimOther,FobsOther))


nash_col = 1 - (ss_err/ss_tot)
print "nash_col= ", nash_col

gradient, intercept, r_value, p_value, std_err = stats.linregress(FsimOther,FobsOther)
r2_col = r_value**2
print "R-squared = ", r2_col
if gradient <= 1:
  adj_r2_col = gradient * (r_value**2)
  print "adj_r2_col =", adj_r2_col
if gradient > 1:
  adj_r2_col = gradient**(-1) * (r_value**2)
  print "adj_r2_col =", adj_r2_col
# Out:
# nash_col=  0.174172423977
# R-squared =  0.24725659191
# adj_r2_col = 0.162826251423

# %%
sim_mean= sum(FsimTP)/float(len(FsimTP))
obs_mean= sum(FobsTP)/float(len(FobsTP))

# total sum of squares 
ss_tot = sum((x-obs_mean)**2 for x in FobsTP) 
# sum of squares of residuals
ss_err = sum((y-x)**2 for y,x in zip(FsimTP,FobsTP))

nash_TP = 1 - (ss_err/ss_tot)
print "nash_TP= ", nash_TP

gradient, intercept, r_value, p_value, std_err = stats.linregress(FsimTP, FobsTP)
r2_TP = r_value**2
print "R-squared = ", r2_TP
if gradient <= 1:
  adj_r2_TP = gradient * (r_value**2)
  print "adj_r2_TP =", adj_r2_TP
if gradient > 1:
  adj_r2_TP = gradient**(-1) * (r_value**2)
  print "adj_r2_TP =", adj_r2_TP
# Out:
# nash_TP=  0.499784002406
# R-squared =  0.629595500444
# adj_r2_TP = 0.358808545373

# %% [markdown]
# Plot the time series of **sim. vs. obs daily streamflows **in cms.

# %%
##############################################################################################
#################################Plot the Discrete Time Series################################
##############################################################################################
# reconstruct the date objects with matching dates only 
fdate=[]
for i in idx_flow:
  if i >=0 :
    fdate.append(datetime.datetime.strptime(tempsimflowdate[i],'%m/%d/%Y'))
ssim = pd.Series(simflowdata[idx_flow][mask_flow], index=fdate)
sobs = pd.Series(obsflowdata[mask_flow], index=fdate)

fig=plt.figure(figsize=(17,5),dpi=400)
ax = plt.subplot()
fig.text(0.7, 0.8, r'$Nash=%.2f$' % nash_flow, fontsize=15)
title('daily streamflow', fontsize=14., y=1.02, fontweight='bold')
plt.ylabel('flow. ($m^{3}\,s^{-1}$)', fontsize=12.)
plt.xlabel('year', fontsize=12.)

# s=square, -=dash, g^=triangle
ssim['1993':'2008'].plot(label='Sim', color='red', linewidth=2.0)
sobs['1993':'2008'].plot(label='Obs',color ='blue')

grid(True)
#tight_layout()
ax.legend(loc='best')
savefig('D:\\Dropbox\\Python_Scripts\\Issaquah\\flow.png',dpi=500,format = 'png',transparent='True')

##############################################################################################
#########################################Plot the CDF#########################################
##############################################################################################
fig=plt.figure(figsize=(7,5),dpi=400)
ax = plt.subplot()
n = len(ssim)

# log-normal probability plot
d = np.linspace(1, n, num=n)/(n+1)
y  = norm.ppf(d,0,1);

# create the axis ticks
p  = [0.001, 0.01, 0.05, 0.2, 0.5, 0.75, 0.90, 0.98, 0.999];
# relate var "p" with "y"
tick  = norm.ppf(p,0,1);
label = ['0.001','0.01','0.05','0.2','0.5','0.75','0.90','0.98','0.999'];
# recast the p to (0,1)

# sort the data in an ascending order
ssim.sort()
sobs.sort()
ax.plot(y,ssim, 'r+', label='sim')
ax.plot(y,sobs,'b*', label='obs')

# use numpoints option so the markeres don't appear twice in one legend
ax.legend(loc=(0.05,0.8),numpoints = 1)
plt.ylabel('flow. ($m^{3}\,s^{-1}$)', fontsize=12.)
plt.xlabel('cumulative prob.', fontsize=12.)
ax = gca()
ax.xaxis.set_major_locator(ticker.FixedLocator(tick))
ax.xaxis.set_major_formatter(ticker.FixedFormatter(label))
grid(True)
# save the figure to the folder
savefig('D:\\Dropbox\\Python_Scripts\\Issaquah\\flow_cdf.png',dpi=500,format = 'png',transparent='True')

# %% [markdown]
# Plot the time series of **simuted sediment concentrations**.

# %% [markdown]
# Plot the **Sim** vs. **obs** monthly **sediment conc**

# %%
##############################################################################################
#################################Plot the Discrete Time Series################################
##############################################################################################
# reconstruct the date objects with matching dates only 

ssim = pd.Series(FsimSed, index=Fsimdate)
sobs = pd.Series(FobsSed, index=Fobsdate)


fig=plt.figure(figsize=(12,5),dpi=400)
ax = plt.subplot()
fig.text(0.7, 0.8, r'$R^2=%.2f$' % r2_sed, fontsize=16)
#fig.text(0.87, 0.85, "A", fontsize=18)
title('sediment concentration (calibration, 2002-2008)' , fontsize=14., y=1.05, fontweight='bold')
plt.ylabel('conc. (mg/l)', fontsize=14.)
plt.xlabel('year', fontsize=14.)
plt.tick_params(axis='both', which='major', labelsize=14)

# s=square, -=dash, g^=triangle
ssim['1993':'2008'].plot(label='Sim', color ='red', linewidth=2)
#sobs['1993':'2009'].plot(label='Obs', style='o', markersize=4)
sobs['1993':'2008'].plot(label='Obs', color ='blue', style='-o', markersize=4)
#sobs['1993':'2009'].plot(label='Obs', color ='blue', style='-o',fontsize=14,markersize=2)

# Plot the error bar for selected data (greater values than a threshold)
c = []
d = []
e = []
f = []
for i in range(len(FsimSed)):
    if (FsimSed[i] > 30 or FobsSed[i] > 30):
        f.append(Fsimdate[i])
        c.append(FsimSed[i])
        d.append(FsimSedPost[i]) 
        e.append(FsimSedPre[i])
a = c - pd.DataFrame([d, c, e]).min()
b = pd.DataFrame([d, c, e]).max() - c

errorbar(f, c, yerr=[a, b], fmt=None, ecolor='grey', lw=8, capsize=3, capthick=2)

grid(True)
#tight_layout()
ax.legend(loc='best')
savefig('D:\\Dropbox\\Python_Scripts\\Issaquah\\sed1.png',dpi=500,format = 'png',transparent='True')

##############################################################################################
#########################################Plot the CDF#########################################
##############################################################################################
fig=plt.figure(figsize=(7,5),dpi=400)
ax = plt.subplot()
n = len(sobs)
# log-normal probability plot
d = np.linspace(1, n, num=n)/(n+1)
y  = norm.ppf(d,0,1);


junk = FsimSed + FsimSedPre + FsimSedPost
nn = len(junk)
dd = np.linspace(1, nn, num=nn)/(nn+1)
yy  = norm.ppf(dd,0,1);

# create the axis ticks
p  = [0.001, 0.01, 0.05, 0.2, 0.5, 0.75, 0.90, 0.98, 0.999];
# relate var "p" with "y"
tick  = norm.ppf(p,0,1);
label = ['0.001','0.01','0.05','0.2','0.5','0.75','0.90','0.98','0.999'];
# recast the p to (0,1)

# sort the data in an ascending order
ssim.sort()
sobs.sort()
junk.sort()
# plot with simulation points that align with the obs
#ax.plot(y, ssim, 'r+', label='sim')
# plot with all points within 9-hour interval of obs collection time.
ax.plot(yy, junk, 'r+', label='sim')
ax.plot(y, sobs,'b*', label='obs')

# use numpoints option so the markeres don't appear twice in one legend
ax.legend(loc=(0.05,0.8),numpoints = 1)
plt.ylabel('conc. (mg/l)', fontsize=12.)
plt.xlabel('cumulative prob.', fontsize=12.)
ax = gca()
ax.xaxis.set_major_locator(ticker.FixedLocator(tick))
ax.xaxis.set_major_formatter(ticker.FixedFormatter(label))
grid(True)
# save the figure to the folder
savefig('D:\\Dropbox\\Python_Scripts\\Issaquah\\sed_cdf1.png',dpi=500,format = 'png',transparent='True')

# %%
##############################################################################################
#################################Plot the Discrete Time Series################################
##############################################################################################
# reconstruct the date objects with matching dates only 

ssim = pd.Series(FsimSed, index=Fsimdate)
sobs = pd.Series(FobsSed, index=Fobsdate)


fig=plt.figure(figsize=(12,5),dpi=400)
ax = plt.subplot()
fig.text(0.7, 0.8, r'$R^2=%.2f$' % r2_sed, fontsize=16)
#fig.text(0.87, 0.85, "A", fontsize=18)
title('sediment concentration (validation, 1993-2001)' , fontsize=14., y=1.05, fontweight='bold')
plt.ylabel('conc. (mg/l)', fontsize=14.)
plt.xlabel('year', fontsize=14.)
plt.tick_params(axis='both', which='major', labelsize=14)
#pylab.ylim([0, 500])

# s=square, -=dash, g^=triangle
ssim['1993':'2001'].plot(label='Sim', color ='red', linewidth=2)
#sobs['1993':'2009'].plot(label='Obs', style='o', markersize=4)
sobs['1993':'2001'].plot(label='Obs', color ='blue', style='-o', markersize=4)
#sobs['1993':'2009'].plot(label='Obs', color ='blue', style='-o',fontsize=14,markersize=2)

# Plot the error bar for selected data (greater values than a threshold)
c = []
d = []
e = []
f = []
for i in range(len(FsimSed)):
    if (FsimSed[i] > 30 or FobsSed[i] > 30):
        f.append(Fsimdate[i])
        c.append(FsimSed[i])
        d.append(FsimSedPost[i]) 
        e.append(FsimSedPre[i])
a = c - pd.DataFrame([d, c, e]).min()
b = pd.DataFrame([d, c, e]).max() - c

errorbar(f, c, yerr=[a, b], fmt=None, ecolor='grey', lw=8, capsize=3, capthick=2)

grid(True)
#tight_layout()
ax.legend(loc='best')
savefig('D:\\Dropbox\\Python_Scripts\\Issaquah\\sed2.png',dpi=500,format = 'png',transparent='True')

##############################################################################################
#########################################Plot the CDF#########################################
##############################################################################################
fig=plt.figure(figsize=(7,5),dpi=400)
ax = plt.subplot()
n = len(sobs)
# log-normal probability plot
d = np.linspace(1, n, num=n)/(n+1)
y  = norm.ppf(d,0,1);


junk = FsimSed + FsimSedPre + FsimSedPost
nn = len(junk)
dd = np.linspace(1, nn, num=nn)/(nn+1)
yy  = norm.ppf(dd,0,1);

# create the axis ticks
p  = [0.001, 0.01, 0.05, 0.2, 0.5, 0.75, 0.90, 0.98, 0.999];
# relate var "p" with "y"
tick  = norm.ppf(p,0,1);
label = ['0.001','0.01','0.05','0.2','0.5','0.75','0.90','0.98','0.999'];
# recast the p to (0,1)

# sort the data in an ascending order
ssim.sort()
sobs.sort()
junk.sort()
# plot with simulation points that align with the obs
#ax.plot(y, ssim, 'r+', label='sim')
# plot with all points within 9-hour interval of obs collection time.
ax.plot(yy, junk, 'r+', label='sim')
ax.plot(y, sobs,'b*', label='obs')

# use numpoints option so the markeres don't appear twice in one legend
ax.legend(loc=(0.05,0.8),numpoints = 1)
plt.ylabel('conc. (mg/l)', fontsize=12.)
plt.xlabel('cumulative prob.', fontsize=12.)
ax = gca()
ax.xaxis.set_major_locator(ticker.FixedLocator(tick))
ax.xaxis.set_major_formatter(ticker.FixedFormatter(label))
grid(True)
# save the figure to the folder
savefig('D:\\Dropbox\\Python_Scripts\\Issaquah\\sed_cdf2.png',dpi=500,format = 'png',transparent='True')

# %% [markdown]
# <font color='blue'>**Log-transform** Sediment Concentration</font>

# %%
# log scale
FsimSed2 = np.log(FsimSed)
FobsSed2 = np.log(FobsSed)
FsimSedPost2 = np.log(FsimSedPost)
FsimSedPre2 = np.log(FsimSedPre)

ssim = pd.Series(FsimSed2, index=Fsimdate)
sobs = pd.Series(FobsSed2, index=Fobsdate)

startdate = datetime.datetime(2002,10,1)
enddate = datetime.datetime(2008,10,1)

fig=plt.figure(figsize=(12,5),dpi=400)
ax = plt.subplot()
fig.text(0.7, 0.8, r'$R^2=%.2f$' % r2_sed, fontsize=16)
#fig.text(0.87, 0.85, "B", fontsize=18)
title('log-scale sediment concentration', fontsize=14., y=1.05, fontweight='bold')
plt.ylabel('log-scale conc. (log-mg/l)', fontsize=14.)
plt.xlabel('year', fontsize=14.)
plt.tick_params(axis='both', which='major', labelsize=14)

# s=square, -=dash, g^=triangle
ssim['1993':'2001'].plot(label='Sim', color='red', linewidth=2)
sobs['1993':'2001'].plot(label='Obs', color ='blue', style='-o', markersize=4)
pylab.ylim([0,10])

# find out the element-wise min and max among three series
# a, b must be relative errors rather than absolute values
a = FsimSed2 - pd.DataFrame([FsimSedPost2, FsimSed2, FsimSedPre2]).min()
b = pd.DataFrame([FsimSedPost2, FsimSed2, FsimSedPre2]).max()-FsimSed2

#print zip(Fsimdate, FsimOther, a, b)

# shaded uncertainty envelope plotting
#fill_between(Fsimdate, a, b, facecolor='grey', interpolate=True)

# uncertainty plot plotting
#errorbar(Fsimdate, FsimOther, yerr=[a, b], fmt=None, ecolor='g', capthick=2)


grid(True)
#tight_layout()
ax.legend(loc='best')
savefig('D:\\Dropbox\\Python_Scripts\\Issaquah\\sed_cdf3.png',dpi=500,format = 'png',transparent='True')

# %%
ssim = pd.Series(FsimSed, index=Fsimdate)
sobs = pd.Series(FobsSed, index=Fobsdate)

fig=plt.figure(figsize=(17,5),dpi=400)
ax = plt.subplot()
fig.text(0.7, 0.8, r'$R^2=%.2f$' % r2_sed, fontsize=16)
#fig.text(0.87, 0.85, "A", fontsize=18)
title('sediment concentration' , fontsize=14., y=1.05, fontweight='bold')
plt.ylabel('conc. (mg/l)', fontsize=14.)
plt.xlabel('year', fontsize=14.)
plt.tick_params(axis='both', which='major', labelsize=14)

# s=square, -=dash, g^=triangle
ssim['1993':'2008'].plot(label='Sim', color ='red', style='-o', markersize=2)
sobs['1993':'2008'].plot(label='Obs', color ='blue', style='-o', markersize=2)

grid(True)
#tight_layout()
ax.legend(loc='best')
savefig('D:\\Dropbox\\Python_Scripts\\Mercer\\sediment.png',dpi=500,format = 'png',transparent='True')

plt.show()

# %% [markdown]
# Plot the **Sim** vs. **obs** monthly **coliform conc**

# %%
ssim = pd.Series(FsimOther, index=Fsimdate)
sobs = pd.Series(FobsOther, index=Fobsdate)

fig=plt.figure(figsize=(12,5),dpi=400)
ax = plt.subplot()
fig.text(0.7, 0.8, r'$R^2=%.2f$' % r2_col, fontsize=16)
#fig.text(0.87, 0.85, "A", fontsize=18)
title('coliform concentration (calibration, 2002-2008)' , fontsize=14., y=1.05, fontweight='bold')
plt.ylabel('conc. (1000 CFU/100ml)', fontsize=14.)
plt.xlabel('year', fontsize=14.)
plt.tick_params(axis='both', which='major', labelsize=14)
pylab.ylim([0, 5])
# s=square, -=dash, g^=triangle
ssim['2002':'2008'].plot(label='Sim', color ='red', linewidth=2)
sobs['2002':'2008'].plot(label='Obs', color ='blue', style='-o', markersize=4)

# Plot the error bar for selected data (greater values than a threshold)
c = []
d = []
e = []
f = []
for i in range(len(FsimSed)):
    if (FsimOther[i] > 0.01 or FobsOther[i] > 0.01):
        f.append(Fsimdate[i])
        c.append(FsimOther[i])
        d.append(FsimOtherPost[i]) 
        e.append(FsimOtherPre[i])
a = c - pd.DataFrame([d, c, e]).min()
b = pd.DataFrame([d, c, e]).max() - c

errorbar(f, c, yerr=[a, b], fmt=None, ecolor='grey', lw=8, capsize=3, capthick=2)

grid(True)
#tight_layout()
ax.legend(loc='best')
savefig('D:\\Dropbox\\Python_Scripts\\Issaquah\\coliform1.png',dpi=500,format = 'png',transparent='True')

plt.show()

##############################################################################################
##############################################################################################
#########################################Plot the CDF#########################################
##############################################################################################
fig=plt.figure(figsize=(7,5),dpi=400)
ax = plt.subplot()
n = len(sobs)
# log-normal probability plot
d = np.linspace(1, n, num=n)/(n+1)
y  = norm.ppf(d,0,1);


junk = FsimOther + FsimOtherPre + FsimOtherPost
nn = len(junk)
dd = np.linspace(1, nn, num=nn)/(nn+1)
yy  = norm.ppf(dd,0,1);

# create the axis ticks
p  = [0.001, 0.01, 0.05, 0.2, 0.5, 0.75, 0.90, 0.98, 0.999];
# relate var "p" with "y"
tick  = norm.ppf(p,0,1);
label = ['0.001','0.01','0.05','0.2','0.5','0.75','0.90','0.98','0.999'];
# recast the p to (0,1)

# sort the data in an ascending order
ssim.sort()
sobs.sort()
junk.sort()
# plot with simulation points that align with the obs
#ax.plot(y, ssim, 'r+', label='sim')
# plot with all points within 9-hour interval of obs collection time.
ax.plot(yy, junk, 'r+', label='sim')
ax.plot(y, sobs,'b*', label='obs')

# use numpoints option so the markeres don't appear twice in one legend
ax.legend(loc=(0.05,0.8),numpoints = 1)
plt.ylabel('conc. (1000 CFU/100ml)', fontsize=12.)
plt.xlabel('cumulative prob.', fontsize=12.)
ax = gca()
ax.xaxis.set_major_locator(ticker.FixedLocator(tick))
ax.xaxis.set_major_formatter(ticker.FixedFormatter(label))
pylab.ylim([0, 5])
grid(True)
# save the figure to the folder
savefig('D:\\Dropbox\\Python_Scripts\\Issaquah\\coliform_cdf1.png',dpi=500,format = 'png',transparent='True')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-001125e9d977> in <module>()
#      12 pylab.ylim([0, 5])
#      13 # s=square, -=dash, g^=triangle
# ---> 14 ssim['2002':'2008'].plot(label='Sim', color ='red', linewidth=2)
#      15 sobs['2002':'2008'].plot(label='Obs', color ='blue', style='-o', markersize=4)
#      16
#
# D:\Tools\Anaconda\lib\site-packages\pandas\tools\plotting.pyc in plot_series(series, label, kind, use_index, rot, xticks, yticks, xlim, ylim, ax, style, grid, legend, logx, logy, secondary_y, **kwds)
#    1827                      secondary_y=secondary_y, **kwds)
#    1828
# -> 1829     plot_obj.generate()
#    1830     plot_obj.draw()
#    1831
#
# D:\Tools\Anaconda\lib\site-packages\pandas\tools\plotting.pyc in generate(self)
#     901     def generate(self):
#     902         self._args_adjust()
# --> 903         self._compute_plot_data()
#     904         self._setup_subplots()
#     905         self._make_plot()
#
# D:\Tools\Anaconda\lib\site-packages\pandas\tools\plotting.pyc in _compute_plot_data(self)
#     982         if is_empty:
#     983             raise TypeError('Empty {0!r}: no numeric data to '
# --> 984                             'plot'.format(numeric_data.__class__.__name__))
#     985
#     986         self.data = numeric_data
#
# TypeError: Empty 'Series': no numeric data to plot

# %%
ssim = pd.Series(FsimOther, index=Fsimdate)
sobs = pd.Series(FobsOther, index=Fobsdate)

fig=plt.figure(figsize=(12,5),dpi=400)
ax = plt.subplot()
fig.text(0.7, 0.8, r'$R^2=%.2f$' % r2_col, fontsize=16)
#fig.text(0.87, 0.85, "A", fontsize=18)
title('coliform validation (calibration, 1993-2001)' , fontsize=14., y=1.05, fontweight='bold')
plt.ylabel('conc. (CFU/100ml)', fontsize=14.)
plt.xlabel('year', fontsize=14.)
plt.tick_params(axis='both', which='major', labelsize=14)

# s=square, -=dash, g^=triangle
ssim['1993':'2000'].plot(label='Sim', color ='red', linewidth=2)
sobs['1993':'2000'].plot(label='Obs', color ='blue', style='-o', markersize=4)

# Plot the error bar for selected data (greater values than a threshold)
c = []
d = []
e = []
f = []
for i in range(len(FsimSed)):
    if (FsimSed[i] > 20 or FobsSed[i] > 20):
        f.append(Fsimdate[i])
        c.append(FsimOther[i])
        d.append(FsimOtherPost[i]) 
        e.append(FsimOtherPre[i])
a = c - pd.DataFrame([d, c, e]).min()
b = pd.DataFrame([d, c, e]).max() - c

errorbar(f, c, yerr=[a, b], fmt=None, ecolor='grey', lw=8, capsize=3, capthick=2)

grid(True)
#tight_layout()
ax.legend(loc='best')
savefig('D:\\Dropbox\\Python_Scripts\\Issaquah\\coliform2.png',dpi=500,format = 'png',transparent='True')
plt.show()

##############################################################################################
##############################################################################################
#########################################Plot the CDF#########################################
##############################################################################################
fig=plt.figure(figsize=(7,5),dpi=400)
ax = plt.subplot()
n = len(sobs)
# log-normal probability plot
d = np.linspace(1, n, num=n)/(n+1)
y  = norm.ppf(d,0,1);


junk = FsimOther + FsimOtherPre + FsimOtherPost
nn = len(junk)
dd = np.linspace(1, nn, num=nn)/(nn+1)
yy  = norm.ppf(dd,0,1);

# create the axis ticks
p  = [0.001, 0.01, 0.05, 0.2, 0.5, 0.75, 0.90, 0.98, 0.999];
# relate var "p" with "y"
tick  = norm.ppf(p,0,1);
label = ['0.001','0.01','0.05','0.2','0.5','0.75','0.90','0.98','0.999'];
# recast the p to (0,1)

# sort the data in an ascending order
ssim.sort()
sobs.sort()
junk.sort()
# plot with simulation points that align with the obs
#ax.plot(y, ssim, 'r+', label='sim')
# plot with all points within 9-hour interval of obs collection time.
ax.plot(yy, junk, 'r+', label='sim')
ax.plot(y, sobs,'b*', label='obs')

# use numpoints option so the markeres don't appear twice in one legend
ax.legend(loc=(0.05,0.8),numpoints = 1)
plt.ylabel('conc. (mg/l)', fontsize=12.)
plt.xlabel('cumulative prob.', fontsize=12.)
ax = gca()
ax.xaxis.set_major_locator(ticker.FixedLocator(tick))
ax.xaxis.set_major_formatter(ticker.FixedFormatter(label))
grid(True)
# save the figure to the folder
savefig('D:\\Dropbox\\Python_Scripts\\Issaquah\\coliform_cdf2.png',dpi=500,format = 'png',transparent='True')

# %%
ssim = pd.Series(FsimTP, index=Fsimdate)
sobs = pd.Series(FobsTP, index=Fobsdate)

fig=plt.figure(figsize=(12,5),dpi=400)
ax = plt.subplot()
fig.text(0.7, 0.8, r'$R^2=%.2f$' % r2_TP, fontsize=16)
#fig.text(0.87, 0.85, "A", fontsize=18)
title('TP concentration (calibration, 2002-2008)', fontsize=14., y=1.05, fontweight='bold')
plt.ylabel('conc. (mg/l)', fontsize=14.)
plt.xlabel('year', fontsize=14.)
plt.tick_params(axis='both', which='major', labelsize=14)
pylab.ylim([0, 0.7])

# s=square, -=dash, g^=triangle
ssim['2002':'2008'].plot(label='Sim', color ='red', linewidth=2)
sobs['2002':'2008'].plot(label='Obs', color ='blue', style='-o', markersize=4)

# Plot the error bar for selected data (greater values than a threshold)
c = []
d = []
e = []
f = []
for i in range(len(FsimSed)):
    if (FsimTP[i] > 0.1 or FobsTP[i] > 0.1):
        f.append(Fsimdate[i])
        c.append(FsimTP[i])
        d.append(FsimTPPost[i]) 
        e.append(FsimTPPre[i])
a = c - pd.DataFrame([d, c, e]).min()
b = pd.DataFrame([d, c, e]).max() - c

errorbar(f, c, yerr=[a, b], fmt=None, ecolor='grey', lw=8, capsize=3, capthick=2)
grid(True)
#tight_layout()
ax.legend(loc='best')
savefig('D:\\Dropbox\\Python_Scripts\\Issaquah\\TP1.png',dpi=500,format = 'png',transparent='True')
plt.show()

# %%
fig=plt.figure(figsize=(7,5),dpi=400)
ax = plt.subplot()
n = len(sobs)
# log-normal probability plot
d = np.linspace(1, n, num=n)/(n+1)
y  = norm.ppf(d,0,1);


junk = FsimTP + FsimTPPre + FsimTPPost
nn = len(junk)
dd = np.linspace(1, nn, num=nn)/(nn+1)
yy  = norm.ppf(dd,0,1);

# create the axis ticks
p  = [0.001, 0.01, 0.05, 0.2, 0.5, 0.75, 0.90, 0.98, 0.999];
# relate var "p" with "y"
tick  = norm.ppf(p,0,1);
label = ['0.001','0.01','0.05','0.2','0.5','0.75','0.90','0.98','0.999'];
# recast the p to (0,1)

# sort the data in an ascending order
ssim.sort()
sobs.sort()
junk.sort()
# plot with simulation points that align with the obs
#ax.plot(y, ssim, 'r+', label='sim')
# plot with all points within 9-hour interval of obs collection time.
ax.plot(yy, junk, 'r+', label='sim')
ax.plot(y, sobs,'b*', label='obs')

# use numpoints option so the markeres don't appear twice in one legend
ax.legend(loc=(0.05,0.8),numpoints = 1)
plt.ylabel('conc. (mg/l)', fontsize=12.)
plt.xlabel('cumulative prob.', fontsize=12.)
ax = gca()
ax.xaxis.set_major_locator(ticker.FixedLocator(tick))
ax.xaxis.set_major_formatter(ticker.FixedFormatter(label))
grid(True)
# save the figure to the folder
savefig('D:\\Dropbox\\Python_Scripts\\Issaquah\\TP_cdf1.png',dpi=500,format = 'png',transparent='True')

# %%
ssim = pd.Series(FsimTP, index=Fsimdate)
sobs = pd.Series(FobsTP, index=Fobsdate)

fig=plt.figure(figsize=(12,5),dpi=400)
ax = plt.subplot()
fig.text(0.7, 0.8, r'$R^2=%.2f$' % r2_TP, fontsize=16)
#fig.text(0.87, 0.85, "A", fontsize=18)
title('TP concentration (validation, 1993-2001)', fontsize=14., y=1.05, fontweight='bold')
plt.ylabel('conc. (mg/l)', fontsize=14.)
plt.xlabel('year', fontsize=14.)
plt.tick_params(axis='both', which='major', labelsize=14)
pylab.ylim([0,1.5])

# s=square, -=dash, g^=triangle
ssim['1993':'2001'].plot(label='Sim', color ='red', linewidth=2)
sobs['1993':'2001'].plot(label='Obs', color ='blue', style='-o', markersize=4)

# Plot the error bar for selected data (greater values than a threshold)
c = []
d = []
e = []
f = []
for i in range(len(FsimSed)):
    if (FsimTP[i] > 0.2 or FobsTP[i] > 0.2):
        f.append(Fsimdate[i])
        c.append(FsimTP[i])
        d.append(FsimTPPost[i]) 
        e.append(FsimTPPre[i])
a = c - pd.DataFrame([d, c, e]).min()
b = pd.DataFrame([d, c, e]).max() - c

errorbar(f, c, yerr=[a, b], fmt=None, ecolor='grey', lw=8, capsize=3, capthick=2)

grid(True)
#tight_layout()
ax.legend(loc='best')
savefig('D:\\Dropbox\\Python_Scripts\\Issaquah\\TP2.png',dpi=500,format = 'png',transparent='True')
plt.show()
#################################################################################################
fig=plt.figure(figsize=(7,5),dpi=400)
ax = plt.subplot()
n = len(sobs)
# log-normal probability plot
d = np.linspace(1, n, num=n)/(n+1)
y  = norm.ppf(d,0,1);


junk = FsimTP + FsimTPPre + FsimTPPost
nn = len(junk)
dd = np.linspace(1, nn, num=nn)/(nn+1)
yy  = norm.ppf(dd,0,1);

# create the axis ticks
p  = [0.001, 0.01, 0.05, 0.2, 0.5, 0.75, 0.90, 0.98, 0.999];
# relate var "p" with "y"
tick  = norm.ppf(p,0,1);
label = ['0.001','0.01','0.05','0.2','0.5','0.75','0.90','0.98','0.999'];
# recast the p to (0,1)

# sort the data in an ascending order
ssim.sort()
sobs.sort()
junk.sort()
# plot with simulation points that align with the obs
#ax.plot(y, ssim, 'r+', label='sim')
# plot with all points within 9-hour interval of obs collection time.
ax.plot(yy, junk, 'r+', label='sim')
ax.plot(y, sobs,'b*', label='obs')

# use numpoints option so the markeres don't appear twice in one legend
ax.legend(loc=(0.05,0.8),numpoints = 1)
plt.ylabel('conc. (mg/l)', fontsize=12.)
plt.xlabel('cumulative prob.', fontsize=12.)
ax = gca()
ax.xaxis.set_major_locator(ticker.FixedLocator(tick))
ax.xaxis.set_major_formatter(ticker.FixedFormatter(label))
grid(True)
# save the figure to the folder
savefig('D:\\Dropbox\\Python_Scripts\\Issaquah\\TP_cdf2.png',dpi=500,format = 'png',transparent='True')
