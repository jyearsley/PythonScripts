# %% [markdown]
# ###This notebook includes Python tools for analyzing DHSVM outputs.
# Time series data are analyzed with **numpy** and **pandas** tools and plotted with **matplotlib**. Spatial maps are analyzed and plotted using **netCDF4** and **Basemap** utilities. In general, the scripts that needs to be changed (eg. file path, locations, time range, and variables to plot, etc) are on top of the coding block if there's any. However, differences in the input data may require changing the code, such as which columns to read as the dates, how many rows to skip as the header, etc. Currently all input file paths are absolute paths so you should be able to run the code as it is and plot from my output files. All plots are saved into a pdf page (specify the file name in the second code block). Note that you'll have to run the last code block to close the pdf file you opened in order to view the file correctly.

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['norm', 'f', 'e', 'gradient']
# `%matplotlib` prevents importing * from pylab and numpy

# %% [markdown]
# **First**, import all necessary libraries.

# %%
# Import all needed libraries 
import sys, os, datetime, time
import numpy as np
import pandas as pd
import numpy.ma as ma
import math
import matplotlib.dates as dates
import matplotlib.ticker as ticker
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
from scipy.stats import norm
from scipy import stats

import os
os.getcwd() 
os.chdir("D:\\Dropbox\\Python_Scripts")
os.getcwd()
# Out:
# 'D:\\Dropbox\\Python_Scripts'

# %% [markdown]
# Read the input **streamflow** files (change the path if needed)<br>
# <span style="background-color: #FFFF00">**<span style="color:#f00">Attention</span>**: the last date in obs. file **MUST NOT** exceed the last date of sim.</span>

# %%
# Enter file path for sim. and obs. flow files
simflowpath = 'D:\\Dropbox\\Python_Scripts\\Swamp\\daily_flow.txt'
obsflowpath = 'D:\\Dropbox\\Python_Scripts\\Swamp\\streamflow.12127100.cms.txt'

# Read flow sim and obs dates &  data
simflowdata = np.genfromtxt(simflowpath, usecols=[1])
obsflowdata = np.genfromtxt(obsflowpath, usecols=[1])
tempsimflowdate = np.genfromtxt(simflowpath, dtype = str, skiprows = 0, usecols = 0)
tempobsflowdate = np.genfromtxt(obsflowpath, dtype = str, skiprows = 0, usecols = 0)

# %% [markdown]
# **Sort** and **match** the obs. and sim. flow files based on dates.<br>

# %%
# Convert the string format dates into a datetime object
simflowdate = []
for i in range(len(tempsimflowdate)):
    simflowdate.append(datetime.datetime.strptime(tempsimflowdate[i],'%m/%d/%Y'))
# sort the dates in an acending order
simflowdate.sort()

# Convert the string format dates into a datetime object
obsflowdate = []
for i in range(len(tempobsflowdate)):
    obsflowdate.append(datetime.datetime.strptime(tempobsflowdate[i],'%Y-%m-%d'))
# sort the dates in an acending order
obsflowdate.sort()

# extract the matching dates from both arrays and mark them by mask
# searchsorted(t1,t2) finds index in t1 for every value in t2:    
idx_flow = np.searchsorted(simflowdate, obsflowdate, side='right')-1
j2 = [i for i in idx_flow if i > 0]

# mask the array as true if 
mask_flow = idx_flow >=0

# compare the obs. and sim. time series
df = pd.DataFrame({"simflowdate":tempsimflowdate[idx_flow][mask_flow], "simflow":simflowdata[idx_flow][mask_flow], \
                   "obsflow":obsflowdata[mask_flow], "obsflowdate":tempobsflowdate[mask_flow]})

#print df
#print df.values

# %% [markdown]
# Read the input **water quality**files (change the path if needed)<br>
# <span style="background-color: #FFFF00">**<span style="color:#f00">Attention</span>**: the last date in obs. file **MUST NOT** exceed the last date of sim.</span>

# %%
# Initialize a pdf file for saving all the figures
# pdfpages = PdfPages('test_figure.pdf')

# Enter file path for swater quality simulation files
simsedfilepath = 'D:\\Dropbox\\Python_Scripts\\Swamp\\Sed.Flow.Only'
simotherfilepath = 'D:\\Dropbox\\Python_Scripts\\Swamp\\Other.Conc.Only'
simOrgPfilepath = 'D:\\Dropbox\\Python_Scripts\\Swamp\\OrgP.Conc.Only'
simSolPfilepath = 'D:\\Dropbox\\Python_Scripts\\Swamp\\solP.Conc.Only'

# Enter file path for observed water quality variable files
obsfilepath = 'D:\\Dropbox\\Python_Scripts\\Swamp\\swamp-time-stamped-validation.txt'

# Enter file path for observed precipitation files
precipfilepath = 'D:\\Dropbox\\Python_Scripts\\Swamp\\Mass.Balance'

# Read dates of sims (continuous)
tempsimdates = np.genfromtxt(simsedfilepath, dtype=str, skiprows=2, usecols=0)

# Read dates of obs (discrete). Use the 2nd column
tempobsdates = np.genfromtxt(obsfilepath, dtype=str, skiprows=1, usecols=0)

# Read sediment sims (use the 2nd col)
simseddata = np.genfromtxt(simsedfilepath, skiprows=2, usecols=[2])
simseddata = simseddata + 1.2
# Read sediment obs.
# Skip the first line, and use the 5th column for sed
obsseddata = np.genfromtxt(obsfilepath, dtype=float, skiprows=1, usecols=[2])

# Read other data
simotherdata = np.genfromtxt(simotherfilepath, skiprows=2, usecols=[1])
simotherdata = simotherdata/0.01444
print len(simotherdata)
#print simotherdata
obsotherdata = np.genfromtxt(obsfilepath, dtype=float, skiprows=1, usecols=[1])
obsotherdata = obsotherdata;

# Read obs. precipitation data
precipdata = np.genfromtxt(precipfilepath, dtype=float, skiprows=24, usecols=[9])
print len(precipdata)

# Read P (phosphorous) data
simOrgnPdata = np.genfromtxt(simOrgPfilepath, skiprows=2, usecols=[1])
simSolPdata = np.genfromtxt(simSolPfilepath, skiprows=2, usecols=[1])
simTPdata = simOrgnPdata + simSolPdata
obsTPdata = np.genfromtxt(obsfilepath, dtype=float, skiprows=1, usecols=[6])
# Out:
# 56256
# 56256

# %% [markdown]
# **Third**, find out the dates when both sims and obs (discontinous) are available.
#
# <span style="background-color: #FFFF00">**Particular attention** needs to be paid on **<span style="color:#f00">np.searchsorted()</span>**. Output all matching columns to make sure its the right match. Right now, the option **side='right'** must be used in the case of **daily time step (mm/dd/yy)** to avoid the 1-day mismatch. Later when working with **3-hourly set**, this may not hold.</span>

# %%
#######dates###########
simdates = []
Fsimdate = []
Fobsdate = []
########sediment#######
FsimSed = []
FsimSedPre = []
FsimSedPost = []
FobsSed = []
########coliform#######
FsimOther = []
FsimOtherPre = []
FsimOtherPost = []
FobsOther = []
######phosphorous######
FsimTP = []
FsimTPPre = []
FsimTPPost = []
FobsTP = []
#######################

# construct the sim. date obj.
for i in range(len(tempsimdates)):
    simdates.append(datetime.datetime.strptime(tempsimdates[i],'%m/%d/%Y-%H:%M:%S'))
simdates.sort()
# construct the obs. date obj.
obsdates = []
for i in range(len(tempobsdates)):
    obsdates.append(datetime.datetime.strptime(tempobsdates[i],'%m/%d/%Y-%H:%M:%S'))
obsdates.sort()


for i in range(len(obsdates)):
    obs = dates.date2num(obsdates[i])
    junk = date2num(simdates)
    #value = obsdates[i]
    idx = (np.abs(junk-obs)).argmin()
    if (idx-1 > 0 and (idx+1)< len(simdates)):
      Fsimdate.append(simdates[idx])
      Fobsdate.append(obsdates[i])
      #
      FsimSed.append(simseddata[idx])
      FsimSedPre.append(simseddata[idx-1])
      FsimSedPost.append(simseddata[idx+1])
      FobsSed.append(obsseddata[i])
      #
      FobsOther.append(obsotherdata[i])
      FsimOther.append(simotherdata[idx])
      FsimOtherPre.append(simotherdata[idx-1])
      FsimOtherPost.append(simotherdata[idx+1])
      #
      FobsTP.append(obsTPdata[i])
      FsimTP.append(simTPdata[idx])
      FsimTPPre.append(simTPdata[idx-1])
      FsimTPPost.append(simTPdata[idx+1])

# unit conversion (divide by 1000)
for i in range(len(FsimOther)):
    FsimOther[i]= FsimOther[i]/1000
    FobsOther[i] = FobsOther[i]/1000
    FsimOtherPost[i] = FsimOtherPost[i]/1000 
    FsimOtherPre[i] = FsimOtherPre[i]/1000 

for i in range(len(FsimSed)):
    #print Fsimdate[i], FsimSed[i], FobsSed[i], FsimOther[i], FobsOther[i]
    print Fsimdate[i], FsimOther[i], FsimOtherPre[i], FsimOtherPost[i], Fobsdate[i], FobsOther[i]
    #print Fsimdate[i], FsimTP[i], Fobsdate[i], FobsTP[i]
# Out:
# 1993-01-11 12:00:00 0.000207063711911 0.000205193905817 0.000154362880886 1993-01-11 10:40:00 0.016
# 1993-02-16 12:00:00 0.00025595567867 0.000365581717452 0.000344806094183 1993-02-16 12:00:00 0.037
# 1993-03-08 09:00:00 0.00018324099723 0.000171398891967 5.95567867036e-05 1993-03-08 10:00:00 0.032
# 1993-03-22 15:00:00 2.13916308864 2.34803199446 1.97438518006 1993-03-22 15:25:00 0.057
# 1993-04-12 09:00:00 0.333895637119 0.333712811634 0.305453185596 1993-04-12 10:20:00 0.13
# 1993-05-10 09:00:00 0.0441434210526 0.0342349030471 0.0320292243767 1993-05-10 10:25:00 0.1
# 1993-07-12 12:00:00 0.000903808864266 0.000410180055402 0.000370083102493 1993-07-12 11:25:00 0.27
# 1993-08-11 12:00:00 0.0 0.0 0.0 1993-08-11 11:25:00 0.27
# 1993-09-20 15:00:00 2.82177250693 3.55708157895 2.51921738227 1993-09-20 15:15:00 0.57
# 1993-10-11 12:00:00 0.0 0.0 0.0 1993-10-11 10:40:00 0.1
# 1993-11-15 12:00:00 1.22754529086 1.0521648892 1.24471523546 1993-11-15 11:15:00 0.09
# 1993-12-13 12:00:00 0.557691620499 0.527847853186 0.52930567867 1993-12-13 11:05:00 0.32
# 1993-12-20 12:00:00 0.000382756232687 0.000415858725762 0.000299861495845 1993-12-20 10:35:00 0.021
# 1994-01-18 12:00:00 0.000325346260388 0.000347922437673 0.000254639889197 1994-01-18 11:50:00 0.06
# 1994-02-15 09:00:00 0.815352631579 0.754009764543 0.830106232687 1994-02-15 09:40:00 0.11
# 1994-02-22 12:00:00 0.439734972299 0.42683898892 0.407877285319 1994-02-22 11:55:00 0.22
# 1994-03-14 09:00:00 0.000901177285319 0.000910595567867 0.00050311634349 1994-03-14 10:30:00 0.03
# 1994-04-11 09:00:00 0.00106495844875 0.00131052631579 0.00051135734072 1994-04-11 10:28:00 0.12
# 1994-05-16 12:00:00 1.28197444598 1.33889958449 1.12052174515 1994-05-16 10:50:00 2.5
# 1994-06-20 12:00:00 0.0 0.0 0.0 1994-06-20 11:45:00 1.0
# 1994-07-11 12:00:00 0.0 0.0 0.0 1994-07-11 11:05:00 0.36
# 1994-08-10 12:00:00 0.000141620498615 0.000146537396122 0.00014175900277 1994-08-10 11:45:00 0.22
# 1994-10-10 12:00:00 0.128494529086 0.127720498615 0.0411114958449 1994-10-10 11:10:00 0.21
# 1994-10-26 06:00:00 3.76344265928 2.36826945983 3.24891745152 1994-10-26 06:55:00 1.6
# 1994-10-31 03:00:00 1.22789501385 0.0797290858726 1.95251412742 1994-10-31 03:03:00 2.5
# 1994-11-07 12:00:00 0.281389196676 0.25438732687 0.253499584488 1994-11-07 11:20:00 0.067
# 1994-12-12 12:00:00 0.0363663434903 0.0071040166205 0.0394252770083 1994-12-12 11:15:00 0.053
# 1995-01-09 12:00:00 0.750656371191 0.729510110803 0.728495290859 1995-01-09 11:19:00 0.17
# 1995-02-14 12:00:00 0.403138296399 0.00253434903047 1.10336475069 1995-02-14 11:05:00 0.05
# 1995-03-09 09:00:00 1.47553504155 1.48125304709 1.36591087258 1995-03-09 10:30:00 0.9
# 1995-03-13 12:00:00 0.543969182825 0.549019529086 0.527703601108 1995-03-13 10:50:00 0.07
# 1995-04-10 12:00:00 0.33886398892 0.364680193906 0.313883240997 1995-04-10 12:25:00 0.04
# 1995-05-02 09:00:00 2.18649674515 2.18813587258 1.99179951524 1995-05-02 10:26:00 2.3
# 1995-05-08 12:00:00 0.000150831024931 0.000602631578947 9.54293628809e-05 1995-05-08 11:00:00 0.13
# 1995-06-12 09:00:00 0.397949238227 0.283798961219 0.279626038781 1995-06-12 10:02:00 0.17
# 1995-07-17 09:00:00 0.0 0.0 0.0 1995-07-17 10:27:00 0.33
# 1995-08-14 09:00:00 0.000140373961219 0.000138434903047 0.000142451523546 1995-08-14 10:22:00 0.06
# 1995-09-18 09:00:00 0.0 0.0 0.0 1995-09-18 10:20:00 0.16
# 1995-10-16 12:00:00 2.23195533241 2.5673567867 1.91869432133 1995-10-16 11:25:00 0.54
# 1995-11-13 12:00:00 0.139616966759 0.133387465374 0.122899307479 1995-11-13 11:15:00 0.045
# 1995-12-01 12:00:00 0.082638365651 0.0698198753463 0.0726278393352 1995-12-01 12:30:00 0.12
# 1996-01-08 12:00:00 0.0275150969529 0.0606450831025 0.013438365651 1996-01-08 11:00:00 0.087
# 1996-02-12 09:00:00 0.00177001385042 0.00194252077562 0.00133199445983 1996-02-12 10:25:00 0.15
# 1996-03-11 09:00:00 0.283767867036 0.275588434903 0.279197229917 1996-03-11 10:10:00 0.27
# 1996-04-01 09:00:00 1.66799819945 1.70129078947 1.55525048476 1996-04-01 09:50:00 0.42
# 1996-04-15 09:00:00 1.24603573407 1.10568698061 1.23236253463 1996-04-15 09:50:00 0.29
# 1996-05-15 12:00:00 0.00894646814404 0.0212882963989 0.00485886426593 1996-05-15 10:55:00 0.43
# 1996-06-10 12:00:00 0.0 0.0 0.0 1996-06-10 11:10:00 0.12
# 1996-07-15 12:00:00 0.0 0.0 0.0 1996-07-15 11:35:00 0.18
# 1996-08-12 12:00:00 0.0 0.0 0.0 1996-08-12 11:15:00 0.23
# 1996-09-09 12:00:00 0.00123060941828 0.0227941828255 0.000573822714681 1996-09-09 12:25:00 0.1
# 1996-10-07 09:00:00 0.0 0.0 0.0 1996-10-07 10:15:00 0.14
# 1996-12-09 09:00:00 0.0338234072022 0.0628223684211 0.0339257617729 1996-12-09 10:05:00 0.055
# 1997-01-13 12:00:00 0.00042756232687 0.000368282548476 0.00023296398892 1997-01-13 11:30:00 0.04
# 1997-02-10 12:00:00 0.000199653739612 0.000218490304709 9.25900277008e-05 1997-02-10 10:52:00 0.032
# 1997-03-10 12:00:00 0.00107361495845 0.00160180055402 0.000395290858726 1997-03-10 10:50:00 0.035
# 1997-03-18 03:00:00 1.35088642659 0.287042243767 1.56150512465 1997-03-18 03:45:00 0.55
# 1997-04-07 09:00:00 0.000591897506925 0.000588573407202 0.000411911357341 1997-04-07 10:10:00 0.043
# 1997-05-12 12:00:00 0.0 0.000146537396122 0.000115581717452 1997-05-12 10:47:00 0.12
# 1997-06-09 09:00:00 0.0 2.8324099723e-05 0.0 1997-06-09 10:26:00 0.16
# 1997-07-07 12:00:00 0.252651523546 0.320989819945 0.0256070637119 1997-07-07 11:25:00 0.41
# 1997-08-11 09:00:00 0.0 0.0 0.0 1997-08-11 10:20:00 0.21
# 1997-09-08 09:00:00 0.0 0.0 0.0 1997-09-08 09:55:00 0.094
# 1997-10-02 12:00:00 1.35456412742 1.40313019391 1.26038864266 1997-10-02 10:35:00 1.3
# 1997-10-13 09:00:00 0.0393467451524 0.0360335180055 0.0145368421053 1997-10-13 10:15:00 0.07
# 1997-10-29 06:00:00 2.40487763158 1.47250367036 2.29646253463 1997-10-29 06:30:00 2.7
# 1997-12-08 09:00:00 0.423023614958 0.593404501385 1.014933241 1997-12-08 10:20:00 0.12
# 1998-02-09 09:00:00 0.0743051939058 0.0764965373961 0.0765059556787 1998-02-09 10:15:00 0.07
# 1998-04-13 09:00:00 0.00068324099723 0.000956301939058 0.00036364265928 1998-04-13 09:45:00 0.062
# 1998-05-11 12:00:00 0.143574168975 0.111155955679 0.090837465374 1998-05-11 10:40:00 0.15
# 1998-06-22 12:00:00 0.0 0.0 0.0 1998-06-22 10:41:00 0.08
# 1998-07-13 12:00:00 9.52216066482e-05 9.4944598338e-05 9.54986149584e-05 1998-07-13 10:45:00 0.15
# 1998-08-10 09:00:00 0.0 0.0 0.0 1998-08-10 10:20:00 0.19
# 1998-09-14 12:00:00 0.0 0.0 0.0 1998-09-14 10:55:00 0.19
# 1998-10-12 12:00:00 2.17298192521 2.37301772853 1.93943926593 1998-10-12 10:35:00 0.5
# 1998-10-28 12:00:00 1.99047880886 2.04007721607 1.81112950139 1998-10-28 12:04:00 1.9
# 1998-11-09 09:00:00 0.153100969529 0.0984871191136 0.163703462604 1998-11-09 09:48:00 0.1
# 1998-12-07 09:00:00 0.452007548476 0.434255609418 0.47099265928 1998-12-07 10:20:00 0.2
# 1998-12-28 09:00:00 0.0771574792244 0.100978739612 0.0828995152355 1998-12-28 09:45:00 0.06
# 1999-01-19 09:00:00 0.891626038781 0.894402631579 0.884523060942 1999-01-19 10:08:00 3.8
# 1999-02-08 12:00:00 0.219704639889 0.213257894737 0.202808240997 1999-02-08 11:25:00 0.18
# 1999-03-08 12:00:00 0.293170360111 0.0267121191136 0.368369252078 1999-03-08 11:20:00 0.064
# 1999-04-12 12:00:00 0.0734501385042 0.0869648891967 0.046941066482 1999-04-12 10:33:00 0.061
# 1999-05-10 12:00:00 0.00443614958449 0.0202951523546 0.000151523545706 1999-05-10 12:25:00 0.068
# 1999-06-14 12:00:00 0.0 0.0 0.0 1999-06-14 10:50:00 0.08
# 1999-06-24 15:00:00 2.43918504155 2.71660734072 2.24357749307 1999-06-24 14:10:00 4.6
# 1999-07-12 09:00:00 0.0 0.0 0.0 1999-07-12 10:25:00 0.06
# 1999-08-09 12:00:00 0.161336842105 0.237223407202 0.0152139889197 1999-08-09 10:42:00 0.079
# 1999-08-09 12:00:00 0.161336842105 0.237223407202 0.0152139889197 1999-08-09 10:50:00 0.084
# 1999-09-13 12:00:00 0.0 0.0 0.0 1999-09-13 10:45:00 0.15
# 1999-10-11 12:00:00 0.265523407202 0.251550761773 0.216790235457 1999-10-11 10:58:00 0.16
# 1999-11-09 09:00:00 3.0131234072 3.41031322715 2.67245429363 1999-11-09 10:23:00 0.9
# 1999-12-06 12:00:00 0.532576385042 0.524046537396 0.523524307479 1999-12-06 12:00:00 0.29
# 1999-12-13 12:00:00 0.265184418283 0.257655817175 0.250348199446 1999-12-13 10:45:00 0.084
# 2000-01-10 12:00:00 0.690053254848 0.0468144044321 0.446785595568 2000-01-10 10:55:00 0.14
# 2000-02-01 03:00:00 1.49520200831 0.469738919668 2.2726867036 2000-02-01 04:29:00 0.53
# 2000-02-29 06:00:00 0.876119113573 0.569187465374 0.942052700831 2000-02-29 07:25:00 0.22
# 2000-03-13 09:00:00 0.696247229917 0.615443351801 0.67079598338 2000-03-13 09:47:00 0.033
# 2000-04-10 12:00:00 0.000954501385042 0.00193871191136 0.000395844875346 2000-04-10 10:38:00 0.07
# 2000-04-10 12:00:00 0.000954501385042 0.00193871191136 0.000395844875346 2000-04-10 10:40:00 0.052
# 2000-05-08 12:00:00 0.291773476454 0.316949307479 0.221242867036 2000-05-08 12:09:00 0.2
# 2000-06-12 09:00:00 2.15334854571 2.02807056787 1.88634293629 2000-06-12 10:07:00 4.5
# 2000-07-10 12:00:00 0.0 0.0 0.0 2000-07-10 10:43:00 0.19
# 2000-07-31 12:00:00 0.0 0.0 0.0 2000-07-31 11:06:00 0.14
# 2000-09-11 12:00:00 1.23098296399 1.30522416898 0.987401592798 2000-09-11 11:30:00 0.24
# 2000-10-09 09:00:00 2.19027728532 1.84636578947 2.15043067867 2000-10-09 10:20:00 0.98
# 2000-11-08 06:00:00 2.39192347645 1.33774854571 2.26621308864 2000-11-08 06:31:00 3.4
# 2000-11-13 09:00:00 0.0 0.0 0.0 2000-11-13 10:29:00 0.14
# 2000-12-11 12:00:00 0.0246026315789 8.81578947368e-05 0.0314346952909 2000-12-11 12:15:00 0.081
# 2001-01-08 12:00:00 0.242212603878 0.0256450831025 0.255678531856 2001-01-08 10:40:00 0.059
# 2001-02-12 12:00:00 0.000479155124654 0.000683033240997 0.000449307479224 2001-02-12 10:44:00 0.059
# 2001-03-05 12:00:00 0.000252146814404 0.000493975069252 0.000306094182825 2001-03-05 11:20:00 0.052
# 2001-04-09 09:00:00 0.143079432133 0.0356043628809 0.0846063711911 2001-04-09 10:18:00 0.05
# 2001-04-30 12:00:00 1.36974099723 1.40230713296 1.22962285319 2001-04-30 11:25:00 0.52
# 2001-05-14 09:00:00 2.34023698061 2.22094501385 2.11933580332 2001-05-14 09:46:00 0.2
# 2001-06-11 06:00:00 5.80509217452 2.39936426593 3.89624459834 2001-06-11 06:32:00 7.8
# 2001-07-09 09:00:00 0.0 0.0 0.0 2001-07-09 10:16:00 0.12
# 2001-08-13 09:00:00 0.0 0.0 0.0 2001-08-13 10:09:00 0.17
# 2001-09-10 09:00:00 0.0 0.0 0.0 2001-09-10 10:20:00 0.18
# 2001-10-08 09:00:00 1.19948878116 0.975473614958 1.35252652355 2001-10-08 10:28:00 0.62
# 2001-11-14 12:00:00 2.4712998615 2.72561627424 2.28992236842 2001-11-14 10:54:00 4.5
# 2001-12-10 12:00:00 0.635548476454 0.636691759003 0.585197229917 2001-12-10 10:53:00 0.1

# %% [markdown]
# Compute <b><span style="color:#f00">R<sup>2</sup></span></b> between sim. and obs. sediment

# %%
# average of sim
sim_mean= sum(FsimSed)/float(len(FsimSed))

print "sim_mean = ", sim_mean
obs_mean= sum(FobsSed)/float(len(FobsSed))

# total sum of squares 
ss_tot = sum((x-obs_mean)**2 for x in FobsSed) 

# sum of squares of residuals
ss_err = sum((y-x)**2 for y,x in zip(FsimSed,FobsSed))
nash_sed = 1 - (ss_err/ss_tot)
print "nash_sed = ", nash_sed

gradient, intercept, r_value, p_value, std_err = stats.linregress(FsimSed,FobsSed)
r2_sed = r_value**2
print "Sediment R-squared = ", r2_sed
if gradient <= 1:
  adj_r2_sed = gradient * (r_value**2)
  print "adj_r2_sed =", adj_r2_sed
if gradient > 1:
  adj_r2_sed = gradient**(-1) * (r_value**2)
  print "adj_r2_sed =", adj_r2_sed
# Out:
# sim_mean =  3.87484321311
# nash_sed =  0.470004098082
# Sediment R-squared =  0.672638161092
# adj_r2_sed = 0.42611661627

# %% [markdown]
# Compute <b><span style="color:#f00">R<sup>2</sup></span></b> between sim. and obs. coliform

# %%
# average of sim
sim_mean= sum(FsimOther)/float(len(FsimOther))
obs_mean= sum(FobsOther)/float(len(FobsOther))

# total sum of squares 
ss_tot = sum((x-obs_mean)**2 for x in FobsOther) 
# sum of squares of residuals
ss_err = sum((y-x)**2 for y,x in zip(FsimOther,FobsOther))


nash_col = 1 - (ss_err/ss_tot)
print "nash_col= ", nash_col

gradient, intercept, r_value, p_value, std_err = stats.linregress(FsimOther,FobsOther)
r2_col = r_value**2
print "R-squared = ", r2_col
if gradient <= 1:
  adj_r2_col = gradient * (r_value**2)
  print "adj_r2_col =", adj_r2_col
if gradient > 1:
  adj_r2_col = gradient**(-1) * (r_value**2)
  print "adj_r2_col =", adj_r2_col
# Out:
# nash_col=  0.521870088791
# R-squared =  0.538596061111
# adj_r2_col = 0.465762992755

# %% [markdown]
# Compute <b><span style="color:#f00">R<sup>2</sup></span></b> between sim. and obs. Total Phosphorous

# %%
sim_mean= sum(FsimTP)/float(len(FsimTP))
obs_mean= sum(FobsTP)/float(len(FobsTP))

# total sum of squares 
ss_tot = sum((x-obs_mean)**2 for x in FobsTP) 
# sum of squares of residuals
ss_err = sum((y-x)**2 for y,x in zip(FsimTP,FobsTP))

nash_TP = 1 - (ss_err/ss_tot)
print "nash_TP= ", nash_TP

gradient, intercept, r_value, p_value, std_err = stats.linregress(FsimTP, FobsTP)
r2_TP = r_value**2
print "R-squared = ", r2_TP
if gradient <= 1:
  adj_r2_TP = gradient * (r_value**2)
  print "adj_r2_TP =", adj_r2_TP
if gradient > 1:
  adj_r2_TP = gradient**(-1) * (r_value**2)
  print "adj_r2_TP =", adj_r2_TP
# Out:
# nash_TP=  -0.0213395735547
# R-squared =  0.20388594648
# adj_r2_TP = 0.111126748208

# %% [markdown]
# Plot the **Sim** vs. **obs** monthly **sediment conc**

# %%
ssim = pd.Series(FsimSed, index=Fsimdate)
sobs = pd.Series(FobsSed, index=Fobsdate)

fig=plt.figure(figsize=(12,5),dpi=400)
ax = plt.subplot()
fig.text(0.7, 0.8, r'$R^2=%.2f$' % r2_sed, fontsize=16)
#fig.text(0.87, 0.85, "A", fontsize=18)
title('sediment concentration (calibration, 2002-2008)' , fontsize=14., y=1.05, fontweight='bold')
plt.ylabel('conc. (mg/l)', fontsize=14.)
plt.xlabel('year', fontsize=14.)
plt.tick_params(axis='both', which='major', labelsize=14)

# s=square, -=dash, g^=triangle
ssim['2002':'2008'].plot(label='Sim', color ='red', linewidth=2)
#sobs['1993':'2009'].plot(label='Obs', style='o', markersize=4)
sobs['2002':'2008'].plot(label='Obs', color ='blue', style='-o', markersize=4)
#sobs['1993':'2009'].plot(label='Obs', color ='blue', style='-o',fontsize=14,markersize=2)
pylab.ylim([0,100])

# Plot the error bar for selected data (greater values than a threshold)
c = []
d = []
e = []
f = []
for i in range(len(FsimSed)):
    if (FsimSed[i] > 30 or FobsSed[i] > 30):
        f.append(Fsimdate[i])
        c.append(FsimSed[i])
        d.append(FsimSedPost[i]) 
        e.append(FsimSedPre[i])
a = c - pd.DataFrame([d, c, e]).min()
b = pd.DataFrame([d, c, e]).max() - c

errorbar(f, c, yerr=[a, b], fmt=None, ecolor='grey', lw=8, capsize=3, capthick=2)

grid(True)
#tight_layout()
ax.legend(loc='best')
savefig('D:\\Dropbox\\Python_Scripts\\Swamp\\sed1.png',dpi=500,format = 'png',transparent='True')

##############################################################################################
#########################################Plot the CDF#########################################
##############################################################################################
fig=plt.figure(figsize=(7,5),dpi=400)
ax = plt.subplot()
n = len(sobs)
# log-normal probability plot
d = np.linspace(1, n, num=n)/(n+1)
y  = norm.ppf(d,0,1);


junk = FsimSed + FsimSedPre + FsimSedPost
nn = len(junk)
dd = np.linspace(1, nn, num=nn)/(nn+1)
yy  = norm.ppf(dd,0,1);

# create the axis ticks
p  = [0.001, 0.01, 0.05, 0.2, 0.5, 0.75, 0.90, 0.98, 0.999];
# relate var "p" with "y"
tick  = norm.ppf(p,0,1);
label = ['0.001','0.01','0.05','0.2','0.5','0.75','0.90','0.98','0.999'];
# recast the p to (0,1)

# sort the data in an ascending order
ssim.sort()
sobs.sort()
junk.sort()
# plot with simulation points that align with the obs
#ax.plot(y, ssim, 'r+', label='sim')
# plot with all points within 9-hour interval of obs collection time.
ax.plot(yy, junk, 'r+', label='sim')
ax.plot(y, sobs,'b*', label='obs')

# use numpoints option so the markeres don't appear twice in one legend
ax.legend(loc=(0.05,0.8),numpoints = 1)
plt.ylabel('conc. (mg/l)', fontsize=12.)
plt.xlabel('cumulative prob.', fontsize=12.)
ax = gca()
ax.xaxis.set_major_locator(ticker.FixedLocator(tick))
ax.xaxis.set_major_formatter(ticker.FixedFormatter(label))
grid(True)
# save the figure to the folder
savefig('D:\\Dropbox\\Python_Scripts\\Swamp\\sed_cdf1.png',dpi=500,format = 'png',transparent='True')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-616304644ddf> in <module>()
#      12
#      13 # s=square, -=dash, g^=triangle
# ---> 14 ssim['2002':'2008'].plot(label='Sim', color ='red', linewidth=2)
#      15 #sobs['1993':'2009'].plot(label='Obs', style='o', markersize=4)
#      16 sobs['2002':'2008'].plot(label='Obs', color ='blue', style='-o', markersize=4)
#
# D:\Tools\Anaconda\lib\site-packages\pandas\tools\plotting.pyc in plot_series(series, label, kind, use_index, rot, xticks, yticks, xlim, ylim, ax, style, grid, legend, logx, logy, secondary_y, **kwds)
#    1827                      secondary_y=secondary_y, **kwds)
#    1828
# -> 1829     plot_obj.generate()
#    1830     plot_obj.draw()
#    1831
#
# D:\Tools\Anaconda\lib\site-packages\pandas\tools\plotting.pyc in generate(self)
#     901     def generate(self):
#     902         self._args_adjust()
# --> 903         self._compute_plot_data()
#     904         self._setup_subplots()
#     905         self._make_plot()
#
# D:\Tools\Anaconda\lib\site-packages\pandas\tools\plotting.pyc in _compute_plot_data(self)
#     982         if is_empty:
#     983             raise TypeError('Empty {0!r}: no numeric data to '
# --> 984                             'plot'.format(numeric_data.__class__.__name__))
#     985
#     986         self.data = numeric_data
#
# TypeError: Empty 'Series': no numeric data to plot

# %%
ssim = pd.Series(FsimSed, index=Fsimdate)
sobs = pd.Series(FobsSed, index=Fobsdate)

fig=plt.figure(figsize=(12,5),dpi=400)
ax = plt.subplot()
fig.text(0.7, 0.8, r'$R^2=%.2f$' % r2_sed, fontsize=16)
#fig.text(0.87, 0.85, "A", fontsize=18)
title('sediment concentration (validation, 1993-2001)' , fontsize=14., y=1.05, fontweight='bold')
plt.ylabel('conc. (mg/l)', fontsize=14.)
plt.xlabel('year', fontsize=14.)
plt.tick_params(axis='both', which='major', labelsize=14)

# s=square, -=dash, g^=triangle
ssim['1993':'2001'].plot(label='Sim', color ='red', linewidth=2)
#sobs['1993':'2009'].plot(label='Obs', style='o', markersize=4)
sobs['1993':'2001'].plot(label='Obs', color ='blue', style='-o', markersize=4)
#sobs['1993':'2009'].plot(label='Obs', color ='blue', style='-o',fontsize=14,markersize=2)

# Plot the error bar for selected data (greater values than a threshold)
c = []
d = []
e = []
f = []
for i in range(len(FsimSed)):
    if (FsimSed[i] > 30 or FobsSed[i] > 30):
        f.append(Fsimdate[i])
        c.append(FsimSed[i])
        d.append(FsimSedPost[i]) 
        e.append(FsimSedPre[i])
a = c - pd.DataFrame([d, c, e]).min()
b = pd.DataFrame([d, c, e]).max() - c

errorbar(f, c, yerr=[a, b], fmt=None, ecolor='grey', lw=8, capsize=3, capthick=2)

grid(True)
#tight_layout()
ax.legend(loc='best')
savefig('D:\\Dropbox\\Python_Scripts\\Swamp\\sed2.png',dpi=500,format = 'png',transparent='True')

##############################################################################################
#########################################Plot the CDF#########################################
##############################################################################################
fig=plt.figure(figsize=(7,5),dpi=400)
ax = plt.subplot()
n = len(sobs)
# log-normal probability plot
d = np.linspace(1, n, num=n)/(n+1)
y  = norm.ppf(d,0,1);


junk = FsimSed + FsimSedPre + FsimSedPost
nn = len(junk)
dd = np.linspace(1, nn, num=nn)/(nn+1)
yy  = norm.ppf(dd,0,1);

# create the axis ticks
p  = [0.001, 0.01, 0.05, 0.2, 0.5, 0.75, 0.90, 0.98, 0.999];
# relate var "p" with "y"
tick  = norm.ppf(p,0,1);
label = ['0.001','0.01','0.05','0.2','0.5','0.75','0.90','0.98','0.999'];
# recast the p to (0,1)

# sort the data in an ascending order
ssim.sort()
sobs.sort()
junk.sort()
# plot with simulation points that align with the obs
#ax.plot(y, ssim, 'r+', label='sim')
# plot with all points within 9-hour interval of obs collection time.
ax.plot(yy, junk, 'r+', label='sim')
ax.plot(y, sobs,'b*', label='obs')

# use numpoints option so the markeres don't appear twice in one legend
ax.legend(loc=(0.05,0.8),numpoints = 1)
plt.ylabel('conc. (mg/l)', fontsize=12.)
plt.xlabel('cumulative prob.', fontsize=12.)
ax = gca()
ax.xaxis.set_major_locator(ticker.FixedLocator(tick))
ax.xaxis.set_major_formatter(ticker.FixedFormatter(label))
grid(True)
# save the figure to the folder
savefig('D:\\Dropbox\\Python_Scripts\\Swamp\\sed_cdf2.png',dpi=500,format = 'png',transparent='True')

# %% [markdown]
# Plot the **Sim** vs. **obs** monthly **coliform conc**

# %%
ssim = pd.Series(FsimOther, index=Fsimdate)
sobs = pd.Series(FobsOther, index=Fobsdate)

fig=plt.figure(figsize=(12,5),dpi=400)
ax = plt.subplot()
fig.text(0.7, 0.8, r'$R^2=%.2f$' % r2_col, fontsize=15)
title('coliform concentration (calibration, 2002-2008)' , fontsize=14., y=1.05, fontweight='bold')
plt.ylabel('conc. (1000 CFU/100ml)', fontsize=14.)
plt.xlabel('year', fontsize=14.)
plt.ylim([0,10])
# s=square, -=dash, g^=triangle
# s=square, -=dash, g^=triangle
ssim['1998':'2008'].plot(label='Sim', color ='red', linewidth=2)
sobs['1998':'2008'].plot(label='Obs', color ='blue', style='-o', markersize=4)

# Plot the error bar for selected data (greater values than a threshold)
c = []
d = []
e = []
f = []
for i in range(len(FsimSed)):
    if (FsimSed[i] > 20 or FobsSed[i] > 20):
        f.append(Fsimdate[i])
        c.append(FsimOther[i])
        d.append(FsimOtherPost[i]) 
        e.append(FsimOtherPre[i])
a = c - pd.DataFrame([d, c, e]).min()
b = pd.DataFrame([d, c, e]).max() - c

errorbar(f, c, yerr=[a, b], fmt=None, ecolor='grey', lw=8, capsize=3, capthick=2)

grid(True)
#tight_layout()
ax.legend(loc='best')
savefig('D:\\Dropbox\\Python_Scripts\\Swamp\\coliform1.png',dpi=500,format = 'png',transparent='True')

##############################################################################################
##############################################################################################
#########################################Plot the CDF#########################################
##############################################################################################
fig=plt.figure(figsize=(7,5),dpi=400)
ax = plt.subplot()
n = len(sobs)
# log-normal probability plot
d = np.linspace(1, n, num=n)/(n+1)
y  = norm.ppf(d,0,1);


junk = FsimOther + FsimOtherPre + FsimOtherPost
nn = len(junk)
dd = np.linspace(1, nn, num=nn)/(nn+1)
yy  = norm.ppf(dd,0,1);

# create the axis ticks
p  = [0.001, 0.01, 0.05, 0.2, 0.5, 0.75, 0.90, 0.98, 0.999];
# relate var "p" with "y"
tick  = norm.ppf(p,0,1);
label = ['0.001','0.01','0.05','0.2','0.5','0.75','0.90','0.98','0.999'];
# recast the p to (0,1)

# sort the data in an ascending order
ssim.sort()
sobs.sort()
junk.sort()
# plot with simulation points that align with the obs
#ax.plot(y, ssim, 'r+', label='sim')
# plot with all points within 9-hour interval of obs collection time.
ax.plot(yy, junk, 'r+', label='sim')
ax.plot(y, sobs,'b*', label='obs')

# use numpoints option so the markeres don't appear twice in one legend
ax.legend(loc=(0.05,0.8),numpoints = 1)
plt.ylabel('conc. (mg/l)', fontsize=12.)
plt.xlabel('cumulative prob.', fontsize=12.)
ax = gca()
ax.xaxis.set_major_locator(ticker.FixedLocator(tick))
ax.xaxis.set_major_formatter(ticker.FixedFormatter(label))
grid(True)
# save the figure to the folder
savefig('D:\\Dropbox\\Python_Scripts\\Swamp\\coliform_cdf1.png',dpi=500,format = 'png',transparent='True')

# %%
ssim = pd.Series(FsimOther, index=Fsimdate)
sobs = pd.Series(FobsOther, index=Fobsdate)

fig=plt.figure(figsize=(12,5),dpi=400)
ax = plt.subplot()
fig.text(0.7, 0.8, r'$R^2=%.2f$' % r2_col, fontsize=15)
title('coliform concentration (calibration, 2002-2008)' , fontsize=14., y=1.05, fontweight='bold')
plt.ylabel('conc. (1000 CFU/100ml)', fontsize=14.)
plt.xlabel('year', fontsize=14.)
plt.ylim([0,10])
# s=square, -=dash, g^=triangle
# s=square, -=dash, g^=triangle
ssim['1993':'2001'].plot(label='Sim', color ='red', linewidth=2)
sobs['1993':'2001'].plot(label='Obs', color ='blue', style='-o', markersize=4)

# Plot the error bar for selected data (greater values than a threshold)
c = []
d = []
e = []
f = []
for i in range(len(FsimSed)):
    if (FsimSed[i] > 20 or FobsSed[i] > 20):
        f.append(Fsimdate[i])
        c.append(FsimOther[i])
        d.append(FsimOtherPost[i]) 
        e.append(FsimOtherPre[i])
a = c - pd.DataFrame([d, c, e]).min()
b = pd.DataFrame([d, c, e]).max() - c

errorbar(f, c, yerr=[a, b], fmt=None, ecolor='grey', lw=8, capsize=3, capthick=2)

grid(True)
#tight_layout()
ax.legend(loc='best')
savefig('D:\\Dropbox\\Python_Scripts\\Swamp\\coliform2.png',dpi=500,format = 'png',transparent='True')

##############################################################################################
##############################################################################################
#########################################Plot the CDF#########################################
##############################################################################################
fig=plt.figure(figsize=(7,5),dpi=400)
ax = plt.subplot()
n = len(sobs)
# log-normal probability plot
d = np.linspace(1, n, num=n)/(n+1)
y  = norm.ppf(d,0,1);


junk = FsimOther + FsimOtherPre + FsimOtherPost
nn = len(junk)
dd = np.linspace(1, nn, num=nn)/(nn+1)
yy  = norm.ppf(dd,0,1);

# create the axis ticks
p  = [0.001, 0.01, 0.05, 0.2, 0.5, 0.75, 0.90, 0.98, 0.999];
# relate var "p" with "y"
tick  = norm.ppf(p,0,1);
label = ['0.001','0.01','0.05','0.2','0.5','0.75','0.90','0.98','0.999'];
# recast the p to (0,1)

# sort the data in an ascending order
ssim.sort()
sobs.sort()
junk.sort()
# plot with simulation points that align with the obs
#ax.plot(y, ssim, 'r+', label='sim')
# plot with all points within 9-hour interval of obs collection time.
ax.plot(yy, junk, 'r+', label='sim')
ax.plot(y, sobs,'b*', label='obs')

# use numpoints option so the markeres don't appear twice in one legend
ax.legend(loc=(0.05,0.8),numpoints = 1)
plt.ylabel('conc. (mg/l)', fontsize=12.)
plt.xlabel('cumulative prob.', fontsize=12.)
ax = gca()
ax.xaxis.set_major_locator(ticker.FixedLocator(tick))
ax.xaxis.set_major_formatter(ticker.FixedFormatter(label))
grid(True)
# save the figure to the folder
savefig('D:\\Dropbox\\Python_Scripts\\Swamp\\coliform_cdf2.png',dpi=500,format = 'png',transparent='True')

# %% [markdown]
# Plot the time series of **total phosphorous concentrations**.

# %%
ssim = pd.Series(FsimTP, index=Fsimdate)
sobs = pd.Series(FobsTP, index=Fobsdate)

fig=plt.figure(figsize=(12,5),dpi=400)
ax = plt.subplot()
fig.text(0.7, 0.8, r'$R^2=%.2f$' % r2_TP, fontsize=16)
#fig.text(0.87, 0.85, "A", fontsize=18)
title('TP concentration (calibration, 2002-2008)', fontsize=14., y=1.05, fontweight='bold')
plt.ylabel('conc. (mg/l)', fontsize=14.)
plt.xlabel('year', fontsize=14.)
plt.tick_params(axis='both', which='major', labelsize=14)
pylab.ylim([0, 0.3])

# s=square, -=dash, g^=triangle
ssim['2002':'2008'].plot(label='Sim', color ='red', linewidth=2)
sobs['2002':'2008'].plot(label='Obs', color ='blue', style='-o', markersize=4)

# Plot the error bar for selected data (greater values than a threshold)
c = []
d = []
e = []
f = []
for i in range(len(FsimSed)):
    if (FsimTP[i] > 0.1 or FobsTP[i] > 0.1):
        f.append(Fsimdate[i])
        c.append(FsimTP[i])
        d.append(FsimTPPost[i]) 
        e.append(FsimTPPre[i])
a = c - pd.DataFrame([d, c, e]).min()
b = pd.DataFrame([d, c, e]).max() - c

errorbar(f, c, yerr=[a, b], fmt=None, ecolor='grey', lw=8, capsize=3, capthick=2)
grid(True)
#tight_layout()
ax.legend(loc='best')
savefig('D:\\Dropbox\\Python_Scripts\\Swamp\\TP1.png',dpi=500,format = 'png',transparent='True')
plt.show()

# %%
fig=plt.figure(figsize=(7,5),dpi=400)
ax = plt.subplot()
n = len(sobs)
# log-normal probability plot
d = np.linspace(1, n, num=n)/(n+1)
y  = norm.ppf(d,0,1);


junk = FsimTP + FsimTPPre + FsimTPPost
nn = len(junk)
dd = np.linspace(1, nn, num=nn)/(nn+1)
yy  = norm.ppf(dd,0,1);

# create the axis ticks
p  = [0.001, 0.01, 0.05, 0.2, 0.5, 0.75, 0.90, 0.98, 0.999];
# relate var "p" with "y"
tick  = norm.ppf(p,0,1);
label = ['0.001','0.01','0.05','0.2','0.5','0.75','0.90','0.98','0.999'];
# recast the p to (0,1)

# sort the data in an ascending order
ssim.sort()
sobs.sort()
junk.sort()
# plot with simulation points that align with the obs
#ax.plot(y, ssim, 'r+', label='sim')
# plot with all points within 9-hour interval of obs collection time.
ax.plot(yy, junk, 'r+', label='sim')
ax.plot(y, sobs,'b*', label='obs')

# use numpoints option so the markeres don't appear twice in one legend
ax.legend(loc=(0.05,0.8),numpoints = 1)
plt.ylabel('conc. (mg/l)', fontsize=12.)
plt.xlabel('cumulative prob.', fontsize=12.)
ax = gca()
ax.xaxis.set_major_locator(ticker.FixedLocator(tick))
ax.xaxis.set_major_formatter(ticker.FixedFormatter(label))
grid(True)
# save the figure to the folder
savefig('D:\\Dropbox\\Python_Scripts\\Swamp\\TP_cdf1.png',dpi=500,format = 'png',transparent='True')

# %%
ssim = pd.Series(FsimTP, index=Fsimdate)
sobs = pd.Series(FobsTP, index=Fobsdate)

fig=plt.figure(figsize=(12,5),dpi=400)
ax = plt.subplot()
fig.text(0.7, 0.8, r'$R^2=%.2f$' % r2_TP, fontsize=16)
#fig.text(0.87, 0.85, "A", fontsize=18)
title('TP concentration (validation, 1993-2001)', fontsize=14., y=1.05, fontweight='bold')
plt.ylabel('conc. (mg/l)', fontsize=14.)
plt.xlabel('year', fontsize=14.)
plt.tick_params(axis='both', which='major', labelsize=14)
pylab.ylim([0,0.6])

# s=square, -=dash, g^=triangle
ssim['1993':'2001'].plot(label='Sim', color ='red', linewidth=2)
sobs['1993':'2001'].plot(label='Obs', color ='blue', style='-o', markersize=4)

# Plot the error bar for selected data (greater values than a threshold)
c = []
d = []
e = []
f = []
for i in range(len(FsimSed)):
    if (FsimTP[i] > 0.08 or FobsTP[i] > 0.08):
        f.append(Fsimdate[i])
        c.append(FsimTP[i])
        d.append(FsimTPPost[i]) 
        e.append(FsimTPPre[i])
a = c - pd.DataFrame([d, c, e]).min()
b = pd.DataFrame([d, c, e]).max() - c

errorbar(f, c, yerr=[a, b], fmt=None, ecolor='grey', lw=8, capsize=3, capthick=2)

grid(True)
#tight_layout()
ax.legend(loc='best')
savefig('D:\\Dropbox\\Python_Scripts\\Swamp\\TP2.png',dpi=500,format = 'png',transparent='True')
plt.show()
#################################################################################################
fig=plt.figure(figsize=(7,5),dpi=400)
ax = plt.subplot()
n = len(sobs)
# log-normal probability plot
d = np.linspace(1, n, num=n)/(n+1)
y  = norm.ppf(d,0,1);


junk = FsimTP + FsimTPPre + FsimTPPost
nn = len(junk)
dd = np.linspace(1, nn, num=nn)/(nn+1)
yy  = norm.ppf(dd,0,1);

# create the axis ticks
p  = [0.001, 0.01, 0.05, 0.2, 0.5, 0.75, 0.90, 0.98, 0.999];
# relate var "p" with "y"
tick  = norm.ppf(p,0,1);
label = ['0.001','0.01','0.05','0.2','0.5','0.75','0.90','0.98','0.999'];
# recast the p to (0,1)

# sort the data in an ascending order
ssim.sort()
sobs.sort()
junk.sort()
# plot with simulation points that align with the obs
#ax.plot(y, ssim, 'r+', label='sim')
# plot with all points within 9-hour interval of obs collection time.
ax.plot(yy, junk, 'r+', label='sim')
ax.plot(y, sobs,'b*', label='obs')

# use numpoints option so the markeres don't appear twice in one legend
ax.legend(loc=(0.05,0.8),numpoints = 1)
plt.ylabel('conc. (mg/l)', fontsize=12.)
plt.xlabel('cumulative prob.', fontsize=12.)
ax = gca()
ax.xaxis.set_major_locator(ticker.FixedLocator(tick))
ax.xaxis.set_major_formatter(ticker.FixedFormatter(label))
grid(True)
# save the figure to the folder
savefig('D:\\Dropbox\\Python_Scripts\\Swamp\\TP_cdf2.png',dpi=500,format = 'png',transparent='True')
