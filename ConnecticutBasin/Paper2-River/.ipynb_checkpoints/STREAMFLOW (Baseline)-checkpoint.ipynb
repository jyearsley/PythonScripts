# %% [markdown]
# ###This notebook includes Python scripts for plotting the streamflow at the location of main stem gages.

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['norm']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
# Import all needed libraries 
import sys, os, datetime, time
import collections
import numpy as np
import pandas as pd
import numpy.ma as ma
import math
import matplotlib.dates as dates
import matplotlib.ticker as ticker
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
from scipy.stats import norm
from scipy import stats

import os
os.getcwd() 
os.chdir("D:\\Dropbox\\Python_Scripts")
os.getcwd()
# Out:
# 'D:\\Dropbox\\Python_Scripts'

# %%
import matplotlib as mpl
mpl.rcParams['lines.linewidth'] = 2
font = {'family' : 'sans-serif',
        'sans-serif' : 'Verdana',
        'weight' : 'medium',
        'size'   : '12'}
params1 = {
          'axes.labelsize': 12,
          'text.fontsize': 12,
          'xtick.labelsize': 12,
          'xtick.direction': 'out',
          'ytick.labelsize': 12,
          'legend.pad': 0.01,     # empty space around the legend box
          'legend.fontsize': 12,
          'legend.labelspacing':0.25,
          'font.size': 12,
          'font.style': 'normal',
          'axes.style': 'normal',
          'xtick.labelstyle': 'normal',
          }
mpl.RcParams.update(params1)
mpl.rc('font', **font)
plt.rc("xtick", direction="out")
plt.rc("ytick", direction="out")
plt.rc('legend',**{'fontsize':12})

# %% [markdown]
# <font color='blue'>Read the input **streamflow** files (change the path if needed)</font>

# %%
obs_path = []
sim_path = []
mainpath = "D:\\Box Sync\\Connecticut_Basin\\TheRiver\\Streamflows\\"
gage_id = ['01129200', '01129500', '01131500', '01138500', '01144500', '01154500', '01170500', '01184000']
for i in range(len(gage_id)):
    obs_path.append('streamflow.'+str(gage_id[i])+'.cms')
    sim_path.append('DailyFlow.'+str(gage_id[i]))

# %%
print obs_path
# Out:
# ['streamflow.01129200.cms', 'streamflow.01129500.cms', 'streamflow.01131500.cms', 'streamflow.01138500.cms', 'streamflow.01144500.cms', 'streamflow.01154500.cms', 'streamflow.01170500.cms', 'streamflow.01184000.cms']

# %%
obsflowdata = {}
simflowdata = {}
tempobsflowdate = collections.defaultdict(list)
tempsimflowdate = collections.defaultdict(list)

# Read flow sim and obs dates & data
for i, n in enumerate(gage_id):
    simflowdata[n] = np.genfromtxt(str(mainpath)+str(sim_path[i]), dtype=float, usecols=[2])
    obsflowdata[n] = np.genfromtxt(str(mainpath)+str(obs_path[i]), dtype=float, usecols=[1])
    tempobsflowdate[n] = np.genfromtxt(str(mainpath)+str(obs_path[i]), dtype=str, skiprows=0, usecols=[0])
    tempsimflowdate[n] = np.genfromtxt(str(mainpath)+str(sim_path[i]), dtype=str, skiprows=0, usecols=[0])

# %% [markdown]
# <font color='blue'>Create panda series data.</font>

# %%
simflowdate = collections.defaultdict(list)
obsflowdate = collections.defaultdict(list)
DailyPrecip = {}
DailySimFlow = {}
DailyObsFlow = {}
MonthlySimFlow = {}
MonthlyObsFlow = {}

for i, n in enumerate(gage_id):
    for j in range(len(tempobsflowdate[n])):
        obsflowdate[n].append(datetime.datetime.strptime(tempobsflowdate[n][j],'%Y-%m-%d'))
    for j in range(len(tempsimflowdate[n])):
        simflowdate[n].append(datetime.datetime.strptime(tempsimflowdate[n][j],'%Y-%m-%d'))

# daily mean flow (unit: m^3/s)   
for i,n in enumerate(gage_id):
    DailySimFlow[n] = pd.Series(simflowdata[n], index=simflowdate[n])
    DailyObsFlow[n] = pd.Series(obsflowdata[n], index=obsflowdate[n])

# %% [markdown]
# <font color='blue'> **Truncate** the obs. and sim. flow files based on dates.</font>

# %%
gage_id = ['01129200', '01129500', '01131500', '01138500', '01144500', '01154500', '01170500', '01184000']
startdate = [datetime.datetime(1956,10,10), datetime.datetime(1930,10,1), datetime.datetime(1927,10,1), datetime.datetime(1950,1,1), datetime.datetime(1916,10,1), datetime.datetime(1942,3,6), datetime.datetime(1916,10,1), datetime.datetime(1928,10,1)] 
enddate = [datetime.datetime(2008,10,1), datetime.datetime(2008,10,1), datetime.datetime(2008,10,1), datetime.datetime(2008,10,1), datetime.datetime(2008,10,1), datetime.datetime(2008,10,1), datetime.datetime(2008,10,1), datetime.datetime(2008,10,1)]

# %%
# Truncate the data into desired time frame
for i, n in enumerate(gage_id):
        DailySimFlow[n] = DailySimFlow[n].truncate(before=startdate[i], after=enddate[i])
        DailyObsFlow[n] = DailyObsFlow[n].truncate(before=startdate[i], after=enddate[i])

# %% [markdown]
# <font color='blue'> **Monthly** obs. and sim. flow.</font>

# %%
# monthly mean flow for each year
for i,n in enumerate(gage_id):
    MonthlySimFlow[n] = DailySimFlow[n].resample('M', how='mean')
    MonthlyObsFlow[n] = DailyObsFlow[n].resample('M', how='mean')
    
# average monthly streamflow over the period
for i,n in enumerate(gage_id):
    MonthlySimFlow[n] = MonthlySimFlow[n].groupby(lambda x: x.month).mean()
    MonthlyObsFlow[n] = MonthlyObsFlow[n].groupby(lambda x: x.month).mean()

# %% [markdown]
# <font color='blue'>Compute **Nash** between sim. and obs. **daily** flow </font>

# %%
nash_flow = {}
for i, n in enumerate(gage_id):
    sim_mean= sum(DailySimFlow[n])/float(len(DailySimFlow[n]))
    print 'sim_mean: ',sim_mean
    obs_mean= sum(DailyObsFlow[n])/float(len(DailyObsFlow[n]))
    print 'obs_mean ',obs_mean
    ss_tot = sum((x-obs_mean)**2 for x in DailyObsFlow[n]) 
    ss_err = sum((y-x)**2 for y,x in zip(DailySimFlow[n], DailyObsFlow[n]))
    nash_flow[n] = 1 - (ss_err/ss_tot)
    print "gage[%s] daily flow nash = %.2f" % (str(gage_id[i]), nash_flow[n])
# Out:
# sim_mean:  10.6241708809
# obs_mean  16.1337671408
# gage[01129200] daily flow nash = -2.17
# sim_mean:  32.9702053458
# obs_mean  45.5506036547
# gage[01129500] daily flow nash = 0.49
# sim_mean:  61.3649642108
# obs_mean  83.3323667354
# gage[01131500] daily flow nash = 0.60
# sim_mean:  108.896915931
# obs_mean  144.523013063
# gage[01138500] daily flow nash = 0.63
# sim_mean:  168.627338414
# obs_mean  199.836852609
# gage[01144500] daily flow nash = 0.71
# sim_mean:  240.778120705
# obs_mean  277.872103959
# gage[01154500] daily flow nash = 0.76
# sim_mean:  323.882049413
# obs_mean  404.734895876
# gage[01170500] daily flow nash = 0.71
# sim_mean:  396.22627582
# obs_mean  483.292006441
# gage[01184000] daily flow nash = 0.73

# %% [markdown]
# <font color='blue'>Plot sim. and obs. flow</font>

# %%
fig=plt.figure(figsize=(14,28),dpi=400)
jj = 1
for i, n in enumerate(gage_id):
    ax = plt.subplot2grid((len(gage_id), 3), (0+i, 0), colspan=2)
    fig.subplots_adjust(hspace = 0.3, wspace = 0.4)
    props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
    textstr1 = '%s\nNash = %.2f' % (str(n), nash_flow[n])
    ax.text(.02,.78, textstr1, fontsize=12, horizontalalignment='left', transform=ax.transAxes, bbox=props)
    
    DailyObsFlow[n].plot(label='Obs', color='grey', linewidth=2, style='-', alpha=0.8)
    DailySimFlow[n].plot(label='Sim', color='blue', linewidth=2, style='-', alpha=0.8)
    ax.grid(True)
    if (i == 0):
        leg=ax.legend(loc=1, numpoints = 1)
        leg.get_frame().set_alpha(0.5)
    plt.ylabel('flow ($m^{3}/s$)', fontsize=12., labelpad=5)
    
    #################### Cumulative Distribution Function ####################
    jj = jj + 1
    ax = plt.subplot2grid((len(gage_id), 3), (0+i, 2), colspan=1)
    jj = jj + 1
    
    nn = len(DailySimFlow[n])
    # log-normal probability plot
    d = np.linspace(1, nn, num=nn)/(nn+1)
    y = norm.ppf(d, 0, 1)
        
    # create the axis ticks
    p  = [0.01, 0.2, 0.5, 0.90, 0.999];
    
    # relate var "p" with "y"
    tick  = norm.ppf(p,0,1);
    label = ['0.01','0.2','0.5','0.90','0.999'];
    
    # sort the data in an ascending order
    DailySimFlow[n].sort()
    DailyObsFlow[n].sort()
    ax.plot(y, DailyObsFlow[n],'*', color = '0.9', alpha = 0.8, label='obs')
    ax.plot(y, DailySimFlow[n], 'b+', label='sim')
    
    # use numpoints option so the markeres don't appear twice in one legend
    ax.xaxis.set_major_locator(ticker.FixedLocator(tick))
    ax.xaxis.set_major_formatter(ticker.FixedFormatter(label))
    ax.grid(True)
    
    # Changing the label's font-size
    ax.tick_params(axis='x', labelsize=11)
    
    if (i == 0):
        leg=ax.legend(loc='best', numpoints = 1)
        leg.get_frame().set_alpha(0.5)
    plt.ylabel('flow ($m^{3}/s$)', fontsize=12., labelpad=5)
    if (i == 1):
        plt.xlabel('probability', fontsize=12., labelpad=5)
    
outfig = str(mainpath) +'DailyFlow.png'    
plt.savefig(str(outfig),dpi=300,format = 'png',transparent='True')

# %% [markdown]
# <font color='blue'>Plot monthly sim. and obs. flow</font>

# %%
# Reorganize the data set to conform to the wateryear (ie. Oct-Sep)
for i, n in enumerate(gage_id):
    MonthlyObsFlow[n] = MonthlyObsFlow[n][9:].append(MonthlyObsFlow[n][:9])
    MonthlySimFlow[n] = MonthlySimFlow[n][9:].append(MonthlySimFlow[n][:9])

# %% [markdown]
# <font color='blue'>Compute **Nash** between sim. and obs. **monthly** flow </font>

# %%
nash_flow = {}
for i, n in enumerate(gage_id):
    sim_mean= sum(MonthlySimFlow[n])/float(len(MonthlySimFlow[n]))
    obs_mean= sum(MonthlyObsFlow[n])/float(len(MonthlyObsFlow[n]))
    ss_tot = sum((x-obs_mean)**2 for x in MonthlyObsFlow[n]) 
    ss_err = sum((y-x)**2 for y,x in zip(MonthlySimFlow[n], MonthlyObsFlow[n]))
    nash_flow[n] = 1 - (ss_err/ss_tot)
    print "gage[%s] monthly flow nash = %.2f" % (str(gage_id[i]), nash_flow[n])
# Out:
# gage[01129200] monthly flow nash = -9.67
# gage[01129500] monthly flow nash = 0.47
# gage[01131500] monthly flow nash = 0.71
# gage[01138500] monthly flow nash = 0.69
# gage[01144500] monthly flow nash = 0.87
# gage[01154500] monthly flow nash = 0.87
# gage[01170500] monthly flow nash = 0.80
# gage[01184000] monthly flow nash = 0.82

# %%
fig=plt.figure(figsize=(12,12),dpi=400)
for i, n in enumerate(gage_id):
    ax = plt.subplot(4, 2, i+1)
    fig.subplots_adjust(hspace = 0.3, wspace = 0.3)
    props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
    
    textstr1 = '%s\nNash = %.2f' % (str(n), nash_flow[n])
    
    ax.text(.02,.78, textstr1, fontsize=12, horizontalalignment='left', transform=ax.transAxes, bbox=props)
    plt.plot(range(1, 13), MonthlyObsFlow[n].values, color='grey', label='obs', linewidth=2.0, linestyle='-')
    plt.plot(range(1, 13), MonthlySimFlow[n].values, color='blue', label='sim', linewidth=2.0, linestyle='-')

    plt.ylabel('flow ($m^{3}/s$)', fontsize=12.)
    if (i == 2):
        plt.xlabel('month', fontsize=12.)
    plt.xlim([1,12])
    ax.xaxis.set_major_locator(ticker.FixedLocator(np.arange(1,13)))
    ax.xaxis.set_major_formatter(ticker.FixedFormatter(['Oct','Nov','Dec','Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep']))
    grid(False)
    if (i == 0):
        ax.legend(loc='best', bbox_to_anchor=(1, 1))

outfig = str(mainpath) +'MonthlyFlow.png'    
plt.savefig(str(outfig),dpi=300, format = 'png',transparent='True')
